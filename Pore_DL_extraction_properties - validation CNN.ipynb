# %% [markdown]
# TESTING THE CODE

# %%
# Run this line if you want to restart the kenerl
from IPython.display import display, Javascript

display(Javascript('IPython.notebook.kernel.restart()'))

# %%
# Check if the gpu is available
import tensorflow as tf
physical_devices_1 = tf.config.list_physical_devices('GPU')
physical_devices_2 = tf.config.list_physical_devices(']CPU')
print(physical_devices_1)
print(physical_devices_2)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# []

# %%
import tensorflow as tf
print(tf.__version__)
import numpy as np
import os
from PIL import Image
# Out:
# 2.10.0

# %%
folder_path = 'IL033_teste_export_slice_tiff/'
# List all files in the folder
files = os.listdir(folder_path)

# %%
leng = len(files)-1
#leng = 5
specific_value = leng

# %%
leng
# Out:
# 3121

# %%
# Calculate the variation into the 3121 slices of the tomography image:
# Circle_radius
circle_radius_initial_parameter = 2.351
circle_radius_final_parameter = 2.365
variation_circle_parameter = abs(circle_radius_final_parameter - circle_radius_initial_parameter)
delta_circle_parameter = variation_circle_parameter/3121
#delta_circle_parameter, variation_circle_parameter, delta_circle_parameter * 3121
# calculate the variation into the 3121 width parameter
circle_center_width_initial_parameter = 1.93
circle_center_width_final_parameter = 1.94
variation_center_width_parameter = abs(circle_center_width_final_parameter - circle_center_width_initial_parameter)
delta_center_width_parameter = variation_center_width_parameter/3121
#variation_center_width_parameter, delta_center_width_parameter, delta_center_width_parameter * 3121
# calculate the variation into the 3121 height parameter
circle_center_height_initial_parameter = 1.98
circle_center_height_final_parameter = 2.04
variation_center_height_parameter = abs(circle_center_height_final_parameter - circle_center_height_initial_parameter)
delta_center_height_parameter = variation_center_height_parameter/3121
#variation_center_height_parameter, delta_center_height_parameter, delta_center_height_parameter * 3121

# %%
# To check the values until the iteration 700
# Allocate the vector to save the properties to each slice
###Grain_Area_vector_values = np.zeros_like(np.zeros(leng-2421))
###Grain_fraction_vector_values = np.zeros_like(np.zeros(leng-2421))
###porosity_vector_values = np.zeros_like(np.zeros(leng-2421))
###pore_Area_vector_values = np.zeros_like(np.zeros(leng-2421))

# %%
# Allocate the vector to save the properties to each slice
Grain_Area_vector_values = np.zeros(leng)
Grain_fraction_vector_values = np.zeros(leng)
porosity_vector_values = np.zeros(leng)
pore_Area_vector_values = np.zeros(leng)
ac_train =  np.zeros(leng)
ac_test = np.zeros(leng)
jaccard_metric_mask_real =  np.zeros(leng)
jaccard_metric_unet_real = np.zeros(leng)

loss_train =  np.zeros(leng)
loss_test = np.zeros(leng)

# %%
ac_train.shape, ac_test.shape, loss_train.shape, loss_test.shape
# Out:
# ((3121,), (3121,), (3121,), (3121,))

# %%
Grain_Area_vector_values.shape, Grain_fraction_vector_values.shape, porosity_vector_values.shape, pore_Area_vector_values.shape
# Out:
# ((3121,), (3121,), (3121,), (3121,))

# %%
import time

# Start the timer
start_time = time.time()

# Apply the methodology
images = []
import cv2
i = 0
for filename in (files):
    if filename.endswith('.tiff') or filename.endswith('.tif'):
        file_path = os.path.join(folder_path, filename)
        image = cv2.imread(file_path)
        slice_image = np.array(image)
        # Set the grain to be the value 1
        # This function is to create the binary image to the recognition process work
        def create_binary(img):    
            import cv2
            # Convert the image to grayscale
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            # Apply a threshold to the grayscale image
            #threshold_value = 95
            threshold_value = img.mean() + 0.24 * img.mean()
            max_value = 1
            # Set the value 1 to be the pore space
            ret, binary = cv2.threshold(gray, threshold_value, max_value, cv2.THRESH_BINARY)
            return binary
        ##def create_binary_otsu(img):    
        ##    import cv2
    
            # Convert the image to grayscale
        ##    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            # Apply Otsu's thresholding
        ##    ret, binary = cv2.threshold(gray, 0, 1, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    
        ##    return binary
        slice_image_binary = create_binary(slice_image)
        # BEGGIN FUNCTION SEGMENTATION WITH U NET
        # Calling the function
        def segmentation_with_u_net_sample_1(image_array, mask_array):
            # convert the image_array from uint8 to float64
            import numpy as np
            # convert to the numpy array
            image_array = np.array(image_array)
            mask_array = np.array(mask_array)
            # Remove the third dimension
            image_array = image_array[:, :, 0]
            # Convert uint8 to float64
            image_array = image_array.astype('float32')
    
            # convert the image_array from uint8 to float64
            import numpy as np

            # Convert uint8 to float64
            ##mask_array = mask_array.astype('bool')
            # Convert uint8 to float64
            mask_array = mask_array.astype('float32')
            # calculate the range of the min and max value of the image_array
            range_image_array = image_array.max() - image_array.min()
            # normalize the image_array to segmentation task
            image_array = (image_array - image_array.min()) / (range_image_array)
            # The step is the size of the moviment in one direction by the patch.
     
    
            from skimage.util import view_as_windows
            #==================old version to create patches==================
            # create patches to the images (original and binary)
            # Split the image and mask arrays into patches
            ##patch_size = (256, 256)  # define the patch size
            ##image_patches = view_as_windows(image_array, patch_size, step=256) 
            ##mask_patches = view_as_windows(mask_array, patch_size, step=256)

            # Reshape the patches to flatten them into 2D arrays
            ##image_patches = image_patches.reshape(-1, *patch_size)
            ##mask_patches = mask_patches.reshape(-1, *patch_size)
            # Add the color channel to the patches
            # Add a color channel
            ##image_patches = np.expand_dims(image_patches, axis=3)
            ##mask_patches = np.expand_dims(mask_patches, axis=3)
            #================================================================
            #===================new version to creat patches=================
            ## New version - sucess
            ## If you normalize the original image, you need to convert to the original scale to reconstruct
            ## If you don't normalize the code works...
            import numpy as np
            from skimage.util import view_as_windows

            # Convert image_array from uint8 to float64
            ##image_array = np.array(image_array)[:, :, 0].astype('float32')

            # Convert mask_array from uint8 to boolean
            ##mask_array = np.array(mask_array).astype('bool')

            # Normalize the image_array
            #range_image_array = image_array.max() - image_array.min()
            #image_array = (image_array - image_array.min()) / (range_image_array)

            # Split the image and mask arrays into patches
            patch_size = (184, 184)
            step = 184
            image_patches = view_as_windows(image_array, patch_size, step=step)
            mask_patches = view_as_windows(mask_array, patch_size, step=step)

            # Reshape the patches to flatten them into 2D arrays
            image_patches_flat = image_patches.reshape(-1, *patch_size)
            mask_patches_flat = mask_patches.reshape(-1, *patch_size)

            # Add the color channel to the patches
            image_patches_flat = np.expand_dims(image_patches_flat, axis=3)
            mask_patches_flat = np.expand_dims(mask_patches_flat, axis=3)

            # Save the position of each patch
            patch_positions = []

            for i in range(image_patches.shape[0]):
                for j in range(image_patches.shape[1]):
                    start_row = i * step
                    start_col = j * step
                    end_row = start_row + patch_size[0]
                    end_col = start_col + patch_size[1]

                    patch_positions.append({
                        'start_row': start_row,
                        'start_col': start_col,
                        'end_row': end_row,
                        'end_col': end_col
                                })

            # Save the patch positions as a NumPy array
            patch_positions_array = np.array(patch_positions)
    
    
    
    
    
            from sklearn.model_selection import train_test_split
    
            # assume X is your feature matrix and y is your target vector
            X_train, X_test, y_train, y_test = train_test_split(image_patches_flat, mask_patches_flat, test_size=0.2, random_state=42)
            # test_size = 0.3 specifies that 30% of the data will be used for testing
            # random_state = 42 sets a seed for the random number generator to ensure reproducibility
    
            #import necessary libraries
            import numpy as np 
            from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D
            from tensorflow.keras.models import Model
            from tensorflow.keras.optimizers import Adam

            #define parameters
            input_shape = (184, 184, 1)
            filters = 92
            
        
            from keras.callbacks import EarlyStopping

            # Construct model
            inputs = Input(input_shape)
            x = Conv2D(filters, (3, 3), activation='relu', padding='same')(inputs)
            x = MaxPooling2D((2, 2), padding='same')(x)
            x = Conv2D(filters, (3, 3), activation='relu', padding='same')(x)
            x = UpSampling2D((2, 2))(x)
            outputs = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)
            # Change the activation function in the final layer to 'sigmoid'
    

            # Compile model
            model = Model(inputs=[inputs], outputs=[outputs])
            model.compile(optimizer=Adam(lr=0.01), loss='binary_crossentropy', metrics=['accuracy'])

            # Define EarlyStopping callback
            early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
            model.fit(X_train, y_train, epochs=20, validation_data=(X_test, y_test), callbacks=[early_stopping], verbose=1)
            y_pred = model.predict(image_patches_flat)
            # Evaluate the model on the test data
            loss_test, final_accuracy_test = model.evaluate(X_test, y_test)
            # Evaluate the model on the train data
            loss_train, final_accuracy_train = model.evaluate(X_train, y_train)
            ####y_pred = mask_patches_flat # Test
            return y_pred, image_patches_flat, mask_patches_flat, patch_positions_array, final_accuracy_train, final_accuracy_test, loss_train, loss_test
            ####y_pred = mask_patches_flat # Test # the thresold is img.mean() + 0.20 * img.mean()
            #return y_pred, image_patches_flat, mask_patches_flat, patch_positions_array
            # END FUNCTION SEGMENTATION WITH U NET
        y_pred_slice_tensor, image_slice_tensor_patches, mask_slice_tensor_patches, slice_patch_positions, ac_train_value, ac_test_value, loss_train_value, loss_test_value = segmentation_with_u_net_sample_1(slice_image, slice_image_binary)
        # Function to reconstruct the original image and mask
        import numpy as np

        def jaccard_similarity(image, binary_mask):
            # Flatten the images to 1D arrays
            image_flat = image.flatten()
            binary_mask_flat = binary_mask.flatten()

            # Calculate intersection (number of matching pixels)
            intersection = np.sum(np.logical_and(image_flat, binary_mask_flat))

            # Calculate union (number of pixels marked as foreground in either image or mask)
            union = np.sum(np.logical_or(image_flat, binary_mask_flat))

            # Calculate Jaccard similarity coefficient
            jaccard = intersection / union

            return jaccard

        # Example usage:
        # Assuming 'image' and 'binary_mask' are the original image and its binary mask
        image_slice_tensor_patches.shape, y_pred_slice_tensor.shape
        jaccard_metric_unet_real[i] = jaccard_similarity(image_slice_tensor_patches, y_pred_slice_tensor)
        print("Jaccard similarity coefficient with cnn:", jaccard_metric_unet_real[i])
        # Example usage:
        # Assuming 'image' and 'binary_mask' are the original image and its binary mask
        jaccard_metric_mask_real[i] = jaccard_similarity(image_slice_tensor_patches, mask_slice_tensor_patches)
        print("Jaccard similarity coefficient with thresold:", jaccard_metric_mask_real[i])
        def reconstruct_mask(mask_patches_flat, patch_positions_array, image_shape):
            # Get the original image shape
            original_shape = (image_shape[0], image_shape[1])

            # Initialize empty arrays for the reconstructed image and mask
            reconstructed_mask = np.zeros(original_shape, dtype='float32')

            for i, position in enumerate(patch_positions_array):
                start_row, start_col = position['start_row'], position['start_col']
                end_row, end_col = position['end_row'], position['end_col']

                # Extract the patches from the flat arrays
                #image_patch = image_patches_flat[i, :, :, 0]
                mask_patch = mask_patches_flat[i, :, :, 0]

                # Update the reconstructed image and mask
                #reconstructed_image[start_row:end_row, start_col:end_col] = image_patch
                reconstructed_mask[start_row:end_row, start_col:end_col] = mask_patch

            return reconstructed_mask
        # (you can replace these with your actual variables)
        reconstructed_mask_slice_image_tensor = reconstruct_mask(y_pred_slice_tensor, slice_patch_positions, slice_image.shape)
        print(reconstructed_mask_slice_image_tensor.min(), reconstructed_mask_slice_image_tensor.max())
        
        # When you set the grain to be the value 1 # background 
        # You are suppose to use the calculate_pore_properties_gray_version_rock to calculate the properties
        import numpy as np

        def calculate_pore_properties_gray_version_rock(segmented_image, pixel_area, circle_area):
            """
            Calculate pore properties including pore area and porosity for a grayscale segmented image.

            Parameters:
            - segmented_image: 2D segmented image where pores are represented by values between 0 and 1.
            - pixel_area: Area of a single pixel in the image.

            Returns:
            - grain_area: Total area of segmented grain regions.
            - fraction_matrix: matrix calculated as the ratio of grain area to the total area.
            """
            # Check if the input image is within the valid range
            if not (np.all(0 <= segmented_image) and np.all(segmented_image <= 1)):
                raise ValueError("Input image must have values between 0 and 1 for grayscale segmentation.")
            # Calculate pore area
            grain_area = np.sum(segmented_image) * pixel_area
    
            # Calculate total area of the image
            #total_area = np.sum(segmented_image >= 0) * pixel_area
            ##total_area = np.sum(segmented_image >= segmented_image.min()) * pixel_area
            total_area = circle_area
            # Calculate porosity
            fraction_matrix = grain_area / total_area
            porosity = 1.0 - fraction_matrix
            pore_area = total_area - grain_area
            return grain_area, fraction_matrix, porosity, pore_area
        
        import random

        import numpy as np
        import cv2

        # Define the range
        #min_value = 1
        #max_value = 3121

        # Generate a random number between the range
        #random_number = random.randint(min_value, max_value)

        # Print the random number
        #print(random_number)

        # Assuming you have loaded the image
        #image = globals()[f'tensor_image_{random_number}']  # Placeholder for the image, replace with your image loading code
        ##image = slice_image # the same thing of the code bellow, you avoid to spent the memory.
        # Get the dimensions of the image
        height, width, _ = slice_image.shape

        # Assuming you have defined these variables elsewhere in your code
        ##delta_circle_parameter = 0.5
        ##delta_center_width_parameter = 0.3
        ##delta_center_height_parameter = 0.2
        
        
        # Calculate the radius and center of the circle (with float coordinates)
        circle_radius = min(width, height) / (2.351 + ((i) * delta_circle_parameter))  # Adjust the radius as needed with a float value
        circle_center = (width / (1.93 + ((i) * delta_center_width_parameter)), height / (1.98 + ((i) * delta_center_height_parameter)))

        # Calculate the area of the circle
        circle_area = np.pi * circle_radius ** 2

        # Calculate the external area (total area - circle area)
        external_area = height * width - circle_area

        # Print the calculated areas
        ##print("Circle Area:", circle_area)
        ##print("External Area:", external_area)

        # Check if the sum of internal and external areas equals the total area
        total_area = height * width
        sum_of_areas = circle_area + external_area
        ##print("Sum of Areas (Internal + External):", sum_of_areas)
        ##print("Total Area:", total_area)
        ##print("Are the areas equal?", np.isclose(sum_of_areas, total_area))
        # Based on the real size of the object in the world
        # In the real world we have 1704 pixels in a diameter with 3.81 cm
        value_pixel_real_world=(3.81)/(1704) # Simple rule
        # Calculating the distance of the width and height in mm
        image_width_cm = (2024 * value_pixel_real_world)
        image_height_cm = (2024 * value_pixel_real_world)
        image_width_m = image_width_cm * (10)**(-2)
        image_height_m = image_height_cm * (10)**(-2)
        # Calculating the total area in meters:
        total_check_real_area = (image_width_m) * (image_height_m)
        # Calculate the total number of pixels in the image
        total_pixels_horizontal = 2024
        total_pixels_vertical = 2024
        total_pixels = total_pixels_horizontal * total_pixels_vertical

        # Calculate the area represented by each pixel in the real world
        pixel_area_real_world = (image_width_m * image_height_m) / total_pixels
        # Atribute the area to each pixel in the real world
        pixel_area = pixel_area_real_world
        # Define the circle area and the external area.
        circle_area_real = circle_area * pixel_area
        external_area_real = external_area * pixel_area
        # Shave the properties in each vector
        ac_train[i], ac_test[i], loss_train[i], loss_test[i] = ac_train_value, ac_test_value, loss_train_value, loss_test_value
        Grain_Area_vector_values[i], Grain_fraction_vector_values[i], porosity_vector_values[i], pore_Area_vector_values[i] = calculate_pore_properties_gray_version_rock(reconstructed_mask_slice_image_tensor, pixel_area, circle_area_real)
        globals()[f'name_slice_{i}'] = filename
        print('The iteration:',i, 'is complete')
        i = i + 1
        if i == specific_value:
            print("Found the specific value. Stopping the loop.")
            break  # Exit the loop

# End the timer
end_time = time.time()

# Calculate the elapsed time in seconds
elapsed_time_seconds = end_time - start_time

# Convert elapsed time from seconds to hours
elapsed_time_hours = elapsed_time_seconds / 3600

print("Time elapsed:", elapsed_time_hours, "hours")
# Out:
# Epoch 1/20
# C:\Users\CometLake_05\anaconda3\envs\GPU-test3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 3/3 [==============================] - 19s 384ms/step - loss: 0.6000 - accuracy: 0.5489 - val_loss: 0.5542 - val_accuracy: 0.6546
# Epoch 2/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.4563 - accuracy: 0.8427 - val_loss: 0.3392 - val_accuracy: 0.9272
# Epoch 3/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.2601 - accuracy: 0.9365 - val_loss: 0.1260 - val_accuracy: 0.9713
# Epoch 4/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.1443 - accuracy: 0.9524 - val_loss: 0.1607 - val_accuracy: 0.9506
# Epoch 5/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.2354 - accuracy: 0.9380 - val_loss: 0.3090 - val_accuracy: 0.9391
# Epoch 6/20
# 3/3 [==============================] - 0s 96ms/step - loss: 0.2220 - accuracy: 0.9493 - val_loss: 0.3768 - val_accuracy: 0.7900
# Epoch 7/20
# 3/3 [==============================] - 0s 96ms/step - loss: 0.2728 - accuracy: 0.8863 - val_loss: 0.3090 - val_accuracy: 0.9373
# Epoch 8/20
# 3/3 [==============================] - 0s 95ms/step - loss: 0.3365 - accuracy: 0.9295 - val_loss: 0.2024 - val_accuracy: 0.9407
# Epoch 9/20
# 3/3 [==============================] - 0s 96ms/step - loss: 0.1515 - accuracy: 0.9480 - val_loss: 0.1698 - val_accuracy: 0.9778
# Epoch 10/20
# 3/3 [==============================] - 0s 104ms/step - loss: 0.1843 - accuracy: 0.9719 - val_loss: 0.0936 - val_accuracy: 0.9639
# Epoch 11/20
# 3/3 [==============================] - 0s 95ms/step - loss: 0.1186 - accuracy: 0.9500 - val_loss: 0.1377 - val_accuracy: 0.9445
# Epoch 12/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.1517 - accuracy: 0.9390 - val_loss: 0.1177 - val_accuracy: 0.9484
# Epoch 13/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.1144 - accuracy: 0.9497 - val_loss: 0.0891 - val_accuracy: 0.9693
# Epoch 14/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.1017 - accuracy: 0.9738 - val_loss: 0.0855 - val_accuracy: 0.9826
# Epoch 15/20
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0818 - accuracy: 0.9779 - val_loss: 0.0603 - val_accuracy: 0.9741
# Epoch 16/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0634 - accuracy: 0.9729 - val_loss: 0.0476 - val_accuracy: 0.9833
# Epoch 17/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0543 - accuracy: 0.9813 - val_loss: 0.0445 - val_accuracy: 0.9806
# Epoch 18/20
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0498 - accuracy: 0.9786 - val_loss: 0.0443 - val_accuracy: 0.9835
# Epoch 19/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0468 - accuracy: 0.9815 - val_loss: 0.0431 - val_accuracy: 0.9817
# Epoch 20/20
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0460 - accuracy: 0.9811 - val_loss: 0.0352 - val_accuracy: 0.9852
# 4/4 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0352 - accuracy: 0.9852
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0398 - accuracy: 0.9833
# Jaccard similarity coefficient with cnn: 0.9999997558937025
# Jaccard similarity coefficient with thresold: 0.4704278574174768
# 4.0264278e-11 1.0
# The iteration: 0 is complete
# Epoch 1/20
# 3/3 [==============================] - 1s 147ms/step - loss: 0.5987 - accuracy: 0.5773 - val_loss: 0.5801 - val_accuracy: 0.6500
# Epoch 2/20
# 3/3 [==============================] - 0s 96ms/step - loss: 0.4852 - accuracy: 0.8303 - val_loss: 0.3324 - val_accuracy: 0.9337
# Epoch 3/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.2938 - accuracy: 0.9265 - val_loss: 0.1776 - val_accuracy: 0.9835
# Epoch 4/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.1496 - accuracy: 0.9596 - val_loss: 0.0781 - val_accuracy: 0.9660
# Epoch 5/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.1728 - accuracy: 0.9375 - val_loss: 0.3475 - val_accuracy: 0.9351
# Epoch 6/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.3635 - accuracy: 0.9274 - val_loss: 0.1757 - val_accuracy: 0.9428
# Epoch 7/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.1453 - accuracy: 0.9571 - val_loss: 0.2169 - val_accuracy: 0.9461
# Epoch 8/20
# 3/3 [==============================] - 0s 95ms/step - loss: 0.1693 - accuracy: 0.9624 - val_loss: 0.1039 - val_accuracy: 0.9541
# Epoch 9/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.1327 - accuracy: 0.9431 - val_loss: 0.1384 - val_accuracy: 0.9436
# Epoch 10/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.1416 - accuracy: 0.9400 - val_loss: 0.1026 - val_accuracy: 0.9544
# Epoch 11/20
# 3/3 [==============================] - 0s 94ms/step - loss: 0.1180 - accuracy: 0.9601 - val_loss: 0.1148 - val_accuracy: 0.9798
# Epoch 12/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.1119 - accuracy: 0.9738 - val_loss: 0.0778 - val_accuracy: 0.9672
# Epoch 13/20
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0841 - accuracy: 0.9633 - val_loss: 0.0604 - val_accuracy: 0.9753
# Epoch 14/20
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0690 - accuracy: 0.9786 - val_loss: 0.0504 - val_accuracy: 0.9795
# Epoch 15/20
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0603 - accuracy: 0.9739 - val_loss: 0.0465 - val_accuracy: 0.9839
# Epoch 16/20
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0576 - accuracy: 0.9793 - val_loss: 0.0594 - val_accuracy: 0.9747
# Epoch 17/20
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0591 - accuracy: 0.9767 - val_loss: 0.0392 - val_accuracy: 0.9836
# Epoch 18/20
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0475 - accuracy: 0.9799 - val_loss: 0.0478 - val_accuracy: 0.9822
# Epoch 19/20
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0500 - accuracy: 0.9799 - val_loss: 0.0370 - val_accuracy: 0.9853
# Epoch 20/20
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0429 - accuracy: 0.9829 - val_loss: 0.0394 - val_accuracy: 0.9831
# 4/4 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0394 - accuracy: 0.9831
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0444 - accuracy: 0.9812
# Jaccard similarity coefficient with cnn: 0.9999997558937025
# Jaccard similarity coefficient with thresold: 0.47099516059146973
# 9.743519e-10 1.0
# The iteration: 1 is complete
# Epoch 1/20
# 3/3 [==============================] - 1s 149ms/step - loss: 0.6588 - accuracy: 0.6040 - val_loss: 0.5637 - val_accuracy: 0.9232
# Epoch 2/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.4992 - accuracy: 0.8817 - val_loss: 0.4363 - val_accuracy: 0.9253
# Epoch 3/20
# 3/3 [==============================] - 0s 95ms/step - loss: 0.3766 - accuracy: 0.9321 - val_loss: 0.2649 - val_accuracy: 0.9384
# Epoch 4/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.2282 - accuracy: 0.9409 - val_loss: 0.1520 - val_accuracy: 0.9471
# Epoch 5/20
# 3/3 [==============================] - 0s 96ms/step - loss: 0.1923 - accuracy: 0.9403 - val_loss: 0.1120 - val_accuracy: 0.9759
# Epoch 6/20
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0992 - accuracy: 0.9677 - val_loss: 0.0729 - val_accuracy: 0.9674
# Epoch 7/20
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0766 - accuracy: 0.9754 - val_loss: 0.0723 - val_accuracy: 0.9687
# Epoch 8/20
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0750 - accuracy: 0.9686 - val_loss: 0.0873 - val_accuracy: 0.9714
# Epoch 9/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0766 - accuracy: 0.9705 - val_loss: 0.0515 - val_accuracy: 0.9778
# Epoch 10/20
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0583 - accuracy: 0.9786 - val_loss: 0.0548 - val_accuracy: 0.9768
# Epoch 11/20
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0567 - accuracy: 0.9768 - val_loss: 0.0593 - val_accuracy: 0.9784
# Epoch 12/20
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0591 - accuracy: 0.9769 - val_loss: 0.0400 - val_accuracy: 0.9835
# Epoch 13/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0488 - accuracy: 0.9808 - val_loss: 0.0493 - val_accuracy: 0.9797
# Epoch 14/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0520 - accuracy: 0.9792 - val_loss: 0.0412 - val_accuracy: 0.9825
# Epoch 15/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0466 - accuracy: 0.9808 - val_loss: 0.0473 - val_accuracy: 0.9816
# Epoch 16/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0546 - accuracy: 0.9783 - val_loss: 0.0394 - val_accuracy: 0.9844
# Epoch 17/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0526 - accuracy: 0.9792 - val_loss: 0.0532 - val_accuracy: 0.9790
# Epoch 18/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0533 - accuracy: 0.9793 - val_loss: 0.0480 - val_accuracy: 0.9804
# Epoch 19/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0526 - accuracy: 0.9792 - val_loss: 0.0665 - val_accuracy: 0.9742
# Epoch 20/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0707 - accuracy: 0.9735 - val_loss: 0.0397 - val_accuracy: 0.9830
# 4/4 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0397 - accuracy: 0.9830
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0437 - accuracy: 0.9815
# Jaccard similarity coefficient with cnn: 0.9999997558937025
# Jaccard similarity coefficient with thresold: 0.47181218456881663
# 2.962633e-08 1.0
# The iteration: 2 is complete
# Epoch 1/20
# 3/3 [==============================] - 1s 156ms/step - loss: 0.6169 - accuracy: 0.5706 - val_loss: 0.5344 - val_accuracy: 0.6513
# Epoch 2/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.4839 - accuracy: 0.8537 - val_loss: 0.4120 - val_accuracy: 0.9252
# Epoch 3/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.3388 - accuracy: 0.9408 - val_loss: 0.1751 - val_accuracy: 0.9483
# Epoch 4/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.1557 - accuracy: 0.9442 - val_loss: 0.1510 - val_accuracy: 0.9750
# Epoch 5/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.1909 - accuracy: 0.9499 - val_loss: 0.1220 - val_accuracy: 0.9530
# Epoch 6/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.1183 - accuracy: 0.9595 - val_loss: 0.0927 - val_accuracy: 0.9603
# Epoch 7/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0843 - accuracy: 0.9648 - val_loss: 0.0923 - val_accuracy: 0.9771
# Epoch 8/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0757 - accuracy: 0.9730 - val_loss: 0.0667 - val_accuracy: 0.9700
# Epoch 9/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0657 - accuracy: 0.9760 - val_loss: 0.0460 - val_accuracy: 0.9829
# Epoch 10/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0579 - accuracy: 0.9758 - val_loss: 0.0439 - val_accuracy: 0.9839
# Epoch 11/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0619 - accuracy: 0.9769 - val_loss: 0.0739 - val_accuracy: 0.9711
# Epoch 12/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0655 - accuracy: 0.9749 - val_loss: 0.0416 - val_accuracy: 0.9841
# Epoch 13/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0507 - accuracy: 0.9792 - val_loss: 0.0391 - val_accuracy: 0.9836
# Epoch 14/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0467 - accuracy: 0.9815 - val_loss: 0.0475 - val_accuracy: 0.9799
# Epoch 15/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0476 - accuracy: 0.9807 - val_loss: 0.0377 - val_accuracy: 0.9843
# Epoch 16/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0445 - accuracy: 0.9815 - val_loss: 0.0458 - val_accuracy: 0.9824
# Epoch 17/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0475 - accuracy: 0.9807 - val_loss: 0.0370 - val_accuracy: 0.9843
# Epoch 18/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0427 - accuracy: 0.9826 - val_loss: 0.0426 - val_accuracy: 0.9820
# Epoch 19/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0445 - accuracy: 0.9816 - val_loss: 0.0363 - val_accuracy: 0.9846
# Epoch 20/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0417 - accuracy: 0.9825 - val_loss: 0.0408 - val_accuracy: 0.9837
# 4/4 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0408 - accuracy: 0.9837
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0450 - accuracy: 0.9822
# Jaccard similarity coefficient with cnn: 0.9999997558937025
# Jaccard similarity coefficient with thresold: 0.4724190329726662
# 3.4470917e-09 0.99999917
# The iteration: 3 is complete
# Epoch 1/20
# 3/3 [==============================] - 1s 155ms/step - loss: 0.6935 - accuracy: 0.4975 - val_loss: 0.6758 - val_accuracy: 0.5670
# Epoch 2/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.6561 - accuracy: 0.7926 - val_loss: 0.5954 - val_accuracy: 0.9320
# Epoch 3/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.5327 - accuracy: 0.9195 - val_loss: 0.3638 - val_accuracy: 0.9354
# Epoch 4/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.2755 - accuracy: 0.9369 - val_loss: 0.1492 - val_accuracy: 0.9432
# Epoch 5/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.1849 - accuracy: 0.9388 - val_loss: 0.2295 - val_accuracy: 0.9383
# Epoch 6/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.2067 - accuracy: 0.9310 - val_loss: 0.1005 - val_accuracy: 0.9567
# Epoch 7/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.1721 - accuracy: 0.9441 - val_loss: 0.0701 - val_accuracy: 0.9685
# Epoch 8/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.1695 - accuracy: 0.9248 - val_loss: 0.2675 - val_accuracy: 0.9418
# Epoch 9/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.3407 - accuracy: 0.9324 - val_loss: 0.1988 - val_accuracy: 0.9467
# Epoch 10/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.1726 - accuracy: 0.9385 - val_loss: 0.1312 - val_accuracy: 0.9618
# Epoch 11/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.1193 - accuracy: 0.9581 - val_loss: 0.1512 - val_accuracy: 0.9514
# Epoch 12/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.1413 - accuracy: 0.9501 - val_loss: 0.0617 - val_accuracy: 0.9748
# Epoch 13/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.1042 - accuracy: 0.9694 - val_loss: 0.0609 - val_accuracy: 0.9789
# Epoch 14/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0864 - accuracy: 0.9658 - val_loss: 0.1129 - val_accuracy: 0.9573
# Epoch 15/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.1041 - accuracy: 0.9580 - val_loss: 0.0600 - val_accuracy: 0.9801
# Epoch 16/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0813 - accuracy: 0.9788 - val_loss: 0.0597 - val_accuracy: 0.9815
# Epoch 17/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0715 - accuracy: 0.9708 - val_loss: 0.0655 - val_accuracy: 0.9709
# Epoch 18/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0665 - accuracy: 0.9730 - val_loss: 0.0591 - val_accuracy: 0.9816
# Epoch 19/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0647 - accuracy: 0.9798 - val_loss: 0.0545 - val_accuracy: 0.9782
# Epoch 20/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0616 - accuracy: 0.9745 - val_loss: 0.0536 - val_accuracy: 0.9775
# 4/4 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0536 - accuracy: 0.9775
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0588 - accuracy: 0.9758
# Jaccard similarity coefficient with cnn: 0.9999997558937025
# Jaccard similarity coefficient with thresold: 0.4730329604608728
# 4.7306814e-05 0.9999629
# The iteration: 4 is complete
# Epoch 1/20
# 3/3 [==============================] - 1s 155ms/step - loss: 0.6455 - accuracy: 0.5418 - val_loss: 0.5649 - val_accuracy: 0.9305
# Epoch 2/20
# 3/3 [==============================] - 0s 103ms/step - loss: 0.5319 - accuracy: 0.9287 - val_loss: 0.4110 - val_accuracy: 0.9324
# Epoch 3/20
# 3/3 [==============================] - 0s 103ms/step - loss: 0.3256 - accuracy: 0.9283 - val_loss: 0.2630 - val_accuracy: 0.9624
# Epoch 4/20
# 3/3 [==============================] - 0s 104ms/step - loss: 0.3331 - accuracy: 0.9313 - val_loss: 0.2146 - val_accuracy: 0.9379
# Epoch 5/20
# 3/3 [==============================] - 0s 103ms/step - loss: 0.1720 - accuracy: 0.9627 - val_loss: 0.1310 - val_accuracy: 0.9496
# Epoch 6/20
# 3/3 [==============================] - 0s 104ms/step - loss: 0.1757 - accuracy: 0.9406 - val_loss: 0.0736 - val_accuracy: 0.9683
# Epoch 7/20
# 3/3 [==============================] - 0s 103ms/step - loss: 0.1565 - accuracy: 0.9292 - val_loss: 0.1910 - val_accuracy: 0.9440
# Epoch 8/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.2339 - accuracy: 0.9343 - val_loss: 0.1318 - val_accuracy: 0.9480
# Epoch 9/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.1427 - accuracy: 0.9586 - val_loss: 0.1309 - val_accuracy: 0.9816
# Epoch 10/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.1168 - accuracy: 0.9641 - val_loss: 0.1235 - val_accuracy: 0.9495
# Epoch 11/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.1291 - accuracy: 0.9461 - val_loss: 0.0829 - val_accuracy: 0.9632
# Epoch 12/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0962 - accuracy: 0.9710 - val_loss: 0.0924 - val_accuracy: 0.9816
# Epoch 13/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0901 - accuracy: 0.9729 - val_loss: 0.0801 - val_accuracy: 0.9636
# Epoch 14/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0846 - accuracy: 0.9619 - val_loss: 0.0621 - val_accuracy: 0.9769
# Epoch 15/20
# 3/3 [==============================] - 0s 103ms/step - loss: 0.0731 - accuracy: 0.9787 - val_loss: 0.0568 - val_accuracy: 0.9791
# Epoch 16/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0651 - accuracy: 0.9725 - val_loss: 0.0541 - val_accuracy: 0.9762
# Epoch 17/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0576 - accuracy: 0.9789 - val_loss: 0.0470 - val_accuracy: 0.9815
# Epoch 18/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0511 - accuracy: 0.9791 - val_loss: 0.0443 - val_accuracy: 0.9843
# Epoch 19/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.0467 - accuracy: 0.9819 - val_loss: 0.0384 - val_accuracy: 0.9840
# Epoch 20/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.0424 - accuracy: 0.9827 - val_loss: 0.0380 - val_accuracy: 0.9839
# 4/4 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0380 - accuracy: 0.9839
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0420 - accuracy: 0.9822
# Jaccard similarity coefficient with cnn: 0.9999997558937025
# Jaccard similarity coefficient with thresold: 0.47368448032807897
# 6.773504e-09 0.99999976
# The iteration: 5 is complete
# Epoch 1/20
# 3/3 [==============================] - 1s 155ms/step - loss: 0.7216 - accuracy: 0.4568 - val_loss: 0.6701 - val_accuracy: 0.4444
# Epoch 2/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.6635 - accuracy: 0.7386 - val_loss: 0.6402 - val_accuracy: 0.8565
# Epoch 3/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.6104 - accuracy: 0.7022 - val_loss: 0.5455 - val_accuracy: 0.6495
# Epoch 4/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.4863 - accuracy: 0.7575 - val_loss: 0.4092 - val_accuracy: 0.9365
# Epoch 5/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.3520 - accuracy: 0.9286 - val_loss: 0.2452 - val_accuracy: 0.9395
# Epoch 6/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.2087 - accuracy: 0.9487 - val_loss: 0.1460 - val_accuracy: 0.9465
# Epoch 7/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.1240 - accuracy: 0.9573 - val_loss: 0.0810 - val_accuracy: 0.9653
# Epoch 8/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.1017 - accuracy: 0.9637 - val_loss: 0.0635 - val_accuracy: 0.9730
# Epoch 9/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.1872 - accuracy: 0.9340 - val_loss: 0.4209 - val_accuracy: 0.9369
# Epoch 10/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.3992 - accuracy: 0.9332 - val_loss: 0.0568 - val_accuracy: 0.9830
# Epoch 11/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.3711 - accuracy: 0.8197 - val_loss: 0.3542 - val_accuracy: 0.9401
# Epoch 12/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.6072 - accuracy: 0.9262 - val_loss: 0.6545 - val_accuracy: 0.9315
# Epoch 13/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.5679 - accuracy: 0.9273 - val_loss: 0.1543 - val_accuracy: 0.9520
# Epoch 14/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.2051 - accuracy: 0.9045 - val_loss: 0.1518 - val_accuracy: 0.9511
# Epoch 15/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.1211 - accuracy: 0.9557 - val_loss: 0.1670 - val_accuracy: 0.9498
# Epoch 16/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.2033 - accuracy: 0.9427 - val_loss: 0.1511 - val_accuracy: 0.9515
# Epoch 17/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.1174 - accuracy: 0.9561 - val_loss: 0.0784 - val_accuracy: 0.9832
# Epoch 18/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.1240 - accuracy: 0.9705 - val_loss: 0.0734 - val_accuracy: 0.9827
# Epoch 19/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0844 - accuracy: 0.9703 - val_loss: 0.1089 - val_accuracy: 0.9581
# Epoch 20/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.1175 - accuracy: 0.9543 - val_loss: 0.0735 - val_accuracy: 0.9681
# 4/4 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0568 - accuracy: 0.9830
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0634 - accuracy: 0.9809
# Jaccard similarity coefficient with cnn: 0.9999997558937025
# Jaccard similarity coefficient with thresold: 0.47435650512928484
# 9.666333e-05 0.9999865
# The iteration: 6 is complete
# Epoch 1/20
# 3/3 [==============================] - 1s 157ms/step - loss: 0.6790 - accuracy: 0.5150 - val_loss: 0.6417 - val_accuracy: 0.6571
# Epoch 2/20
# 3/3 [==============================] - 0s 103ms/step - loss: 0.5876 - accuracy: 0.5346 - val_loss: 0.5197 - val_accuracy: 0.6634
# Epoch 3/20
# 3/3 [==============================] - 0s 103ms/step - loss: 0.4639 - accuracy: 0.8270 - val_loss: 0.3845 - val_accuracy: 0.9306
# Epoch 4/20
# 3/3 [==============================] - 0s 103ms/step - loss: 0.3328 - accuracy: 0.9439 - val_loss: 0.2301 - val_accuracy: 0.9411
# Epoch 5/20
# 3/3 [==============================] - 0s 103ms/step - loss: 0.2455 - accuracy: 0.9340 - val_loss: 0.1379 - val_accuracy: 0.9817
# Epoch 6/20
# 3/3 [==============================] - 0s 103ms/step - loss: 0.1157 - accuracy: 0.9717 - val_loss: 0.0995 - val_accuracy: 0.9587
# Epoch 7/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.1040 - accuracy: 0.9647 - val_loss: 0.1298 - val_accuracy: 0.9560
# Epoch 8/20
# 3/3 [==============================] - 0s 103ms/step - loss: 0.1675 - accuracy: 0.9495 - val_loss: 0.0585 - val_accuracy: 0.9845
# Epoch 9/20
# 3/3 [==============================] - 0s 103ms/step - loss: 0.1332 - accuracy: 0.9480 - val_loss: 0.2394 - val_accuracy: 0.9480
# Epoch 10/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.2253 - accuracy: 0.9463 - val_loss: 0.0493 - val_accuracy: 0.9831
# Epoch 11/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.1899 - accuracy: 0.9093 - val_loss: 0.2590 - val_accuracy: 0.9472
# Epoch 12/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.3751 - accuracy: 0.9370 - val_loss: 0.2585 - val_accuracy: 0.9467
# Epoch 13/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.1521 - accuracy: 0.9619 - val_loss: 0.2759 - val_accuracy: 0.8697
# Epoch 14/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.1571 - accuracy: 0.9315 - val_loss: 0.1288 - val_accuracy: 0.9563
# Epoch 15/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.1595 - accuracy: 0.9488 - val_loss: 0.1202 - val_accuracy: 0.9559
# Epoch 16/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.0994 - accuracy: 0.9615 - val_loss: 0.0926 - val_accuracy: 0.9848
# Epoch 17/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.1113 - accuracy: 0.9810 - val_loss: 0.0662 - val_accuracy: 0.9759
# Epoch 18/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0820 - accuracy: 0.9656 - val_loss: 0.0934 - val_accuracy: 0.9603
# Epoch 19/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0974 - accuracy: 0.9577 - val_loss: 0.0686 - val_accuracy: 0.9701
# Epoch 20/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0769 - accuracy: 0.9754 - val_loss: 0.0775 - val_accuracy: 0.9850
# 4/4 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0493 - accuracy: 0.9831
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0546 - accuracy: 0.9817
# Jaccard similarity coefficient with cnn: 0.9999997558937025
# Jaccard similarity coefficient with thresold: 0.47481493686799336
# 8.080658e-05 0.9999943
# The iteration: 7 is complete
# Epoch 1/20
# 3/3 [==============================] - 1s 157ms/step - loss: 0.7212 - accuracy: 0.5874 - val_loss: 0.6181 - val_accuracy: 0.9286
# Epoch 2/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.5765 - accuracy: 0.8744 - val_loss: 0.5101 - val_accuracy: 0.7102
# Epoch 3/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.4487 - accuracy: 0.8642 - val_loss: 0.3529 - val_accuracy: 0.9446
# Epoch 4/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.2719 - accuracy: 0.9372 - val_loss: 0.1674 - val_accuracy: 0.9783
# Epoch 5/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.1992 - accuracy: 0.9469 - val_loss: 0.0931 - val_accuracy: 0.9798
# Epoch 6/20
# 3/3 [==============================] - 0s 103ms/step - loss: 0.1348 - accuracy: 0.9650 - val_loss: 0.1694 - val_accuracy: 0.9472
# Epoch 7/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.2159 - accuracy: 0.8941 - val_loss: 0.1671 - val_accuracy: 0.9497
# Epoch 8/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.4052 - accuracy: 0.9323 - val_loss: 0.4632 - val_accuracy: 0.9332
# Epoch 9/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.3008 - accuracy: 0.9387 - val_loss: 0.1876 - val_accuracy: 0.9220
# Epoch 10/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.1935 - accuracy: 0.9099 - val_loss: 0.1615 - val_accuracy: 0.9498
# Epoch 11/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.2469 - accuracy: 0.9374 - val_loss: 0.2049 - val_accuracy: 0.9431
# Epoch 12/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.1567 - accuracy: 0.9467 - val_loss: 0.1066 - val_accuracy: 0.9808
# Epoch 13/20
# 3/3 [==============================] - 0s 103ms/step - loss: 0.1478 - accuracy: 0.9711 - val_loss: 0.0813 - val_accuracy: 0.9705
# Epoch 14/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.1076 - accuracy: 0.9552 - val_loss: 0.1167 - val_accuracy: 0.9526
# Epoch 15/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.1117 - accuracy: 0.9540 - val_loss: 0.0918 - val_accuracy: 0.9813
# Epoch 16/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0902 - accuracy: 0.9768 - val_loss: 0.0739 - val_accuracy: 0.9680
# Epoch 17/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0825 - accuracy: 0.9640 - val_loss: 0.0621 - val_accuracy: 0.9755
# Epoch 18/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0725 - accuracy: 0.9773 - val_loss: 0.0597 - val_accuracy: 0.9791
# Epoch 19/20
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0667 - accuracy: 0.9735 - val_loss: 0.0603 - val_accuracy: 0.9735
# Epoch 20/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0645 - accuracy: 0.9752 - val_loss: 0.0563 - val_accuracy: 0.9817
# 4/4 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0563 - accuracy: 0.9817
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0626 - accuracy: 0.9800
# Jaccard similarity coefficient with cnn: 0.9999997558937025
# Jaccard similarity coefficient with thresold: 0.4711418685121107
# 2.255176e-06 0.99993384
# The iteration: 8 is complete
# Epoch 1/20
# 3/3 [==============================] - 1s 150ms/step - loss: 0.6724 - accuracy: 0.4676 - val_loss: 0.6148 - val_accuracy: 0.4356
# Epoch 2/20
# 3/3 [==============================] - 0s 103ms/step - loss: 0.5570 - accuracy: 0.5528 - val_loss: 0.4719 - val_accuracy: 0.9322
# Epoch 3/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.3965 - accuracy: 0.9216 - val_loss: 0.2484 - val_accuracy: 0.9499
# Epoch 4/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.2146 - accuracy: 0.9460 - val_loss: 0.1137 - val_accuracy: 0.9527
# Epoch 5/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.3301 - accuracy: 0.8128 - val_loss: 0.5801 - val_accuracy: 0.9259
# Epoch 6/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.7847 - accuracy: 0.9133 - val_loss: 0.5179 - val_accuracy: 0.9284
# Epoch 7/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.3161 - accuracy: 0.9430 - val_loss: 0.7987 - val_accuracy: 0.5727
# Epoch 8/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.4444 - accuracy: 0.7840 - val_loss: 0.3061 - val_accuracy: 0.9346
# Epoch 9/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.3961 - accuracy: 0.9235 - val_loss: 0.3812 - val_accuracy: 0.9290
# Epoch 10/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.3720 - accuracy: 0.9215 - val_loss: 0.2202 - val_accuracy: 0.9355
# Epoch 11/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.1904 - accuracy: 0.9356 - val_loss: 0.1559 - val_accuracy: 0.9707
# Epoch 12/20
# 3/3 [==============================] - 0s 96ms/step - loss: 0.2051 - accuracy: 0.9750 - val_loss: 0.1995 - val_accuracy: 0.9813
# Epoch 13/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.1891 - accuracy: 0.9727 - val_loss: 0.1325 - val_accuracy: 0.9617
# Epoch 14/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.1384 - accuracy: 0.9504 - val_loss: 0.1215 - val_accuracy: 0.9508
# 4/4 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1137 - accuracy: 0.9527
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1260 - accuracy: 0.9462
# Jaccard similarity coefficient with cnn: 0.9999997558937025
# Jaccard similarity coefficient with thresold: 0.4717389526616747
# 0.014655755 0.9998832
# The iteration: 9 is complete
# Epoch 1/20
# 3/3 [==============================] - 1s 150ms/step - loss: 0.6918 - accuracy: 0.4660 - val_loss: 0.6513 - val_accuracy: 0.6718
# Epoch 2/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.6002 - accuracy: 0.6660 - val_loss: 0.5422 - val_accuracy: 0.6451
# Epoch 3/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.4673 - accuracy: 0.7900 - val_loss: 0.3766 - val_accuracy: 0.9561
# Epoch 4/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.2941 - accuracy: 0.9351 - val_loss: 0.1835 - val_accuracy: 0.9823
# Epoch 5/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.1556 - accuracy: 0.9558 - val_loss: 0.1467 - val_accuracy: 0.9691
# Epoch 6/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.1823 - accuracy: 0.9504 - val_loss: 0.0949 - val_accuracy: 0.9606
# Epoch 7/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.1941 - accuracy: 0.9034 - val_loss: 0.2679 - val_accuracy: 0.9426
# Epoch 8/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.3107 - accuracy: 0.9353 - val_loss: 0.0789 - val_accuracy: 0.9661
# Epoch 9/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.1490 - accuracy: 0.9337 - val_loss: 0.0766 - val_accuracy: 0.9671
# Epoch 10/20
# 3/3 [==============================] - 0s 96ms/step - loss: 0.1267 - accuracy: 0.9543 - val_loss: 0.0888 - val_accuracy: 0.9637
# Epoch 11/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0903 - accuracy: 0.9697 - val_loss: 0.0784 - val_accuracy: 0.9809
# Epoch 12/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0772 - accuracy: 0.9733 - val_loss: 0.0784 - val_accuracy: 0.9666
# Epoch 13/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0795 - accuracy: 0.9661 - val_loss: 0.0633 - val_accuracy: 0.9827
# Epoch 14/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0735 - accuracy: 0.9804 - val_loss: 0.0550 - val_accuracy: 0.9779
# Epoch 15/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0699 - accuracy: 0.9700 - val_loss: 0.0584 - val_accuracy: 0.9748
# Epoch 16/20
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0646 - accuracy: 0.9758 - val_loss: 0.0635 - val_accuracy: 0.9825
# Epoch 17/20
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0632 - accuracy: 0.9789 - val_loss: 0.0595 - val_accuracy: 0.9742
# Epoch 18/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0641 - accuracy: 0.9725 - val_loss: 0.0526 - val_accuracy: 0.9835
# Epoch 19/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0595 - accuracy: 0.9809 - val_loss: 0.0514 - val_accuracy: 0.9777
# Epoch 20/20
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0563 - accuracy: 0.9760 - val_loss: 0.0468 - val_accuracy: 0.9836
# 4/4 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0468 - accuracy: 0.9836
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0527 - accuracy: 0.9814
# Jaccard similarity coefficient with cnn: 0.9999995117874049
# Jaccard similarity coefficient with thresold: 0.47213427610486225
# 4.4407596e-05 0.9999918
# The iteration: 10 is complete
# Epoch 1/20
# 3/3 [==============================] - 1s 150ms/step - loss: 0.7138 - accuracy: 0.5625 - val_loss: 0.6889 - val_accuracy: 0.5662
# Epoch 2/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.6325 - accuracy: 0.7808 - val_loss: 0.5362 - val_accuracy: 0.6923
# Epoch 3/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.4920 - accuracy: 0.7347 - val_loss: 0.4057 - val_accuracy: 0.9242
# Epoch 4/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.3535 - accuracy: 0.9325 - val_loss: 0.2189 - val_accuracy: 0.9432
# Epoch 5/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.1900 - accuracy: 0.9456 - val_loss: 0.1020 - val_accuracy: 0.9743
# Epoch 6/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.1231 - accuracy: 0.9550 - val_loss: 0.2082 - val_accuracy: 0.9164
# Epoch 7/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.2285 - accuracy: 0.9292 - val_loss: 0.2507 - val_accuracy: 0.9431
# Epoch 8/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.1892 - accuracy: 0.9471 - val_loss: 0.0540 - val_accuracy: 0.9820
# Epoch 9/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0853 - accuracy: 0.9661 - val_loss: 0.0601 - val_accuracy: 0.9733
# Epoch 10/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0754 - accuracy: 0.9762 - val_loss: 0.0500 - val_accuracy: 0.9793
# Epoch 11/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0698 - accuracy: 0.9699 - val_loss: 0.0470 - val_accuracy: 0.9823
# Epoch 12/20
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0618 - accuracy: 0.9799 - val_loss: 0.0501 - val_accuracy: 0.9783
# Epoch 13/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0588 - accuracy: 0.9743 - val_loss: 0.0492 - val_accuracy: 0.9844
# Epoch 14/20
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0554 - accuracy: 0.9810 - val_loss: 0.0513 - val_accuracy: 0.9777
# Epoch 15/20
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0547 - accuracy: 0.9781 - val_loss: 0.0456 - val_accuracy: 0.9845
# Epoch 16/20
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0507 - accuracy: 0.9802 - val_loss: 0.0418 - val_accuracy: 0.9828
# Epoch 17/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0485 - accuracy: 0.9817 - val_loss: 0.0404 - val_accuracy: 0.9839
# Epoch 18/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0481 - accuracy: 0.9798 - val_loss: 0.0416 - val_accuracy: 0.9848
# Epoch 19/20
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0483 - accuracy: 0.9819 - val_loss: 0.0435 - val_accuracy: 0.9814
# Epoch 20/20
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0480 - accuracy: 0.9804 - val_loss: 0.0421 - val_accuracy: 0.9845
# 4/4 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0421 - accuracy: 0.9845
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0477 - accuracy: 0.9825
# Jaccard similarity coefficient with cnn: 0.9999992676811074
# Jaccard similarity coefficient with thresold: 0.47269412750608863
# 2.891929e-06 0.9999999
# The iteration: 11 is complete
# Epoch 1/20
# 3/3 [==============================] - 1s 150ms/step - loss: 0.6762 - accuracy: 0.6442 - val_loss: 0.5972 - val_accuracy: 0.4357
# Epoch 2/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.5451 - accuracy: 0.5492 - val_loss: 0.4701 - val_accuracy: 0.9327
# Epoch 3/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.3961 - accuracy: 0.9237 - val_loss: 0.2504 - val_accuracy: 0.9504
# Epoch 4/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.2019 - accuracy: 0.9489 - val_loss: 0.0867 - val_accuracy: 0.9728
# Epoch 5/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.1992 - accuracy: 0.9504 - val_loss: 0.5091 - val_accuracy: 0.9300
# Epoch 6/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.3948 - accuracy: 0.9335 - val_loss: 0.5130 - val_accuracy: 0.6699
# Epoch 7/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.2978 - accuracy: 0.8450 - val_loss: 0.3835 - val_accuracy: 0.9363
# Epoch 8/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.4164 - accuracy: 0.9302 - val_loss: 0.1830 - val_accuracy: 0.9480
# Epoch 9/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.1841 - accuracy: 0.9363 - val_loss: 0.1417 - val_accuracy: 0.9627
# Epoch 10/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.1202 - accuracy: 0.9604 - val_loss: 0.1411 - val_accuracy: 0.9516
# Epoch 11/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.1675 - accuracy: 0.9446 - val_loss: 0.1047 - val_accuracy: 0.9575
# Epoch 12/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0993 - accuracy: 0.9618 - val_loss: 0.1124 - val_accuracy: 0.9808
# Epoch 13/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.1210 - accuracy: 0.9781 - val_loss: 0.0697 - val_accuracy: 0.9746
# Epoch 14/20
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0930 - accuracy: 0.9615 - val_loss: 0.0911 - val_accuracy: 0.9619
# Epoch 15/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0956 - accuracy: 0.9595 - val_loss: 0.0625 - val_accuracy: 0.9793
# Epoch 16/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0847 - accuracy: 0.9780 - val_loss: 0.0601 - val_accuracy: 0.9822
# Epoch 17/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0705 - accuracy: 0.9736 - val_loss: 0.0616 - val_accuracy: 0.9740
# Epoch 18/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0658 - accuracy: 0.9726 - val_loss: 0.0523 - val_accuracy: 0.9834
# Epoch 19/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.0617 - accuracy: 0.9807 - val_loss: 0.0468 - val_accuracy: 0.9827
# Epoch 20/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0563 - accuracy: 0.9770 - val_loss: 0.0444 - val_accuracy: 0.9824
# 4/4 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0444 - accuracy: 0.9824
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0522 - accuracy: 0.9788
# Jaccard similarity coefficient with cnn: 0.9999997558937025
# Jaccard similarity coefficient with thresold: 0.47351531462258106
# 1.2600827e-05 0.9999852
# The iteration: 12 is complete
# Epoch 1/20
# 3/3 [==============================] - 1s 152ms/step - loss: 0.7002 - accuracy: 0.5054 - val_loss: 0.6479 - val_accuracy: 0.9426
# Epoch 2/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.5737 - accuracy: 0.8007 - val_loss: 0.5031 - val_accuracy: 0.6847
# Epoch 3/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.4372 - accuracy: 0.8454 - val_loss: 0.3527 - val_accuracy: 0.9556
# Epoch 4/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.2708 - accuracy: 0.9430 - val_loss: 0.1351 - val_accuracy: 0.9747
# Epoch 5/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.1108 - accuracy: 0.9648 - val_loss: 0.1015 - val_accuracy: 0.9800
# Epoch 6/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.2430 - accuracy: 0.9544 - val_loss: 0.2559 - val_accuracy: 0.9457
# Epoch 7/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.5844 - accuracy: 0.7797 - val_loss: 0.1320 - val_accuracy: 0.9593
# Epoch 8/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.5410 - accuracy: 0.9363 - val_loss: 1.0554 - val_accuracy: 0.9241
# Epoch 9/20
# 3/3 [==============================] - 0s 97ms/step - loss: 1.1913 - accuracy: 0.9158 - val_loss: 0.9028 - val_accuracy: 0.9241
# Epoch 10/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.8122 - accuracy: 0.9200 - val_loss: 0.3553 - val_accuracy: 0.9345
# Epoch 11/20
# 3/3 [==============================] - 0s 96ms/step - loss: 0.2358 - accuracy: 0.9395 - val_loss: 0.1200 - val_accuracy: 0.9822
# Epoch 12/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.2813 - accuracy: 0.8686 - val_loss: 0.2087 - val_accuracy: 0.9651
# Epoch 13/20
# 3/3 [==============================] - 0s 96ms/step - loss: 0.1654 - accuracy: 0.9668 - val_loss: 0.0987 - val_accuracy: 0.9622
# Epoch 14/20
# 3/3 [==============================] - 0s 96ms/step - loss: 0.1189 - accuracy: 0.9517 - val_loss: 0.1095 - val_accuracy: 0.9539
# Epoch 15/20
# 3/3 [==============================] - 0s 96ms/step - loss: 0.1190 - accuracy: 0.9506 - val_loss: 0.0945 - val_accuracy: 0.9697
# Epoch 16/20
# 3/3 [==============================] - 0s 96ms/step - loss: 0.1051 - accuracy: 0.9688 - val_loss: 0.0771 - val_accuracy: 0.9727
# Epoch 17/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0856 - accuracy: 0.9663 - val_loss: 0.0652 - val_accuracy: 0.9778
# Epoch 18/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0757 - accuracy: 0.9750 - val_loss: 0.0605 - val_accuracy: 0.9758
# Epoch 19/20
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0706 - accuracy: 0.9705 - val_loss: 0.0583 - val_accuracy: 0.9825
# Epoch 20/20
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0660 - accuracy: 0.9773 - val_loss: 0.0536 - val_accuracy: 0.9783
# 4/4 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0536 - accuracy: 0.9783
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0639 - accuracy: 0.9733
# Jaccard similarity coefficient with cnn: 0.9999985353622147
# Jaccard similarity coefficient with thresold: 0.4743031365264111
# 0.00013859436 0.99997365
# The iteration: 13 is complete
# Epoch 1/20
# 3/3 [==============================] - 1s 150ms/step - loss: 0.6748 - accuracy: 0.5809 - val_loss: 0.5416 - val_accuracy: 0.6633
# Epoch 2/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.5866 - accuracy: 0.8931 - val_loss: 0.5142 - val_accuracy: 0.9363
# Epoch 3/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.4423 - accuracy: 0.9235 - val_loss: 0.3120 - val_accuracy: 0.9261
# Epoch 4/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.2503 - accuracy: 0.9455 - val_loss: 0.1306 - val_accuracy: 0.9462
# Epoch 5/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.1316 - accuracy: 0.9555 - val_loss: 0.0592 - val_accuracy: 0.9745
# Epoch 6/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0626 - accuracy: 0.9762 - val_loss: 0.0610 - val_accuracy: 0.9739
# Epoch 7/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.1514 - accuracy: 0.9573 - val_loss: 0.2387 - val_accuracy: 0.9527
# Epoch 8/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.4678 - accuracy: 0.8228 - val_loss: 0.2745 - val_accuracy: 0.9509
# Epoch 9/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.7712 - accuracy: 0.9289 - val_loss: 1.2031 - val_accuracy: 0.9210
# Epoch 10/20
# 3/3 [==============================] - 0s 97ms/step - loss: 1.3409 - accuracy: 0.8905 - val_loss: 0.9594 - val_accuracy: 0.9171
# Epoch 11/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.8172 - accuracy: 0.9115 - val_loss: 0.3457 - val_accuracy: 0.9272
# Epoch 12/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.2648 - accuracy: 0.9262 - val_loss: 0.1338 - val_accuracy: 0.9442
# Epoch 13/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.2023 - accuracy: 0.9507 - val_loss: 0.2783 - val_accuracy: 0.9824
# Epoch 14/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.3301 - accuracy: 0.9627 - val_loss: 0.3127 - val_accuracy: 0.9429
# Epoch 15/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.3468 - accuracy: 0.9503 - val_loss: 0.2918 - val_accuracy: 0.9834
# 4/4 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0592 - accuracy: 0.9745
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0701 - accuracy: 0.9696
# Jaccard similarity coefficient with cnn: 0.9999995117874049
# Jaccard similarity coefficient with thresold: 0.475077955384182
# 8.143339e-05 0.99993086
# The iteration: 14 is complete
# Epoch 1/20
# 3/3 [==============================] - 1s 150ms/step - loss: 0.6542 - accuracy: 0.4918 - val_loss: 0.6686 - val_accuracy: 0.5807
# Epoch 2/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.5811 - accuracy: 0.6303 - val_loss: 0.5026 - val_accuracy: 0.6917
# Epoch 3/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.4289 - accuracy: 0.8754 - val_loss: 0.3608 - val_accuracy: 0.9450
# Epoch 4/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.2993 - accuracy: 0.9471 - val_loss: 0.1682 - val_accuracy: 0.9525
# Epoch 5/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.1464 - accuracy: 0.9629 - val_loss: 0.2564 - val_accuracy: 0.9404
# Epoch 6/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.2627 - accuracy: 0.9398 - val_loss: 0.7298 - val_accuracy: 0.5919
# Epoch 7/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.4727 - accuracy: 0.8162 - val_loss: 0.6684 - val_accuracy: 0.9284
# Epoch 8/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.7224 - accuracy: 0.9244 - val_loss: 0.3782 - val_accuracy: 0.9366
# Epoch 9/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.2171 - accuracy: 0.9554 - val_loss: 0.3728 - val_accuracy: 0.7658
# Epoch 10/20
# ...
# Epoch 15/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0625 - accuracy: 0.9760 - val_loss: 0.0585 - val_accuracy: 0.9744
# Epoch 16/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.0620 - accuracy: 0.9755 - val_loss: 0.0552 - val_accuracy: 0.9761
# Epoch 17/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0623 - accuracy: 0.9750 - val_loss: 0.0499 - val_accuracy: 0.9794
# Epoch 18/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0562 - accuracy: 0.9769 - val_loss: 0.0491 - val_accuracy: 0.9812
# Epoch 19/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0549 - accuracy: 0.9777 - val_loss: 0.0522 - val_accuracy: 0.9804
# Epoch 20/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0577 - accuracy: 0.9765 - val_loss: 0.0605 - val_accuracy: 0.9772
# 4/4 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0605 - accuracy: 0.9772
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0694 - accuracy: 0.9750
# Jaccard similarity coefficient with cnn: 0.9999997558937025
# Jaccard similarity coefficient with thresold: 0.4689205006621385
# 9.8168954e-08 0.99999976
# The iteration: 3099 is complete
# Epoch 1/20
# 3/3 [==============================] - 1s 157ms/step - loss: 0.6201 - accuracy: 0.6490 - val_loss: 0.5397 - val_accuracy: 0.6417
# Epoch 2/20
# 3/3 [==============================] - 0s 103ms/step - loss: 0.4777 - accuracy: 0.7895 - val_loss: 0.5060 - val_accuracy: 0.9778
# Epoch 3/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.3945 - accuracy: 0.9416 - val_loss: 0.2588 - val_accuracy: 0.9330
# Epoch 4/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.1985 - accuracy: 0.9569 - val_loss: 0.1494 - val_accuracy: 0.9446
# Epoch 5/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.1690 - accuracy: 0.9376 - val_loss: 0.2702 - val_accuracy: 0.9375
# Epoch 6/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.4141 - accuracy: 0.9306 - val_loss: 0.3270 - val_accuracy: 0.9345
# Epoch 7/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.2522 - accuracy: 0.9236 - val_loss: 0.1261 - val_accuracy: 0.9771
# Epoch 8/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.1264 - accuracy: 0.9583 - val_loss: 0.1447 - val_accuracy: 0.9462
# Epoch 9/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.1264 - accuracy: 0.9491 - val_loss: 0.1091 - val_accuracy: 0.9775
# Epoch 10/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.1152 - accuracy: 0.9728 - val_loss: 0.0961 - val_accuracy: 0.9564
# Epoch 11/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.1050 - accuracy: 0.9534 - val_loss: 0.0842 - val_accuracy: 0.9625
# Epoch 12/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0915 - accuracy: 0.9694 - val_loss: 0.0760 - val_accuracy: 0.9757
# Epoch 13/20
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0832 - accuracy: 0.9664 - val_loss: 0.0713 - val_accuracy: 0.9681
# Epoch 14/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0748 - accuracy: 0.9725 - val_loss: 0.0632 - val_accuracy: 0.9779
# Epoch 15/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0710 - accuracy: 0.9721 - val_loss: 0.0607 - val_accuracy: 0.9733
# Epoch 16/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0635 - accuracy: 0.9771 - val_loss: 0.0527 - val_accuracy: 0.9794
# Epoch 17/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0576 - accuracy: 0.9766 - val_loss: 0.0492 - val_accuracy: 0.9809
# Epoch 18/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0535 - accuracy: 0.9797 - val_loss: 0.0484 - val_accuracy: 0.9793
# Epoch 19/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0513 - accuracy: 0.9796 - val_loss: 0.0450 - val_accuracy: 0.9810
# Epoch 20/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0487 - accuracy: 0.9800 - val_loss: 0.0444 - val_accuracy: 0.9818
# 4/4 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0444 - accuracy: 0.9818
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0485 - accuracy: 0.9808
# Jaccard similarity coefficient with cnn: 0.9999997558937025
# Jaccard similarity coefficient with thresold: 0.47426032722457173
# 3.0180992e-08 0.9999988
# The iteration: 3100 is complete
# Epoch 1/20
# 3/3 [==============================] - 1s 153ms/step - loss: 0.6912 - accuracy: 0.4791 - val_loss: 0.6458 - val_accuracy: 0.9141
# Epoch 2/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.6048 - accuracy: 0.8873 - val_loss: 0.5311 - val_accuracy: 0.6434
# Epoch 3/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.4654 - accuracy: 0.7958 - val_loss: 0.3585 - val_accuracy: 0.9343
# Epoch 4/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.3098 - accuracy: 0.9404 - val_loss: 0.2432 - val_accuracy: 0.9322
# Epoch 5/20
# 3/3 [==============================] - 0s 103ms/step - loss: 0.2734 - accuracy: 0.8387 - val_loss: 0.1710 - val_accuracy: 0.9423
# Epoch 6/20
# 3/3 [==============================] - 0s 104ms/step - loss: 0.3613 - accuracy: 0.9298 - val_loss: 0.4460 - val_accuracy: 0.9260
# Epoch 7/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.3242 - accuracy: 0.9319 - val_loss: 0.0979 - val_accuracy: 0.9737
# Epoch 8/20
# 3/3 [==============================] - 0s 104ms/step - loss: 0.2081 - accuracy: 0.9083 - val_loss: 0.1086 - val_accuracy: 0.9529
# Epoch 9/20
# 3/3 [==============================] - 0s 103ms/step - loss: 0.1659 - accuracy: 0.9405 - val_loss: 0.2005 - val_accuracy: 0.9358
# Epoch 10/20
# 3/3 [==============================] - 0s 103ms/step - loss: 0.1881 - accuracy: 0.9349 - val_loss: 0.1252 - val_accuracy: 0.9460
# Epoch 11/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.1388 - accuracy: 0.9527 - val_loss: 0.1476 - val_accuracy: 0.9698
# Epoch 12/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.1505 - accuracy: 0.9639 - val_loss: 0.1120 - val_accuracy: 0.9540
# Epoch 13/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.1216 - accuracy: 0.9482 - val_loss: 0.1163 - val_accuracy: 0.9487
# Epoch 14/20
# 3/3 [==============================] - 0s 103ms/step - loss: 0.1159 - accuracy: 0.9485 - val_loss: 0.0922 - val_accuracy: 0.9608
# Epoch 15/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.1026 - accuracy: 0.9668 - val_loss: 0.0878 - val_accuracy: 0.9725
# Epoch 16/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0919 - accuracy: 0.9668 - val_loss: 0.0815 - val_accuracy: 0.9640
# Epoch 17/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0801 - accuracy: 0.9666 - val_loss: 0.0644 - val_accuracy: 0.9797
# Epoch 18/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0699 - accuracy: 0.9790 - val_loss: 0.0679 - val_accuracy: 0.9709
# Epoch 19/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.0667 - accuracy: 0.9724 - val_loss: 0.0610 - val_accuracy: 0.9796
# Epoch 20/20
# 3/3 [==============================] - 0s 105ms/step - loss: 0.0616 - accuracy: 0.9773 - val_loss: 0.0567 - val_accuracy: 0.9756
# 4/4 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0567 - accuracy: 0.9756
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0607 - accuracy: 0.9742
# Jaccard similarity coefficient with cnn: 0.9999990235748097
# Jaccard similarity coefficient with thresold: 0.47386131624197014
# 3.6849616e-07 0.99999356
# The iteration: 3101 is complete
# Epoch 1/20
# 3/3 [==============================] - 1s 155ms/step - loss: 0.6491 - accuracy: 0.5588 - val_loss: 0.6169 - val_accuracy: 0.9221
# Epoch 2/20
# 3/3 [==============================] - 0s 103ms/step - loss: 0.5528 - accuracy: 0.8562 - val_loss: 0.5046 - val_accuracy: 0.6909
# Epoch 3/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.3973 - accuracy: 0.8777 - val_loss: 0.2732 - val_accuracy: 0.9567
# Epoch 4/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.2681 - accuracy: 0.9374 - val_loss: 0.1120 - val_accuracy: 0.9554
# Epoch 5/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.3403 - accuracy: 0.8132 - val_loss: 0.4768 - val_accuracy: 0.9231
# Epoch 6/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.6200 - accuracy: 0.9194 - val_loss: 0.5411 - val_accuracy: 0.9196
# Epoch 7/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.3909 - accuracy: 0.9246 - val_loss: 0.1249 - val_accuracy: 0.9515
# Epoch 8/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.2414 - accuracy: 0.9227 - val_loss: 0.2623 - val_accuracy: 0.9521
# Epoch 9/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.2013 - accuracy: 0.9563 - val_loss: 0.1374 - val_accuracy: 0.9430
# Epoch 10/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.1740 - accuracy: 0.9347 - val_loss: 0.1952 - val_accuracy: 0.9335
# Epoch 11/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.1928 - accuracy: 0.9321 - val_loss: 0.1436 - val_accuracy: 0.9411
# Epoch 12/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.1377 - accuracy: 0.9446 - val_loss: 0.1246 - val_accuracy: 0.9664
# Epoch 13/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.1481 - accuracy: 0.9701 - val_loss: 0.1169 - val_accuracy: 0.9724
# Epoch 14/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.1164 - accuracy: 0.9629 - val_loss: 0.1043 - val_accuracy: 0.9553
# Epoch 15/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.1051 - accuracy: 0.9549 - val_loss: 0.0747 - val_accuracy: 0.9726
# Epoch 16/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0875 - accuracy: 0.9747 - val_loss: 0.0691 - val_accuracy: 0.9728
# Epoch 17/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0798 - accuracy: 0.9664 - val_loss: 0.0664 - val_accuracy: 0.9714
# Epoch 18/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0736 - accuracy: 0.9748 - val_loss: 0.0607 - val_accuracy: 0.9794
# Epoch 19/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0690 - accuracy: 0.9730 - val_loss: 0.0606 - val_accuracy: 0.9736
# Epoch 20/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0659 - accuracy: 0.9762 - val_loss: 0.0528 - val_accuracy: 0.9793
# 4/4 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0528 - accuracy: 0.9793
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0584 - accuracy: 0.9781
# Jaccard similarity coefficient with cnn: 0.9999995117874049
# Jaccard similarity coefficient with thresold: 0.47334187054841437
# 3.795092e-07 0.99997973
# The iteration: 3102 is complete
# Epoch 1/20
# 3/3 [==============================] - 1s 163ms/step - loss: 0.6225 - accuracy: 0.6094 - val_loss: 0.5923 - val_accuracy: 0.9208
# Epoch 2/20
# 3/3 [==============================] - 0s 103ms/step - loss: 0.5256 - accuracy: 0.8110 - val_loss: 0.4142 - val_accuracy: 0.9234
# Epoch 3/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.3457 - accuracy: 0.9386 - val_loss: 0.2196 - val_accuracy: 0.9375
# Epoch 4/20
# 3/3 [==============================] - 0s 104ms/step - loss: 0.1590 - accuracy: 0.9516 - val_loss: 0.0850 - val_accuracy: 0.9633
# Epoch 5/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.1658 - accuracy: 0.9581 - val_loss: 0.1075 - val_accuracy: 0.9589
# Epoch 6/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.5242 - accuracy: 0.8181 - val_loss: 0.7465 - val_accuracy: 0.9264
# Epoch 7/20
# 3/3 [==============================] - 0s 101ms/step - loss: 1.0023 - accuracy: 0.9216 - val_loss: 1.0818 - val_accuracy: 0.9180
# Epoch 8/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.9281 - accuracy: 0.9191 - val_loss: 0.4813 - val_accuracy: 0.9257
# Epoch 9/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.3278 - accuracy: 0.9306 - val_loss: 0.1102 - val_accuracy: 0.9594
# Epoch 10/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.2261 - accuracy: 0.9268 - val_loss: 0.3252 - val_accuracy: 0.8048
# Epoch 11/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.3085 - accuracy: 0.8898 - val_loss: 0.1807 - val_accuracy: 0.9652
# Epoch 12/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.1769 - accuracy: 0.9498 - val_loss: 0.1519 - val_accuracy: 0.9407
# Epoch 13/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.1701 - accuracy: 0.9331 - val_loss: 0.1798 - val_accuracy: 0.9316
# Epoch 14/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.1937 - accuracy: 0.9284 - val_loss: 0.1881 - val_accuracy: 0.9299
# 4/4 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0850 - accuracy: 0.9633
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0933 - accuracy: 0.9597
# Jaccard similarity coefficient with cnn: 0.9999997558937025
# Jaccard similarity coefficient with thresold: 0.47326242043658423
# 0.0032377895 0.9999527
# The iteration: 3103 is complete
# Epoch 1/20
# 3/3 [==============================] - 1s 152ms/step - loss: 0.6846 - accuracy: 0.4656 - val_loss: 0.6430 - val_accuracy: 0.4352
# Epoch 2/20
# 3/3 [==============================] - 0s 102ms/step - loss: 0.6195 - accuracy: 0.7186 - val_loss: 0.5503 - val_accuracy: 0.7658
# Epoch 3/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.4923 - accuracy: 0.7819 - val_loss: 0.3735 - val_accuracy: 0.9270
# Epoch 4/20
# 3/3 [==============================] - 0s 103ms/step - loss: 0.3198 - accuracy: 0.9351 - val_loss: 0.2222 - val_accuracy: 0.9358
# Epoch 5/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.1870 - accuracy: 0.9540 - val_loss: 0.1972 - val_accuracy: 0.9393
# Epoch 6/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.1943 - accuracy: 0.9401 - val_loss: 0.5668 - val_accuracy: 0.5960
# Epoch 7/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.3490 - accuracy: 0.8329 - val_loss: 0.4244 - val_accuracy: 0.9306
# Epoch 8/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.3867 - accuracy: 0.9310 - val_loss: 0.0973 - val_accuracy: 0.9589
# Epoch 9/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.1795 - accuracy: 0.9304 - val_loss: 0.0747 - val_accuracy: 0.9697
# Epoch 10/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.1397 - accuracy: 0.9527 - val_loss: 0.1961 - val_accuracy: 0.9459
# Epoch 11/20
# 3/3 [==============================] - 0s 100ms/step - loss: 0.1659 - accuracy: 0.9462 - val_loss: 0.0750 - val_accuracy: 0.9753
# Epoch 12/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.1310 - accuracy: 0.9675 - val_loss: 0.0733 - val_accuracy: 0.9727
# Epoch 13/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.1102 - accuracy: 0.9583 - val_loss: 0.1285 - val_accuracy: 0.9543
# Epoch 14/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.1138 - accuracy: 0.9554 - val_loss: 0.0763 - val_accuracy: 0.9787
# Epoch 15/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.1000 - accuracy: 0.9769 - val_loss: 0.0695 - val_accuracy: 0.9746
# Epoch 16/20
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0835 - accuracy: 0.9658 - val_loss: 0.0825 - val_accuracy: 0.9650
# Epoch 17/20
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0803 - accuracy: 0.9670 - val_loss: 0.0687 - val_accuracy: 0.9790
# Epoch 18/20
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0782 - accuracy: 0.9784 - val_loss: 0.0634 - val_accuracy: 0.9767
# Epoch 19/20
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0725 - accuracy: 0.9706 - val_loss: 0.0658 - val_accuracy: 0.9720
# Epoch 20/20
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0813 - accuracy: 0.9656

# %%
# Calcular os minutos a partir da parte decimal do tempo decorrido em horas
elapsed_minutes = (elapsed_time_hours - int(elapsed_time_hours)) * 60

print("Time elapsed:", int(elapsed_time_hours), "hours and", round(elapsed_minutes), "minutes")
# Out:
# Time elapsed: 5 hours and 31 minutes

# %%
ac_train[0], ac_test[0], loss_train[0], loss_test[0]
# Out:
# (0.9833083152770996,
#  0.9852315783500671,
#  0.03983570262789726,
#  0.03520595654845238)

# %%
porosity_vector_values.min()
# Out:
# 0.01602614608396591

# %%
porosity_vector_values[0]

# %%
porosity_vector_values[3120]

# %%
len(porosity_vector_values)

# %%
porosity_vector_values.min(), porosity_vector_values.max()

# %%
# Calculating the distance between the pixels in each direction:
# In the real world we have 1704 pixels in a diameter with 3.81 cm
value_pixel_real_world=(3.81)/(1704) # Simple rule
# Calculating the distance of the width and height in mm
image_width_cm = (2024 * value_pixel_real_world)
image_height_cm = (2024 * value_pixel_real_world)
image_width_m = image_width_cm * (10)**(-2)
image_height_m = image_height_cm * (10)**(-2)
# Calculating the total area in meters:
total_check_real_area = (image_width_m) * (image_height_m)
# Calculate the total number of pixels in the image
total_pixels_horizontal = 2024
total_pixels_vertical = 2024
total_pixels = total_pixels_horizontal * total_pixels_vertical

# %%
image_width_m, image_height_m
# Out:
# (0.045254929577464784, 0.045254929577464784)

# %%
# Define the dimensions of the image in meters
image_width_meters = image_width_m  # example width of the image in meters
image_height_meters = image_height_m  # example height of the image in meters

# Calculate the number of pixels in each direction
number_of_pixels_in_each_direction = total_pixels_horizontal  # Assuming y_pred is your prediction array

# Calculate the distance between pixels in meters
pixel_distance_horizontal = image_width_meters / (number_of_pixels_in_each_direction - 1)
pixel_distance_vertical = image_height_meters / (number_of_pixels_in_each_direction - 1)

# Calculate the total area
total_area = image_width_meters * image_height_meters

# Print the results
print("Distance between pixels horizontally:", pixel_distance_horizontal, "meters")
print("Distance between pixels vertically:", pixel_distance_vertical, "meters")
print("Total Area:", total_area, "square meters")
# Out:
# Distance between pixels horizontally: 2.2370207403591095e-05 meters
# Distance between pixels vertically: 2.2370207403591095e-05 meters
# Total Area: 0.002048008651061297 square meters

# %%
# Checking if the area formed by the distance between the pixels is less than the total area.
pixel_distance_horizontal * pixel_distance_vertical  < total_area
# Out:
# True

# %%
# There are two ways to define the dz to the riemann integral:
# The first way
# comp_z = number_of_crooped_images * mean of the distance between pixels
length_z = 7.36*10**(-2)


# Checking the dz
dz1 = length_z/3121.

dz2 = value_pixel_real_world+pixel_distance_horizontal
dz1, dz2
# A razão de aspecto do pixel é 1, então o diametro é de uma esfera.
# dz1 - intervalo do slice baseado nos intervalos entre os slices no valor real.
# dz2 - intervalo do slice baseado no diametro do pixel na transformação de escala para o real.
# Out:
# (2.3582185197052225e-05, 0.0022582857003613376)

# %% [markdown]
# ## Calculating the 3d properties by using the riemann integral

# %%
porosity_vector_values.min(), porosity_vector_values.max()
# Out:
# (-0.023507969560063513, 0.5735124055973941)

# %%
porosity_vector_values[2201], porosity_vector_values[3120]
# Out:
# (0.17736829541101606, 0.17438586515856003)

# %%
porosity_vector_values[2200], Grain_fraction_vector_values[2200]
# Out:
# (0.15217677820006004, 0.84782322179994)

# %%
def riemann_integral_L_porosity(porosity_values, slice_thickness):
    total_porosity = sum(porosity_values)
    integral_approximation = total_porosity * slice_thickness 
    return integral_approximation

# %%
def riemann_integral_L_fraction_grain(fraction_grain_values, slice_thickness):
    total_fraction_grain = sum(fraction_grain_values) 
    integral_approximation = total_fraction_grain * slice_thickness 
    return integral_approximation

# %%
def riemann_integral_L_pore_area(pore_area_values, slice_thickness):
    total_pore_area = sum(pore_area_values)
    integral_approximation = total_pore_area * slice_thickness
    return integral_approximation

# %%
def riemann_integral_L_grain_area(grain_area_values, slice_thickness):
    total_grain_area = sum(grain_area_values)
    integral_approximation = total_grain_area * slice_thickness
    return integral_approximation

# %%
length_z
# Out:
# 0.0736

# %%
## side Area of  cylinder
r = value_pixel_real_world/2
side_area = 2 * 3.1415 * r * length_z

# %%
delta_side_area = side_area/3121
delta_side_area_percentage = (delta_side_area * 100.0) / side_area
delta_side_area, side_area, delta_side_area_percentage
# Out:
# (1.6564429963310786e-07, 0.0005169758591549296, 0.03204101249599488)

# %%
# In the case of porosity and grain fraction, the integral is supposed to be in percentage, wich means that
# we need to covnert the interval "H" and the range of riemman integral both in percentage

# Example porosity values (vector representing porosity values at discrete depths)
# Example porosity values at different }depths
# The "H" of the reimann integral

slice_thickness =  dz1 # meters 

##Slice_thickness = pixel_distance_horizontal * (10**(-2))
##slice_thickness_percentage = (100.0 * slice_thickness)/(length_z) # based on the length
slice_thickness_percentage = delta_side_area_percentage # Based on the side area

# Compute Riemann integral approximation for porosity over the depth of the rock
integral_approximation_porosity = riemann_integral_L_porosity(porosity_vector_values, slice_thickness_percentage)

print("Riemann integral approximation for porosity in 3D to the sample IL033:", integral_approximation_porosity, "%")
# Out:
# Riemann integral approximation for porosity in 3D to the sample IL033: 16.242983217188634 %

# %%
porosity_vector_values.min(), porosity_vector_values.max()
# Out:
# (-0.023507969560063513, 0.5735124055973941)

# %%
porosity_vector_values[0]
# Out:
# 0.1942276816666858

# %%
import numpy as np

# Assuming porosity_vector_values is a NumPy array
# Find the minimum value and its index
min_value = np.min(porosity_vector_values)
min_position = np.argmin(porosity_vector_values)

print("Minimum value:", min_value)
print("Position of minimum value:", min_position)
# Out:
# Minimum value: -0.023507969560063513
# Position of minimum value: 1586

# %%
import numpy as np

# Assuming porosity_vector_values is a NumPy array
# Find the minimum value and its index
max_value = np.max(porosity_vector_values)
max_position = np.argmax(porosity_vector_values)

print("Maximun value:", max_value)
print("Position of Maximun value:", max_position)
# Out:
# Maximun value: 0.5735124055973941
# Position of Maximun value: 2523

# %%
slice_number = max_position+330-1
slice_number
# Out:
# 2852

# %%
slice_thickness_percentage
# Out:
# 0.03204101249599488

# %%
# The "H" of the reimann integral
##slice_thickness = (pixel_distance_horizontal + pixel_distance_vertical) / 2  # meters 

# Compute Riemann integral approximation for porosity over the depth of the rock
integral_approximation_grain_fraction = riemann_integral_L_fraction_grain(Grain_fraction_vector_values, slice_thickness_percentage)

print("Riemann integral approximation for grain fraction in 3D over length:", integral_approximation_grain_fraction, "%")
# Out:
# Riemann integral approximation for grain fraction in 3D over length: 83.75701678281158 %

# %%
integral_approximation_porosity + integral_approximation_grain_fraction
# Out:
# 100.00000000000021

# %%
# Compute Riemann integral approximation for porosity over the depth of the rock
integral_approximation_pore_volume = riemann_integral_L_pore_area(pore_Area_vector_values, slice_thickness)

print("Riemann integral approximation for pore_volume:", integral_approximation_pore_volume,"m^3")
# Out:
# Riemann integral approximation for pore_volume: 1.383417986790989e-05 m^3

# %%
pore_Area_vector_values[1], Grain_Area_vector_values[1]
# Out:
# (0.00019286467874535902, 0.0009711936539206628)

# %%
# Compute Riemann integral approximation for porosity over the depth of the rock
integral_approximation_grain_volume = riemann_integral_L_grain_area(Grain_Area_vector_values, slice_thickness)

print("Riemann integral approximation for grain_volume:", integral_approximation_grain_volume, "m^3")
# Out:
# Riemann integral approximation for grain_volume: 7.133383523564125e-05 m^3

# %%
vol_sample = 3.1415 * ((3.81/2)*10**(-2))**2 * length_z #

# %%
total_volu = integral_approximation_pore_volume + integral_approximation_grain_volume
total_volu = total_volu * 10**(6)
print('Checando o volume total da amostra (aproximado)',total_volu, vol_sample * 10**(6),'cm^3')
# Out:
# Checando o volume total da amostra (aproximado) 85.16801510355114 83.90828379600002

# %%
percentual_variation = ((total_volu - vol_sample)*100.0)/vol_sample

# %%
# priting the error
print('the error in relation to the volume of the sample is:',percentual_variation,'%')
# Out:
# the error in relation to the volume of the sample is: 1.5013193579477933 %

# %%
## Calculating the porosity from the volume grain and pore:
#total_volu
#integral_approximation_grain_volume
grain_frac = (integral_approximation_grain_volume * 100)/total_volu
grain_frac
# Out:
# 83.75660175819564

# %% [markdown]
# ### Graphic of the 2d variation properties

# %%
import matplotlib.pyplot as plt
import numpy as np

# Ajustar o tamanho da figura
plt.figure(figsize=(12, 6))  # Largura = 18 polegadas, Altura = 6 polegadas

# Plot
plt.plot(np.arange(len(Grain_fraction_vector_values)), abs(Grain_fraction_vector_values))
plt.xlabel('Índice', fontsize=22)
plt.ylabel('Valores de fração de grão (%)',fontsize=22)
plt.title('Valores de fração de grão (%) vs. Índice',fontsize=22)

# Calculate statistics
mean_value = Grain_fraction_vector_values.mean()
max_value = Grain_fraction_vector_values.max()
min_value = Grain_fraction_vector_values.min()

# Round the statistics to four decimal places
mean_value = round(mean_value, 4)
max_value = round(max_value, 4)
min_value = round(min_value, 4)

# Draw lines for mean, max, and min
plt.axhline(y=mean_value, color='r', linestyle='--', label=f'Mean: {mean_value}')
plt.axhline(y=max_value, color='g', linestyle='--', label=f'Max: {max_value}')
plt.axhline(y=min_value, color='b', linestyle='--', label=f'Min: {min_value}')
plt.legend(fontsize=22)  # Define o tamanho da fonte para a legenda

plt.xticks(fontsize=22)  # Define o tamanho da fonte para os números no eixo x
plt.yticks(fontsize=22)  # Define o tamanho da fonte para os números no eixo y

plt.grid(True)

# Save the plot as PNG
plt.savefig('TheCNNresults\Grain_fraction_cnn_plot.png')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Ajustar o tamanho da figura
plt.figure(figsize=(12, 6))  # Largura = 18 polegadas, Altura = 6 polegadas

# Plot
plt.plot(np.arange(len(porosity_vector_values)), abs(porosity_vector_values))
plt.xlabel('Índice', fontsize=22)
plt.ylabel('Valores de Porosidade (%)',fontsize=22)
plt.title('Valores de Porosidade (%) vs. Índice',fontsize=22)

# Calculate statistics
mean_value = porosity_vector_values.mean()
max_value = porosity_vector_values.max()
min_value = porosity_vector_values.min()

# Round the statistics to four decimal places
mean_value = round(mean_value, 4)
max_value = round(max_value, 4)
min_value = round(min_value, 4)

# Draw lines for mean, max, and min
plt.axhline(y=mean_value, color='r', linestyle='--', label=f'Mean: {mean_value}')
plt.axhline(y=max_value, color='g', linestyle='--', label=f'Max: {max_value}')
plt.axhline(y=min_value, color='b', linestyle='--', label=f'Min: {min_value}')
plt.legend(fontsize=22)  # Define o tamanho da fonte para a legenda

plt.xticks(fontsize=22)  # Define o tamanho da fonte para os números no eixo x
plt.yticks(fontsize=22)  # Define o tamanho da fonte para os números no eixo y

plt.grid(True)

# Save the plot as PNG
plt.savefig('TheCNNresults\porosity_cnn_plot.png')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

# Dados de exemplo (valores de porosidade)
# porosity_vector_values = np.random.normal(loc=mean_value, scale=std_value, size=1000)

# Ajustar o tamanho da figura
plt.figure(figsize=(12, 6))

# Plot da distribuição normal
plt.hist(porosity_vector_values, bins=30, density=True, alpha=0.6, color='g')

# Obter os parâmetros da distribuição normal
mu, std = norm.fit(porosity_vector_values)

# Calcular a PDF da distribuição normal
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)

# Plot da PDF da distribuição normal
plt.plot(x, p, 'k', linewidth=2)

# Adicionar legendas e rótulos
plt.title('Distribuição Normal dos Valores de Porosidade', fontsize=22)
plt.xlabel('Valores de Porosidade (%)', fontsize=22)
plt.ylabel('Densidade de Probabilidade', fontsize=22)
plt.legend(['Distribuição Normal', 'Dados de Porosidade'], fontsize=22)

plt.xticks(fontsize=22)  # Define o tamanho da fonte para os números no eixo x
plt.yticks(fontsize=22)  # Define o tamanho da fonte para os números no eixo y

plt.grid(True)

# Salvar o gráfico como PNG
plt.savefig('TheCNNresults\porosity_distribution_plot_cnn.png')

plt.show()

# %%
pore_Area_vector_values.shape
# Out:
# (3121,)

# %%
pore_Area_vector_values_cm_2 = pore_Area_vector_values*(10)**(4)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Ajustar o tamanho da figura
plt.figure(figsize=(12, 6))  # Largura = 18 polegadas, Altura = 6 polegadas

# Plot
plt.plot(np.arange(len(pore_Area_vector_values_cm_2)), abs(pore_Area_vector_values_cm_2))
plt.xlabel('Índice',fontsize=22)
plt.ylabel('Valores de área do poro (cm²)',fontsize=22)
plt.title('Valores de área do poro (cm²) vs. Índice',fontsize=22)

# Calculate statistics
mean_value = pore_Area_vector_values_cm_2.mean()
max_value = pore_Area_vector_values_cm_2.max()
min_value = pore_Area_vector_values_cm_2.min()

# Round the statistics to four decimal places
mean_value = round(mean_value, 4)
max_value = round(max_value, 4)
min_value = round(min_value, 4)

# Draw lines for mean, max, and min
plt.axhline(y=mean_value, color='r', linestyle='--', label=f'Mean: {mean_value}')
plt.axhline(y=max_value, color='g', linestyle='--', label=f'Max: {max_value}')
plt.axhline(y=min_value, color='b', linestyle='--', label=f'Min: {min_value}')
plt.legend(fontsize=22)  # Define o tamanho da fonte para a legenda

plt.xticks(fontsize=22)  # Define o tamanho da fonte para os números no eixo x
plt.yticks(fontsize=22)  # Define o tamanho da fonte para os números no eixo y

plt.grid(True)

# Save the plot as PNG
plt.savefig('TheCNNresults\pore_area_cnn_plot.png')

plt.show()

# %%
Grain_Area_vector_values.shape
# Out:
# (3121,)

# %%
Grain_Area_vector_values_cm_2 = Grain_Area_vector_values * 10**(4)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Ajustar o tamanho da figura
plt.figure(figsize=(12, 6))  # Largura = 18 polegadas, Altura = 6 polegadas

# Plot
plt.plot(np.arange(len(Grain_Area_vector_values_cm_2)), abs(Grain_Area_vector_values_cm_2))
plt.xlabel('Índice', fontsize=22)
plt.ylabel('Valores de área do grão (cm²)',fontsize=22)
plt.title('Valores de área do grão (cm²) vs. Índice', fontsize=22)

# Calculate statistics
mean_value = Grain_Area_vector_values_cm_2.mean()
max_value = Grain_Area_vector_values_cm_2.max()
min_value = Grain_Area_vector_values_cm_2.min()

# Round the statistics to four decimal places
mean_value = round(mean_value, 4)
max_value = round(max_value, 4)
min_value = round(min_value, 4)

# Draw lines for mean, max, and min
plt.axhline(y=mean_value, color='r', linestyle='--', label=f'Mean: {mean_value}')
plt.axhline(y=max_value, color='g', linestyle='--', label=f'Max: {max_value}')
plt.axhline(y=min_value, color='b', linestyle='--', label=f'Min: {min_value}')
plt.legend(fontsize=22)  # Define o tamanho da fonte para a legenda

plt.xticks(fontsize=22)  # Define o tamanho da fonte para os números no eixo x
plt.yticks(fontsize=22)  # Define o tamanho da fonte para os números no eixo y


plt.grid(True)

# Save the plot as PNG
plt.savefig('TheCNNresults\grain_area_cnn_plot.png')

plt.show()

# %%
porosity_vector_values.min(), porosity_vector_values.max()
# Out:
# (-0.023507969560063513, 0.5735124055973941)

# %%
Grain_fraction_vector_values.min(), Grain_fraction_vector_values.max()
# Out:
# (0.42648759440260586, 1.0235079695600635)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a range of numbers from 1 to the length of the vectors
num_points = range(1, len(jaccard_metric_unet_real) + 1)

# Plot# Plot
plt.figure(figsize=(12, 6))
plt.plot(num_points, jaccard_metric_unet_real, label='Métrica de Jaccard CNN')
plt.plot(num_points, jaccard_metric_mask_real, label='Métrica de Jaccard Thresold')
plt.xlabel('Index', fontsize=22)
plt.ylabel('Valor da métrica de Jaccard',fontsize=22)
plt.title('Comparação das métricas de Jaccard',fontsize=22)
plt.legend(fontsize=22)  # Define o tamanho da fonte para a legenda

plt.xticks(fontsize=22)  # Define o tamanho da fonte para os números no eixo x
plt.yticks(fontsize=22)  # Define o tamanho da fonte para os números no eixo y


plt.grid(True)
# Save the plot as PNG
plt.savefig('TheCNNresults\Jaccard_metric_cnn_vs_thresold_plot.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a range of numbers from 1 to the length of the vectors
num_points = range(1, len(jaccard_metric_unet_real) + 1)

# Plot
plt.figure(figsize=(12, 6))
plt.plot(num_points, ac_train, label='Acurácia Treino')
plt.plot(num_points, ac_test, label='Acurácia Teste')
plt.xlabel('índice', fontsize=22)
plt.ylabel('valor da Acurácia',fontsize=22)
plt.title('Acurácia da CNN: Treino e Teste',fontsize=22)
plt.legend(fontsize=22)  # Define o tamanho da fonte para a legenda

plt.xticks(fontsize=22)  # Define o tamanho da fonte para os números no eixo x
plt.yticks(fontsize=22)  # Define o tamanho da fonte para os números no eixo y
plt.grid(True)
plt.savefig('TheCNNresults\c_metric_cnn_train_and_test_plot.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a range of numbers from 1 to the length of the vectors
num_points = range(1, len(jaccard_metric_unet_real) + 1)

# Plot
plt.figure(figsize=(12, 6))
plt.plot(num_points, loss_train, label='Função de perda treino')
plt.plot(num_points, loss_test, label='Função de perda teste')
plt.xlabel('Index', fontsize=22)
plt.ylabel('Valor da função de perda',fontsize=22)
plt.title('Função de perda da CNN: Treino e Teste',fontsize=22)
plt.legend(fontsize=22)  # Define o tamanho da fonte para a legenda

plt.xticks(fontsize=22)  # Define o tamanho da fonte para os números no eixo x
plt.yticks(fontsize=22)  # Define o tamanho da fonte para os números no eixo y
plt.grid(True)
plt.savefig('TheCNNresults\loss_metric_cnn_train_and_test_plot.png')
plt.show()

# %%
## Testing
import statistics
# Calculate median
median_value = statistics.median(pore_Area_vector_values)
total_area = sum(pore_Area_vector_values)

# convert to the percentage
median_percentage = (100.0 * median_value)/(total_area)
print("Median:", median_value, 'total area', total_area, 'median percentage', median_percentage)

# %%
#delta_a = 3.81/3121
delta_a = median_value # The median of area per slice
delta_a_percentage = median_percentage
delta_a, delta_a_percentage

# %%
def riemann_integral_volume_new_version(porosity_values, delta_h, delta_a):
    total_volume = 0
    for porosity in porosity_values:
        area = porosity * delta_h  # Area of each slice
        volume = area * delta_a  # Volume of each slice
        total_volume += volume  # Accumulate the volume
    return total_volume

# %%
# Compute Riemann integral approximation for porosity over the depth of the rock
integral_approximation_porosity_new = riemann_integral_volume_new_version(porosity_vector_values, slice_thickness_percentage, delta_a_percentage)

print("Riemann integral approximation for porosity in 3D to the sample IL033:", integral_approximation_porosity_new, "%")
# Out:
# Riemann integral approximation for porosity in 3D to the sample IL033: 0.21956087311109937 %

# %%
## Testing
import statistics
# Calculate median
median_value_grain = statistics.median(Grain_Area_vector_values)
total_area_grain = sum(Grain_Area_vector_values)

# convert to the percentage
median_percentage_grain = (100.0 * median_value_grain)/(total_area_grain)
print("Median:", median_value_grain, 'total area', total_area_grain, 'median percentage', median_percentage_grain)
# Out:
# Median: 0.0010779967109545473 total area 3.355506898693627 median percentage 0.032126195639002715

# %%
# The "H" of the reimann integral
##slice_thickness = (pixel_distance_horizontal + pixel_distance_vertical) / 2  # meters 

# Compute Riemann integral approximation for porosity over the depth of the rock
integral_approximation_grain_fraction = riemann_integral_volume_new_version(Grain_fraction_vector_values, slice_thickness_percentage, median_percentage_grain)

print("Riemann integral approximation for grain fraction in 3D over length:", integral_approximation_grain_fraction, "%")
# Out:
# Riemann integral approximation for grain fraction in 3D over length: 2.976969102542287 %
