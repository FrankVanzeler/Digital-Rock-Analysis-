# %% [markdown]
# TESTING THE CODE

# %%
# Run this line if you want to restart the kenerl
from IPython.display import display, Javascript

display(Javascript('IPython.notebook.kernel.restart()'))

# %%
# Check if the gpu is available
import tensorflow as tf
physical_devices_1 = tf.config.list_physical_devices('GPU')
physical_devices_2 = tf.config.list_physical_devices('CPU')
print(physical_devices_1)
print(physical_devices_2)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
import tensorflow as tf
print(tf.__version__)
import numpy as np
import os
from PIL import Image
# Out:
# 2.10.0

# %%
folder_path = 'IL033_teste_export_slice_tiff'
# List all files in the folder
files = os.listdir(folder_path)

# %%
leng = len(files) - 1
leng
# Out:
# 3121

# %%
##leng = 15
specific_value = leng
#leng

# %%
# Calculate the variation into the 3121 slices of the tomography image:
# Circle_radius
circle_radius_initial_parameter = 2.351
circle_radius_final_parameter = 2.365
variation_circle_parameter = abs(circle_radius_final_parameter - circle_radius_initial_parameter)
delta_circle_parameter = variation_circle_parameter/3121
#delta_circle_parameter, variation_circle_parameter, delta_circle_parameter * 3121
# calculate the variation into the 3121 width parameter
circle_center_width_initial_parameter = 1.93
circle_center_width_final_parameter = 1.94
variation_center_width_parameter = abs(circle_center_width_final_parameter - circle_center_width_initial_parameter)
delta_center_width_parameter = variation_center_width_parameter/3121
#variation_center_width_parameter, delta_center_width_parameter, delta_center_width_parameter * 3121
# calculate the variation into the 3121 height parameter
circle_center_height_initial_parameter = 1.98
circle_center_height_final_parameter = 2.04
variation_center_height_parameter = abs(circle_center_height_final_parameter - circle_center_height_initial_parameter)
delta_center_height_parameter = variation_center_height_parameter/3121
#variation_center_height_parameter, delta_center_height_parameter, delta_center_height_parameter * 3121

# %%
# To check the values until the iteration 700
# Allocate the vector to save the properties to each slice
##Grain_Area_vector_values = np.zeros_like(np.zeros(leng-2421))
##Grain_fraction_vector_values = np.zeros_like(np.zeros(leng-2421))
##porosity_vector_values = np.zeros_like(np.zeros(leng-2421))
##pore_Area_vector_values = np.zeros_like(np.zeros(leng-2421))

# %%
# Allocate the vector to save the properties to each slice
Grain_Area_vector_values = np.zeros_like(np.zeros(leng))
Grain_fraction_vector_values = np.zeros_like(np.zeros(leng))
porosity_vector_values = np.zeros_like(np.zeros(leng))
pore_Area_vector_values = np.zeros_like(np.zeros(leng))

# %%
Grain_Area_vector_values.shape, Grain_fraction_vector_values.shape, porosity_vector_values.shape, pore_Area_vector_values.shape
# Out:
# ((3121,), (3121,), (3121,), (3121,))

# %%
import time

# Start the timer
start_time = time.time()

# Apply the methodology
images = []
import cv2
i = 0
for filename in (files):
    if filename.endswith('.tif') or filename.endswith('.tiff'):
        i = i + 1
        file_path = os.path.join(folder_path, filename)
        image = cv2.imread(file_path)
        slice_image = np.array(image)
        # Set the grain to be the value 1
        # This function is to create the binary image to the recognition process work
        def create_binary(img):    
            import cv2
            # Convert the image to grayscale
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            # Apply a threshold to the grayscale image
            #threshold_value = 95
            threshold_value = img.mean() + 0.24 * img.mean()
            max_value = 1
            # Set the value 1 to be the pore space
            ret, binary = cv2.threshold(gray, threshold_value, max_value, cv2.THRESH_BINARY)
            return binary
        ##def create_binary_otsu(img):    
        ##    import cv2
    
            # Convert the image to grayscale
        ##    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            # Apply Otsu's thresholding
        ##    ret, binary = cv2.threshold(gray, 0, 1, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    
        ##    return binary
        slice_image_binary = create_binary(slice_image)
        # BEGGIN FUNCTION SEGMENTATION WITH U NET
        # Calling the function
        def segmentation_with_u_net_sample_1(image_array, mask_array):
            # convert the image_array from uint8 to float64
            import numpy as np
            # convert to the numpy array
            image_array = np.array(image_array)
            mask_array = np.array(mask_array)
            # Remove the third dimension
            image_array = image_array[:, :, 0]
            # Convert uint8 to float64
            image_array = image_array.astype('float32')
    
            # convert the image_array from uint8 to float64
            import numpy as np

            # Convert uint8 to float64
            mask_array = mask_array.astype('float32')

            # calculate the range of the min and max value of the image_array
            range_image_array = image_array.max() - image_array.min()
            # normalize the image_array to segmentation task
            image_array = (image_array - image_array.min()) / (range_image_array)
            # The step is the size of the moviment in one direction by the patch.
     
    
            from skimage.util import view_as_windows
            #==================old version to create patches==================
            # create patches to the images (original and binary)
            # Split the image and mask arrays into patches
            ##patch_size = (256, 256)  # define the patch size
            ##image_patches = view_as_windows(image_array, patch_size, step=256) 
            ##mask_patches = view_as_windows(mask_array, patch_size, step=256)

            # Reshape the patches to flatten them into 2D arrays
            ##image_patches = image_patches.reshape(-1, *patch_size)
            ##mask_patches = mask_patches.reshape(-1, *patch_size)
            # Add the color channel to the patches
            # Add a color channel
            ##image_patches = np.expand_dims(image_patches, axis=3)
            ##mask_patches = np.expand_dims(mask_patches, axis=3)
            #================================================================
            #===================new version to creat patches=================
            ## New version - sucess
            ## If you normalize the original image, you need to convert to the original scale to reconstruct
            ## If you don't normalize the code works...
            import numpy as np
            from skimage.util import view_as_windows

            # Convert image_array from uint8 to float64
            ##image_array = np.array(image_array)[:, :, 0].astype('float32')

            # Convert mask_array from uint8 to boolean
            ##mask_array = np.array(mask_array).astype('bool')

            # Normalize the image_array
            #range_image_array = image_array.max() - image_array.min()
            #image_array = (image_array - image_array.min()) / (range_image_array)

            # Split the image and mask arrays into patches
            patch_size = (184, 184)
            step = 184
            image_patches = view_as_windows(image_array, patch_size, step=step)
            mask_patches = view_as_windows(mask_array, patch_size, step=step)

            # Reshape the patches to flatten them into 2D arrays
            image_patches_flat = image_patches.reshape(-1, *patch_size)
            mask_patches_flat = mask_patches.reshape(-1, *patch_size)

            # Add the color channel to the patches
            image_patches_flat = np.expand_dims(image_patches_flat, axis=3)
            mask_patches_flat = np.expand_dims(mask_patches_flat, axis=3)

            # Save the position of each patch
            patch_positions = []

            for i in range(image_patches.shape[0]):
                for j in range(image_patches.shape[1]):
                    start_row = i * step
                    start_col = j * step
                    end_row = start_row + patch_size[0]
                    end_col = start_col + patch_size[1]

                    patch_positions.append({
                        'start_row': start_row,
                        'start_col': start_col,
                        'end_row': end_row,
                        'end_col': end_col
                                })

            # Save the patch positions as a NumPy array
            patch_positions_array = np.array(patch_positions)
    
    
    
    
    
            ####from sklearn.model_selection import train_test_split
    
            # assume X is your feature matrix and y is your target vector
            ####X_train, X_test, y_train, y_test = train_test_split(image_patches_flat, mask_patches_flat, test_size=0.3, random_state=42)
            # test_size = 0.3 specifies that 30% of the data will be used for testing
            # random_state = 42 sets a seed for the random number generator to ensure reproducibility
    
            #import necessary libraries
            ####import numpy as np 
            ####from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D
            ####from tensorflow.keras.models import Model
            ####from tensorflow.keras.optimizers import Adam

            #define parameters
            input_shape = (184, 184, 1)
            filters = 92
            #input_shape = (256, 256, 1)
            #filters = 128
            #filters = 128

            #construct model
            ##inputs = Input(input_shape)
            ##x = Conv2D(filters, (3, 3), activation='relu', padding='same')(inputs) # número de filtros, (3, 3) -> kernel size, 
            ##x = MaxPooling2D((2, 2), padding='same')(x)
            ##x = Conv2D(filters, (3, 3), activation='relu', padding='same')(x)
            ##x = UpSampling2D((2, 2))(x)
            ##outputs = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)
    
            #compile model
            ##model = Model(inputs=[inputs], outputs=[outputs])
            ##model.compile(optimizer=Adam(lr=0.01), loss='binary_crossentropy', metrics=['accuracy'])
    
            #summary of model
            ##model.summary()
    
            # Build the model
            ##model.fit(X_train, y_train, epochs=80, validation_data=(X_test, y_test)) # try the verbose=0
            ####from keras.callbacks import EarlyStopping

            # Construct model
            ####inputs = Input(input_shape)
            ####x = Conv2D(filters, (3, 3), activation='relu', padding='same')(inputs)
            ####x = MaxPooling2D((2, 2), padding='same')(x)
            ####x = Conv2D(filters, (3, 3), activation='relu', padding='same')(x)
            ####x = UpSampling2D((2, 2))(x)
            ####outputs = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)
            # Change the activation function in the final layer to 'sigmoid'
    

            # Compile model
            ####model = Model(inputs=[inputs], outputs=[outputs])
            ####model.compile(optimizer=Adam(lr=0.01), loss='binary_crossentropy', metrics=['accuracy'])

            # Define EarlyStopping callback
            ####early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
            ## To train just one time
            ###if(i == 1):
                # Build and train the model
            ###    model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test), callbacks=[early_stopping], verbose=1)
            ###else:
                # The predict segmentation to the input image
            ###    y_pred = model.predict(image_patches_flat)
            ###    return y_pred, image_patches_flat, mask_patches_flat, patch_positions_array
            # To train per slice
            ####model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test), callbacks=[early_stopping], verbose=1)
            ####y_pred = model.predict(image_patches_flat)
            y_pred = mask_patches_flat # Test # the thresold is img.mean() + 0.20 * img.mean()
            return y_pred, image_patches_flat, mask_patches_flat, patch_positions_array
            # END FUNCTION SEGMENTATION WITH U NET
        y_pred_slice_tensor, image_slice_tensor_patches, mask_slice_tensor_patches, slice_patch_positions = segmentation_with_u_net_sample_1(slice_image, slice_image_binary)
        # Function to reconstruct the original image and mask
        
        
        def reconstruct_mask(mask_patches_flat, patch_positions_array, image_shape):
            # Get the original image shape
            original_shape = (image_shape[0], image_shape[1])

            # Initialize empty arrays for the reconstructed image and mask
            reconstructed_mask = np.zeros(original_shape, dtype='float32')

            for i, position in enumerate(patch_positions_array):
                start_row, start_col = position['start_row'], position['start_col']
                end_row, end_col = position['end_row'], position['end_col']

                # Extract the patches from the flat arrays
                #image_patch = image_patches_flat[i, :, :, 0]
                mask_patch = mask_patches_flat[i, :, :, 0]

                # Update the reconstructed image and mask
                #reconstructed_image[start_row:end_row, start_col:end_col] = image_patch
                reconstructed_mask[start_row:end_row, start_col:end_col] = mask_patch

            return reconstructed_mask
        # (you can replace these with your actual variables)
        reconstructed_mask_slice_image_tensor = reconstruct_mask(y_pred_slice_tensor, slice_patch_positions, slice_image.shape)
        print(reconstructed_mask_slice_image_tensor.min(), reconstructed_mask_slice_image_tensor.max())
        # When you set the grain to be the value 1 # background 
        # You are suppose to use the calculate_pore_properties_gray_version_rock to calculate the properties
        import numpy as np

        def calculate_pore_properties_gray_version_rock(segmented_image, pixel_area, circle_area):
            """
            Calculate pore properties including pore area and porosity for a grayscale segmented image.

            Parameters:
            - segmented_image: 2D segmented image where pores are represented by values between 0 and 1.
            - pixel_area: Area of a single pixel in the image.

            Returns:
            - grain_area: Total area of segmented grain regions.
            - fraction_matrix: matrix calculated as the ratio of grain area to the total area.
            """
            # Check if the input image is within the valid range
            if not (np.all(0 <= segmented_image) and np.all(segmented_image <= 1)):
                raise ValueError("Input image must have values between 0 and 1 for grayscale segmentation.")
            # Calculate pore area
            grain_area = np.sum(segmented_image) * pixel_area
    
            # Calculate total area of the image
            #total_area = np.sum(segmented_image >= 0) * pixel_area
            ##total_area = np.sum(segmented_image >= segmented_image.min()) * pixel_area
            total_area = circle_area
            # Calculate porosity
            fraction_matrix = grain_area / total_area
            porosity = 1.0 - fraction_matrix
            pore_area = total_area - grain_area
            return grain_area, fraction_matrix, porosity, pore_area
        
        import random

        import numpy as np
        import cv2

        # Define the range
        #min_value = 1
        #max_value = 3121

        # Generate a random number between the range
        #random_number = random.randint(min_value, max_value)

        # Print the random number
        #print(random_number)

        # Assuming you have loaded the image
        #image = globals()[f'tensor_image_{random_number}']  # Placeholder for the image, replace with your image loading code
        ##image = slice_image # the same thing of the code bellow, you avoid to spent the memory.
        # Get the dimensions of the image
        height, width, _ = slice_image.shape

        # Assuming you have defined these variables elsewhere in your code
        ##delta_circle_parameter = 0.5
        ##delta_center_width_parameter = 0.3
        ##delta_center_height_parameter = 0.2
        
        # Calculate the radius and center of the circle (with float coordinates)
        circle_radius = min(width, height) / (2.351 + ((i - 1) * delta_circle_parameter))  # Adjust the radius as needed with a float value
        circle_center = (width / (1.93 + ((i - 1) * delta_center_width_parameter)), height / (1.98 + ((i-1) * delta_center_height_parameter)))

        # Calculate the area of the circle
        circle_area = np.pi * circle_radius ** 2

        # Calculate the external area (total area - circle area)
        external_area = height * width - circle_area

        # Print the calculated areas
        ##print("Circle Area:", circle_area)
        ##print("External Area:", external_area)

        # Check if the sum of internal and external areas equals the total area
        total_area = height * width
        sum_of_areas = circle_area + external_area
        ##print("Sum of Areas (Internal + External):", sum_of_areas)
        ##print("Total Area:", total_area)
        ##print("Are the areas equal?", np.isclose(sum_of_areas, total_area))
        # Based on the real size of the object in the world
        # In the real world we have 1704 pixels in a diameter with 3.81 cm
        value_pixel_real_world=(3.81)/(1704) # Simple rule
        # Calculating the distance of the width and height in mm
        image_width_cm = (2024 * value_pixel_real_world)
        image_height_cm = (2024 * value_pixel_real_world)
        image_width_m = image_width_cm * (10)**(-2)
        image_height_m = image_height_cm * (10)**(-2)
        # Calculating the total area in meters:
        total_check_real_area = (image_width_m) * (image_height_m)
        # Calculate the total number of pixels in the image
        total_pixels_horizontal = 2024
        total_pixels_vertical = 2024
        total_pixels = total_pixels_horizontal * total_pixels_vertical

        # Calculate the area represented by each pixel in the real world
        pixel_area_real_world = (image_width_m * image_height_m) / total_pixels
        # Atribute the area to each pixel in the real world
        pixel_area = pixel_area_real_world
        # Define the circle area and the external area.
        circle_area_real = circle_area * pixel_area
        external_area_real = external_area * pixel_area
        # Shave the properties in each vector
        Grain_Area_vector_values[i-1], Grain_fraction_vector_values[i-1], porosity_vector_values[i-1], pore_Area_vector_values[i-1] = calculate_pore_properties_gray_version_rock(reconstructed_mask_slice_image_tensor, pixel_area, circle_area_real)
        globals()[f'name_slice_{i-1}'] = filename
        print('The iteration:',i-1, 'is complete')
        if i == specific_value:
            print("Found the specific value. Stopping the loop.")
            break  # Exit the loop
            
            
# End the timer
end_time = time.time()

# Calculate the elapsed time in seconds
elapsed_time_seconds = end_time - start_time

# Convert elapsed time from seconds to hours
elapsed_time_hours = elapsed_time_seconds / 3600

print("Time elapsed:", elapsed_time_hours, "hours")
# Out:
# 0.0 1.0
# The iteration: 0 is complete
# 0.0 1.0
# The iteration: 1 is complete
# 0.0 1.0
# The iteration: 2 is complete
# 0.0 1.0
# The iteration: 3 is complete
# 0.0 1.0
# The iteration: 4 is complete
# 0.0 1.0
# The iteration: 5 is complete
# 0.0 1.0
# The iteration: 6 is complete
# 0.0 1.0
# The iteration: 7 is complete
# 0.0 1.0
# The iteration: 8 is complete
# 0.0 1.0
# The iteration: 9 is complete
# 0.0 1.0
# The iteration: 10 is complete
# 0.0 1.0
# The iteration: 11 is complete
# 0.0 1.0
# The iteration: 12 is complete
# 0.0 1.0
# The iteration: 13 is complete
# 0.0 1.0
# The iteration: 14 is complete
# 0.0 1.0
# The iteration: 15 is complete
# 0.0 1.0
# The iteration: 16 is complete
# 0.0 1.0
# The iteration: 17 is complete
# 0.0 1.0
# The iteration: 18 is complete
# 0.0 1.0
# The iteration: 19 is complete
# 0.0 1.0
# The iteration: 20 is complete
# 0.0 1.0
# The iteration: 21 is complete
# 0.0 1.0
# The iteration: 22 is complete
# 0.0 1.0
# The iteration: 23 is complete
# 0.0 1.0
# The iteration: 24 is complete
# 0.0 1.0
# The iteration: 25 is complete
# 0.0 1.0
# The iteration: 26 is complete
# 0.0 1.0
# The iteration: 27 is complete
# 0.0 1.0
# The iteration: 28 is complete
# 0.0 1.0
# The iteration: 29 is complete
# 0.0 1.0
# The iteration: 30 is complete
# 0.0 1.0
# The iteration: 31 is complete
# 0.0 1.0
# The iteration: 32 is complete
# 0.0 1.0
# The iteration: 33 is complete
# 0.0 1.0
# The iteration: 34 is complete
# 0.0 1.0
# The iteration: 35 is complete
# 0.0 1.0
# The iteration: 36 is complete
# 0.0 1.0
# The iteration: 37 is complete
# 0.0 1.0
# The iteration: 38 is complete
# 0.0 1.0
# The iteration: 39 is complete
# 0.0 1.0
# The iteration: 40 is complete
# 0.0 1.0
# The iteration: 41 is complete
# 0.0 1.0
# The iteration: 42 is complete
# 0.0 1.0
# The iteration: 43 is complete
# 0.0 1.0
# The iteration: 44 is complete
# 0.0 1.0
# The iteration: 45 is complete
# 0.0 1.0
# The iteration: 46 is complete
# 0.0 1.0
# The iteration: 47 is complete
# 0.0 1.0
# The iteration: 48 is complete
# 0.0 1.0
# The iteration: 49 is complete
# 0.0 1.0
# The iteration: 50 is complete
# 0.0 1.0
# The iteration: 51 is complete
# 0.0 1.0
# The iteration: 52 is complete
# 0.0 1.0
# The iteration: 53 is complete
# 0.0 1.0
# The iteration: 54 is complete
# 0.0 1.0
# The iteration: 55 is complete
# 0.0 1.0
# The iteration: 56 is complete
# 0.0 1.0
# The iteration: 57 is complete
# 0.0 1.0
# The iteration: 58 is complete
# 0.0 1.0
# The iteration: 59 is complete
# 0.0 1.0
# The iteration: 60 is complete
# 0.0 1.0
# The iteration: 61 is complete
# 0.0 1.0
# The iteration: 62 is complete
# 0.0 1.0
# The iteration: 63 is complete
# 0.0 1.0
# The iteration: 64 is complete
# 0.0 1.0
# The iteration: 65 is complete
# 0.0 1.0
# The iteration: 66 is complete
# 0.0 1.0
# The iteration: 67 is complete
# 0.0 1.0
# The iteration: 68 is complete
# 0.0 1.0
# The iteration: 69 is complete
# 0.0 1.0
# The iteration: 70 is complete
# 0.0 1.0
# The iteration: 71 is complete
# 0.0 1.0
# The iteration: 72 is complete
# 0.0 1.0
# The iteration: 73 is complete
# 0.0 1.0
# The iteration: 74 is complete
# 0.0 1.0
# The iteration: 75 is complete
# 0.0 1.0
# The iteration: 76 is complete
# 0.0 1.0
# The iteration: 77 is complete
# 0.0 1.0
# The iteration: 78 is complete
# 0.0 1.0
# The iteration: 79 is complete
# 0.0 1.0
# The iteration: 80 is complete
# 0.0 1.0
# The iteration: 81 is complete
# 0.0 1.0
# The iteration: 82 is complete
# 0.0 1.0
# The iteration: 83 is complete
# 0.0 1.0
# The iteration: 84 is complete
# 0.0 1.0
# The iteration: 85 is complete
# 0.0 1.0
# The iteration: 86 is complete
# 0.0 1.0
# The iteration: 87 is complete
# 0.0 1.0
# The iteration: 88 is complete
# 0.0 1.0
# The iteration: 89 is complete
# 0.0 1.0
# The iteration: 90 is complete
# 0.0 1.0
# The iteration: 91 is complete
# 0.0 1.0
# The iteration: 92 is complete
# 0.0 1.0
# The iteration: 93 is complete
# 0.0 1.0
# The iteration: 94 is complete
# 0.0 1.0
# The iteration: 95 is complete
# 0.0 1.0
# The iteration: 96 is complete
# 0.0 1.0
# The iteration: 97 is complete
# 0.0 1.0
# The iteration: 98 is complete
# 0.0 1.0
# The iteration: 99 is complete
# 0.0 1.0
# The iteration: 100 is complete
# 0.0 1.0
# The iteration: 101 is complete
# 0.0 1.0
# The iteration: 102 is complete
# 0.0 1.0
# The iteration: 103 is complete
# 0.0 1.0
# The iteration: 104 is complete
# 0.0 1.0
# The iteration: 105 is complete
# 0.0 1.0
# The iteration: 106 is complete
# 0.0 1.0
# The iteration: 107 is complete
# 0.0 1.0
# The iteration: 108 is complete
# 0.0 1.0
# The iteration: 109 is complete
# 0.0 1.0
# The iteration: 110 is complete
# 0.0 1.0
# The iteration: 111 is complete
# 0.0 1.0
# The iteration: 112 is complete
# 0.0 1.0
# The iteration: 113 is complete
# 0.0 1.0
# The iteration: 114 is complete
# 0.0 1.0
# The iteration: 115 is complete
# 0.0 1.0
# The iteration: 116 is complete
# 0.0 1.0
# The iteration: 117 is complete
# 0.0 1.0
# The iteration: 118 is complete
# 0.0 1.0
# The iteration: 119 is complete
# 0.0 1.0
# The iteration: 120 is complete
# 0.0 1.0
# The iteration: 121 is complete
# 0.0 1.0
# The iteration: 122 is complete
# 0.0 1.0
# The iteration: 123 is complete
# 0.0 1.0
# The iteration: 124 is complete
# 0.0 1.0
# The iteration: 125 is complete
# 0.0 1.0
# The iteration: 126 is complete
# 0.0 1.0
# The iteration: 127 is complete
# 0.0 1.0
# The iteration: 128 is complete
# 0.0 1.0
# The iteration: 129 is complete
# 0.0 1.0
# The iteration: 130 is complete
# 0.0 1.0
# The iteration: 131 is complete
# 0.0 1.0
# The iteration: 132 is complete
# 0.0 1.0
# The iteration: 133 is complete
# 0.0 1.0
# The iteration: 134 is complete
# 0.0 1.0
# The iteration: 135 is complete
# 0.0 1.0
# The iteration: 136 is complete
# 0.0 1.0
# The iteration: 137 is complete
# 0.0 1.0
# The iteration: 138 is complete
# 0.0 1.0
# The iteration: 139 is complete
# 0.0 1.0
# The iteration: 140 is complete
# 0.0 1.0
# The iteration: 141 is complete
# 0.0 1.0
# The iteration: 142 is complete
# 0.0 1.0
# The iteration: 143 is complete
# 0.0 1.0
# The iteration: 144 is complete
# 0.0 1.0
# The iteration: 145 is complete
# 0.0 1.0
# The iteration: 146 is complete
# 0.0 1.0
# The iteration: 147 is complete
# 0.0 1.0
# The iteration: 148 is complete
# 0.0 1.0
# The iteration: 149 is complete
# 0.0 1.0
# The iteration: 150 is complete
# 0.0 1.0
# The iteration: 151 is complete
# 0.0 1.0
# The iteration: 152 is complete
# 0.0 1.0
# The iteration: 153 is complete
# 0.0 1.0
# The iteration: 154 is complete
# 0.0 1.0
# The iteration: 155 is complete
# 0.0 1.0
# The iteration: 156 is complete
# 0.0 1.0
# The iteration: 157 is complete
# 0.0 1.0
# The iteration: 158 is complete
# 0.0 1.0
# The iteration: 159 is complete
# 0.0 1.0
# The iteration: 160 is complete
# 0.0 1.0
# The iteration: 161 is complete
# 0.0 1.0
# The iteration: 162 is complete
# 0.0 1.0
# The iteration: 163 is complete
# 0.0 1.0
# The iteration: 164 is complete
# 0.0 1.0
# The iteration: 165 is complete
# 0.0 1.0
# The iteration: 166 is complete
# 0.0 1.0
# The iteration: 167 is complete
# 0.0 1.0
# The iteration: 168 is complete
# 0.0 1.0
# The iteration: 169 is complete
# 0.0 1.0
# The iteration: 170 is complete
# 0.0 1.0
# The iteration: 171 is complete
# 0.0 1.0
# The iteration: 172 is complete
# 0.0 1.0
# The iteration: 173 is complete
# 0.0 1.0
# The iteration: 174 is complete
# 0.0 1.0
# The iteration: 175 is complete
# 0.0 1.0
# The iteration: 176 is complete
# 0.0 1.0
# The iteration: 177 is complete
# 0.0 1.0
# The iteration: 178 is complete
# 0.0 1.0
# The iteration: 179 is complete
# 0.0 1.0
# The iteration: 180 is complete
# 0.0 1.0
# The iteration: 181 is complete
# 0.0 1.0
# The iteration: 182 is complete
# 0.0 1.0
# The iteration: 183 is complete
# 0.0 1.0
# The iteration: 184 is complete
# 0.0 1.0
# The iteration: 185 is complete
# 0.0 1.0
# The iteration: 186 is complete
# 0.0 1.0
# The iteration: 187 is complete
# 0.0 1.0
# The iteration: 188 is complete
# 0.0 1.0
# The iteration: 189 is complete
# 0.0 1.0
# The iteration: 190 is complete
# 0.0 1.0
# The iteration: 191 is complete
# 0.0 1.0
# The iteration: 192 is complete
# 0.0 1.0
# The iteration: 193 is complete
# 0.0 1.0
# The iteration: 194 is complete
# 0.0 1.0
# The iteration: 195 is complete
# 0.0 1.0
# The iteration: 196 is complete
# 0.0 1.0
# The iteration: 197 is complete
# 0.0 1.0
# The iteration: 198 is complete
# 0.0 1.0
# The iteration: 199 is complete
# 0.0 1.0
# The iteration: 200 is complete
# 0.0 1.0
# The iteration: 201 is complete
# 0.0 1.0
# The iteration: 202 is complete
# 0.0 1.0
# The iteration: 203 is complete
# 0.0 1.0
# The iteration: 204 is complete
# 0.0 1.0
# The iteration: 205 is complete
# 0.0 1.0
# The iteration: 206 is complete
# 0.0 1.0
# The iteration: 207 is complete
# 0.0 1.0
# The iteration: 208 is complete
# 0.0 1.0
# The iteration: 209 is complete
# 0.0 1.0
# The iteration: 210 is complete
# 0.0 1.0
# The iteration: 211 is complete
# 0.0 1.0
# The iteration: 212 is complete
# 0.0 1.0
# The iteration: 213 is complete
# 0.0 1.0
# The iteration: 214 is complete
# 0.0 1.0
# The iteration: 215 is complete
# 0.0 1.0
# The iteration: 216 is complete
# 0.0 1.0
# The iteration: 217 is complete
# 0.0 1.0
# The iteration: 218 is complete
# 0.0 1.0
# The iteration: 219 is complete
# 0.0 1.0
# The iteration: 220 is complete
# 0.0 1.0
# The iteration: 221 is complete
# 0.0 1.0
# The iteration: 222 is complete
# 0.0 1.0
# The iteration: 223 is complete
# 0.0 1.0
# The iteration: 224 is complete
# 0.0 1.0
# The iteration: 225 is complete
# 0.0 1.0
# The iteration: 226 is complete
# 0.0 1.0
# The iteration: 227 is complete
# 0.0 1.0
# The iteration: 228 is complete
# 0.0 1.0
# The iteration: 229 is complete
# 0.0 1.0
# The iteration: 230 is complete
# 0.0 1.0
# The iteration: 231 is complete
# 0.0 1.0
# The iteration: 232 is complete
# 0.0 1.0
# The iteration: 233 is complete
# 0.0 1.0
# The iteration: 234 is complete
# 0.0 1.0
# The iteration: 235 is complete
# 0.0 1.0
# The iteration: 236 is complete
# 0.0 1.0
# The iteration: 237 is complete
# 0.0 1.0
# The iteration: 238 is complete
# 0.0 1.0
# The iteration: 239 is complete
# 0.0 1.0
# The iteration: 240 is complete
# 0.0 1.0
# The iteration: 241 is complete
# 0.0 1.0
# The iteration: 242 is complete
# 0.0 1.0
# The iteration: 243 is complete
# 0.0 1.0
# The iteration: 244 is complete
# 0.0 1.0
# The iteration: 245 is complete
# 0.0 1.0
# The iteration: 246 is complete
# 0.0 1.0
# The iteration: 247 is complete
# 0.0 1.0
# The iteration: 248 is complete
# 0.0 1.0
# The iteration: 249 is complete
# 0.0 1.0
# The iteration: 250 is complete
# 0.0 1.0
# The iteration: 251 is complete
# 0.0 1.0
# The iteration: 252 is complete
# 0.0 1.0
# The iteration: 253 is complete
# 0.0 1.0
# The iteration: 254 is complete
# 0.0 1.0
# The iteration: 255 is complete
# 0.0 1.0
# The iteration: 256 is complete
# 0.0 1.0
# The iteration: 257 is complete
# 0.0 1.0
# The iteration: 258 is complete
# 0.0 1.0
# The iteration: 259 is complete
# 0.0 1.0
# The iteration: 260 is complete
# 0.0 1.0
# The iteration: 261 is complete
# 0.0 1.0
# The iteration: 262 is complete
# 0.0 1.0
# The iteration: 263 is complete
# 0.0 1.0
# The iteration: 264 is complete
# 0.0 1.0
# The iteration: 265 is complete
# 0.0 1.0
# The iteration: 266 is complete
# 0.0 1.0
# The iteration: 267 is complete
# 0.0 1.0
# The iteration: 268 is complete
# 0.0 1.0
# The iteration: 269 is complete
# 0.0 1.0
# The iteration: 270 is complete
# 0.0 1.0
# The iteration: 271 is complete
# 0.0 1.0
# The iteration: 272 is complete
# 0.0 1.0
# The iteration: 273 is complete
# 0.0 1.0
# The iteration: 274 is complete
# 0.0 1.0
# The iteration: 275 is complete
# 0.0 1.0
# The iteration: 276 is complete
# 0.0 1.0
# The iteration: 277 is complete
# 0.0 1.0
# The iteration: 278 is complete
# 0.0 1.0
# The iteration: 279 is complete
# 0.0 1.0
# The iteration: 280 is complete
# 0.0 1.0
# The iteration: 281 is complete
# 0.0 1.0
# The iteration: 282 is complete
# 0.0 1.0
# The iteration: 283 is complete
# 0.0 1.0
# The iteration: 284 is complete
# 0.0 1.0
# The iteration: 285 is complete
# 0.0 1.0
# The iteration: 286 is complete
# 0.0 1.0
# The iteration: 287 is complete
# 0.0 1.0
# The iteration: 288 is complete
# 0.0 1.0
# The iteration: 289 is complete
# 0.0 1.0
# The iteration: 290 is complete
# 0.0 1.0
# The iteration: 291 is complete
# 0.0 1.0
# The iteration: 292 is complete
# 0.0 1.0
# The iteration: 293 is complete
# 0.0 1.0
# The iteration: 294 is complete
# 0.0 1.0
# The iteration: 295 is complete
# 0.0 1.0
# The iteration: 296 is complete
# 0.0 1.0
# The iteration: 297 is complete
# 0.0 1.0
# The iteration: 298 is complete
# 0.0 1.0
# The iteration: 299 is complete
# 0.0 1.0
# The iteration: 300 is complete
# 0.0 1.0
# The iteration: 301 is complete
# 0.0 1.0
# The iteration: 302 is complete
# 0.0 1.0
# The iteration: 303 is complete
# 0.0 1.0
# The iteration: 304 is complete
# 0.0 1.0
# The iteration: 305 is complete
# 0.0 1.0
# The iteration: 306 is complete
# 0.0 1.0
# The iteration: 307 is complete
# 0.0 1.0
# The iteration: 308 is complete
# 0.0 1.0
# The iteration: 309 is complete
# 0.0 1.0
# The iteration: 310 is complete
# 0.0 1.0
# The iteration: 311 is complete
# 0.0 1.0
# The iteration: 312 is complete
# 0.0 1.0
# The iteration: 313 is complete
# 0.0 1.0
# The iteration: 314 is complete
# 0.0 1.0
# The iteration: 315 is complete
# 0.0 1.0
# The iteration: 316 is complete
# 0.0 1.0
# The iteration: 317 is complete
# 0.0 1.0
# The iteration: 318 is complete
# 0.0 1.0
# The iteration: 319 is complete
# 0.0 1.0
# The iteration: 320 is complete
# 0.0 1.0
# The iteration: 321 is complete
# 0.0 1.0
# The iteration: 322 is complete
# 0.0 1.0
# The iteration: 323 is complete
# 0.0 1.0
# The iteration: 324 is complete
# 0.0 1.0
# The iteration: 325 is complete
# 0.0 1.0
# The iteration: 326 is complete
# 0.0 1.0
# The iteration: 327 is complete
# 0.0 1.0
# The iteration: 328 is complete
# 0.0 1.0
# The iteration: 329 is complete
# 0.0 1.0
# The iteration: 330 is complete
# 0.0 1.0
# The iteration: 331 is complete
# 0.0 1.0
# The iteration: 332 is complete
# 0.0 1.0
# The iteration: 333 is complete
# 0.0 1.0
# The iteration: 334 is complete
# 0.0 1.0
# The iteration: 335 is complete
# 0.0 1.0
# The iteration: 336 is complete
# 0.0 1.0
# The iteration: 337 is complete
# 0.0 1.0
# The iteration: 338 is complete
# 0.0 1.0
# The iteration: 339 is complete
# 0.0 1.0
# The iteration: 340 is complete
# 0.0 1.0
# The iteration: 341 is complete
# 0.0 1.0
# The iteration: 342 is complete
# 0.0 1.0
# The iteration: 343 is complete
# 0.0 1.0
# The iteration: 344 is complete
# 0.0 1.0
# The iteration: 345 is complete
# 0.0 1.0
# The iteration: 346 is complete
# 0.0 1.0
# The iteration: 347 is complete
# 0.0 1.0
# The iteration: 348 is complete
# 0.0 1.0
# The iteration: 349 is complete
# 0.0 1.0
# The iteration: 350 is complete
# 0.0 1.0
# The iteration: 351 is complete
# 0.0 1.0
# The iteration: 352 is complete
# 0.0 1.0
# The iteration: 353 is complete
# 0.0 1.0
# The iteration: 354 is complete
# 0.0 1.0
# The iteration: 355 is complete
# 0.0 1.0
# The iteration: 356 is complete
# 0.0 1.0
# The iteration: 357 is complete
# 0.0 1.0
# The iteration: 358 is complete
# 0.0 1.0
# The iteration: 359 is complete
# 0.0 1.0
# The iteration: 360 is complete
# 0.0 1.0
# The iteration: 361 is complete
# 0.0 1.0
# The iteration: 362 is complete
# 0.0 1.0
# The iteration: 363 is complete
# 0.0 1.0
# The iteration: 364 is complete
# 0.0 1.0
# The iteration: 365 is complete
# 0.0 1.0
# The iteration: 366 is complete
# 0.0 1.0
# The iteration: 367 is complete
# 0.0 1.0
# The iteration: 368 is complete
# 0.0 1.0
# The iteration: 369 is complete
# 0.0 1.0
# The iteration: 370 is complete
# 0.0 1.0
# The iteration: 371 is complete
# 0.0 1.0
# The iteration: 372 is complete
# 0.0 1.0
# The iteration: 373 is complete
# 0.0 1.0
# The iteration: 374 is complete
# 0.0 1.0
# The iteration: 375 is complete
# 0.0 1.0
# The iteration: 376 is complete
# 0.0 1.0
# The iteration: 377 is complete
# 0.0 1.0
# The iteration: 378 is complete
# 0.0 1.0
# The iteration: 379 is complete
# 0.0 1.0
# The iteration: 380 is complete
# 0.0 1.0
# The iteration: 381 is complete
# 0.0 1.0
# The iteration: 382 is complete
# 0.0 1.0
# The iteration: 383 is complete
# 0.0 1.0
# The iteration: 384 is complete
# 0.0 1.0
# The iteration: 385 is complete
# 0.0 1.0
# The iteration: 386 is complete
# 0.0 1.0
# The iteration: 387 is complete
# 0.0 1.0
# The iteration: 388 is complete
# 0.0 1.0
# The iteration: 389 is complete
# 0.0 1.0
# The iteration: 390 is complete
# 0.0 1.0
# The iteration: 391 is complete
# 0.0 1.0
# The iteration: 392 is complete
# 0.0 1.0
# The iteration: 393 is complete
# 0.0 1.0
# The iteration: 394 is complete
# 0.0 1.0
# The iteration: 395 is complete
# 0.0 1.0
# The iteration: 396 is complete
# 0.0 1.0
# The iteration: 397 is complete
# 0.0 1.0
# The iteration: 398 is complete
# 0.0 1.0
# The iteration: 399 is complete
# 0.0 1.0
# The iteration: 400 is complete
# 0.0 1.0
# The iteration: 401 is complete
# 0.0 1.0
# The iteration: 402 is complete
# 0.0 1.0
# The iteration: 403 is complete
# 0.0 1.0
# The iteration: 404 is complete
# 0.0 1.0
# The iteration: 405 is complete
# 0.0 1.0
# The iteration: 406 is complete
# 0.0 1.0
# The iteration: 407 is complete
# 0.0 1.0
# The iteration: 408 is complete
# 0.0 1.0
# The iteration: 409 is complete
# 0.0 1.0
# The iteration: 410 is complete
# 0.0 1.0
# The iteration: 411 is complete
# 0.0 1.0
# The iteration: 412 is complete
# 0.0 1.0
# The iteration: 413 is complete
# 0.0 1.0
# The iteration: 414 is complete
# 0.0 1.0
# The iteration: 415 is complete
# 0.0 1.0
# The iteration: 416 is complete
# 0.0 1.0
# The iteration: 417 is complete
# 0.0 1.0
# The iteration: 418 is complete
# 0.0 1.0
# The iteration: 419 is complete
# 0.0 1.0
# The iteration: 420 is complete
# 0.0 1.0
# The iteration: 421 is complete
# 0.0 1.0
# The iteration: 422 is complete
# 0.0 1.0
# The iteration: 423 is complete
# 0.0 1.0
# The iteration: 424 is complete
# 0.0 1.0
# The iteration: 425 is complete
# 0.0 1.0
# The iteration: 426 is complete
# 0.0 1.0
# The iteration: 427 is complete
# 0.0 1.0
# The iteration: 428 is complete
# 0.0 1.0
# The iteration: 429 is complete
# 0.0 1.0
# The iteration: 430 is complete
# 0.0 1.0
# The iteration: 431 is complete
# 0.0 1.0
# The iteration: 432 is complete
# 0.0 1.0
# The iteration: 433 is complete
# 0.0 1.0
# The iteration: 434 is complete
# 0.0 1.0
# The iteration: 435 is complete
# 0.0 1.0
# The iteration: 436 is complete
# 0.0 1.0
# The iteration: 437 is complete
# 0.0 1.0
# The iteration: 438 is complete
# 0.0 1.0
# The iteration: 439 is complete
# 0.0 1.0
# The iteration: 440 is complete
# 0.0 1.0
# The iteration: 441 is complete
# 0.0 1.0
# The iteration: 442 is complete
# 0.0 1.0
# The iteration: 443 is complete
# 0.0 1.0
# The iteration: 444 is complete
# 0.0 1.0
# The iteration: 445 is complete
# 0.0 1.0
# The iteration: 446 is complete
# 0.0 1.0
# The iteration: 447 is complete
# 0.0 1.0
# The iteration: 448 is complete
# 0.0 1.0
# The iteration: 449 is complete
# 0.0 1.0
# The iteration: 450 is complete
# 0.0 1.0
# The iteration: 451 is complete
# 0.0 1.0
# The iteration: 452 is complete
# 0.0 1.0
# The iteration: 453 is complete
# 0.0 1.0
# The iteration: 454 is complete
# 0.0 1.0
# The iteration: 455 is complete
# 0.0 1.0
# The iteration: 456 is complete
# 0.0 1.0
# The iteration: 457 is complete
# 0.0 1.0
# The iteration: 458 is complete
# 0.0 1.0
# The iteration: 459 is complete
# 0.0 1.0
# The iteration: 460 is complete
# 0.0 1.0
# The iteration: 461 is complete
# 0.0 1.0
# The iteration: 462 is complete
# 0.0 1.0
# The iteration: 463 is complete
# 0.0 1.0
# The iteration: 464 is complete
# 0.0 1.0
# The iteration: 465 is complete
# 0.0 1.0
# The iteration: 466 is complete
# 0.0 1.0
# The iteration: 467 is complete
# 0.0 1.0
# The iteration: 468 is complete
# 0.0 1.0
# The iteration: 469 is complete
# 0.0 1.0
# The iteration: 470 is complete
# 0.0 1.0
# The iteration: 471 is complete
# 0.0 1.0
# The iteration: 472 is complete
# 0.0 1.0
# The iteration: 473 is complete
# 0.0 1.0
# The iteration: 474 is complete
# 0.0 1.0
# The iteration: 475 is complete
# 0.0 1.0
# The iteration: 476 is complete
# 0.0 1.0
# The iteration: 477 is complete
# 0.0 1.0
# The iteration: 478 is complete
# 0.0 1.0
# The iteration: 479 is complete
# 0.0 1.0
# The iteration: 480 is complete
# 0.0 1.0
# The iteration: 481 is complete
# 0.0 1.0
# The iteration: 482 is complete
# 0.0 1.0
# The iteration: 483 is complete
# 0.0 1.0
# The iteration: 484 is complete
# 0.0 1.0
# The iteration: 485 is complete
# 0.0 1.0
# The iteration: 486 is complete
# 0.0 1.0
# The iteration: 487 is complete
# 0.0 1.0
# The iteration: 488 is complete
# 0.0 1.0
# The iteration: 489 is complete
# 0.0 1.0
# The iteration: 490 is complete
# 0.0 1.0
# The iteration: 491 is complete
# 0.0 1.0
# The iteration: 492 is complete
# 0.0 1.0
# The iteration: 493 is complete
# 0.0 1.0
# The iteration: 494 is complete
# 0.0 1.0
# The iteration: 495 is complete
# 0.0 1.0
# The iteration: 496 is complete
# 0.0 1.0
# The iteration: 497 is complete
# 0.0 1.0
# The iteration: 498 is complete
# 0.0 1.0
# The iteration: 499 is complete
# 0.0 1.0
# The iteration: 500 is complete
# 0.0 1.0
# The iteration: 501 is complete
# 0.0 1.0
# The iteration: 502 is complete
# 0.0 1.0
# The iteration: 503 is complete
# 0.0 1.0
# The iteration: 504 is complete
# 0.0 1.0
# The iteration: 505 is complete
# 0.0 1.0
# The iteration: 506 is complete
# 0.0 1.0
# The iteration: 507 is complete
# 0.0 1.0
# The iteration: 508 is complete
# 0.0 1.0
# The iteration: 509 is complete
# 0.0 1.0
# The iteration: 510 is complete
# 0.0 1.0
# The iteration: 511 is complete
# 0.0 1.0
# The iteration: 512 is complete
# 0.0 1.0
# The iteration: 513 is complete
# 0.0 1.0
# The iteration: 514 is complete
# 0.0 1.0
# The iteration: 515 is complete
# 0.0 1.0
# The iteration: 516 is complete
# 0.0 1.0
# The iteration: 517 is complete
# 0.0 1.0
# The iteration: 518 is complete
# 0.0 1.0
# The iteration: 519 is complete
# 0.0 1.0
# The iteration: 520 is complete
# 0.0 1.0
# The iteration: 521 is complete
# 0.0 1.0
# The iteration: 522 is complete
# 0.0 1.0
# The iteration: 523 is complete
# 0.0 1.0
# The iteration: 524 is complete
# 0.0 1.0
# The iteration: 525 is complete
# 0.0 1.0
# The iteration: 526 is complete
# 0.0 1.0
# The iteration: 527 is complete
# 0.0 1.0
# The iteration: 528 is complete
# 0.0 1.0
# The iteration: 529 is complete
# 0.0 1.0
# The iteration: 530 is complete
# 0.0 1.0
# The iteration: 531 is complete
# 0.0 1.0
# The iteration: 532 is complete
# 0.0 1.0
# The iteration: 533 is complete
# 0.0 1.0
# The iteration: 534 is complete
# 0.0 1.0
# The iteration: 535 is complete
# 0.0 1.0
# The iteration: 536 is complete
# 0.0 1.0
# The iteration: 537 is complete
# 0.0 1.0
# The iteration: 538 is complete
# 0.0 1.0
# The iteration: 539 is complete
# 0.0 1.0
# The iteration: 540 is complete
# 0.0 1.0
# The iteration: 541 is complete
# 0.0 1.0
# The iteration: 542 is complete
# 0.0 1.0
# The iteration: 543 is complete
# 0.0 1.0
# The iteration: 544 is complete
# 0.0 1.0
# The iteration: 545 is complete
# 0.0 1.0
# The iteration: 546 is complete
# 0.0 1.0
# The iteration: 547 is complete
# 0.0 1.0
# The iteration: 548 is complete
# 0.0 1.0
# The iteration: 549 is complete
# 0.0 1.0
# The iteration: 550 is complete
# 0.0 1.0
# The iteration: 551 is complete
# 0.0 1.0
# The iteration: 552 is complete
# 0.0 1.0
# The iteration: 553 is complete
# 0.0 1.0
# The iteration: 554 is complete
# 0.0 1.0
# The iteration: 555 is complete
# 0.0 1.0
# The iteration: 556 is complete
# 0.0 1.0
# The iteration: 557 is complete
# 0.0 1.0
# The iteration: 558 is complete
# 0.0 1.0
# The iteration: 559 is complete
# 0.0 1.0
# The iteration: 560 is complete
# 0.0 1.0
# The iteration: 561 is complete
# 0.0 1.0
# The iteration: 562 is complete
# 0.0 1.0
# The iteration: 563 is complete
# 0.0 1.0
# The iteration: 564 is complete
# 0.0 1.0
# The iteration: 565 is complete
# 0.0 1.0
# The iteration: 566 is complete
# 0.0 1.0
# The iteration: 567 is complete
# 0.0 1.0
# The iteration: 568 is complete
# 0.0 1.0
# The iteration: 569 is complete
# 0.0 1.0
# The iteration: 570 is complete
# 0.0 1.0
# The iteration: 571 is complete
# 0.0 1.0
# The iteration: 572 is complete
# 0.0 1.0
# The iteration: 573 is complete
# 0.0 1.0
# The iteration: 574 is complete
# 0.0 1.0
# The iteration: 575 is complete
# 0.0 1.0
# The iteration: 576 is complete
# 0.0 1.0
# The iteration: 577 is complete
# 0.0 1.0
# The iteration: 578 is complete
# 0.0 1.0
# The iteration: 579 is complete
# 0.0 1.0
# The iteration: 580 is complete
# 0.0 1.0
# The iteration: 581 is complete
# 0.0 1.0
# The iteration: 582 is complete
# 0.0 1.0
# The iteration: 583 is complete
# 0.0 1.0
# The iteration: 584 is complete
# 0.0 1.0
# The iteration: 585 is complete
# 0.0 1.0
# The iteration: 586 is complete
# 0.0 1.0
# The iteration: 587 is complete
# 0.0 1.0
# The iteration: 588 is complete
# 0.0 1.0
# The iteration: 589 is complete
# 0.0 1.0
# The iteration: 590 is complete
# 0.0 1.0
# The iteration: 591 is complete
# 0.0 1.0
# The iteration: 592 is complete
# 0.0 1.0
# The iteration: 593 is complete
# 0.0 1.0
# The iteration: 594 is complete
# 0.0 1.0
# The iteration: 595 is complete
# 0.0 1.0
# The iteration: 596 is complete
# 0.0 1.0
# The iteration: 597 is complete
# 0.0 1.0
# The iteration: 598 is complete
# 0.0 1.0
# The iteration: 599 is complete
# 0.0 1.0
# The iteration: 600 is complete
# 0.0 1.0
# The iteration: 601 is complete
# 0.0 1.0
# The iteration: 602 is complete
# 0.0 1.0
# The iteration: 603 is complete
# 0.0 1.0
# The iteration: 604 is complete
# 0.0 1.0
# The iteration: 605 is complete
# 0.0 1.0
# The iteration: 606 is complete
# 0.0 1.0
# The iteration: 607 is complete
# 0.0 1.0
# The iteration: 608 is complete
# 0.0 1.0
# The iteration: 609 is complete
# 0.0 1.0
# The iteration: 610 is complete
# 0.0 1.0
# The iteration: 611 is complete
# 0.0 1.0
# The iteration: 612 is complete
# 0.0 1.0
# The iteration: 613 is complete
# 0.0 1.0
# The iteration: 614 is complete
# 0.0 1.0
# The iteration: 615 is complete
# 0.0 1.0
# The iteration: 616 is complete
# 0.0 1.0
# The iteration: 617 is complete
# 0.0 1.0
# The iteration: 618 is complete
# 0.0 1.0
# The iteration: 619 is complete
# 0.0 1.0
# The iteration: 620 is complete
# 0.0 1.0
# The iteration: 621 is complete
# 0.0 1.0
# The iteration: 622 is complete
# 0.0 1.0
# The iteration: 623 is complete
# 0.0 1.0
# The iteration: 624 is complete
# 0.0 1.0
# The iteration: 625 is complete
# 0.0 1.0
# The iteration: 626 is complete
# 0.0 1.0
# The iteration: 627 is complete
# 0.0 1.0
# The iteration: 628 is complete
# 0.0 1.0
# The iteration: 629 is complete
# 0.0 1.0
# The iteration: 630 is complete
# 0.0 1.0
# The iteration: 631 is complete
# 0.0 1.0
# The iteration: 632 is complete
# 0.0 1.0
# The iteration: 633 is complete
# 0.0 1.0
# The iteration: 634 is complete
# 0.0 1.0
# The iteration: 635 is complete
# 0.0 1.0
# The iteration: 636 is complete
# 0.0 1.0
# The iteration: 637 is complete
# 0.0 1.0
# The iteration: 638 is complete
# 0.0 1.0
# The iteration: 639 is complete
# 0.0 1.0
# The iteration: 640 is complete
# 0.0 1.0
# The iteration: 641 is complete
# 0.0 1.0
# The iteration: 642 is complete
# 0.0 1.0
# The iteration: 643 is complete
# 0.0 1.0
# The iteration: 644 is complete
# 0.0 1.0
# The iteration: 645 is complete
# 0.0 1.0
# The iteration: 646 is complete
# 0.0 1.0
# The iteration: 647 is complete
# 0.0 1.0
# The iteration: 648 is complete
# 0.0 1.0
# The iteration: 649 is complete
# 0.0 1.0
# The iteration: 650 is complete
# 0.0 1.0
# The iteration: 651 is complete
# 0.0 1.0
# The iteration: 652 is complete
# 0.0 1.0
# The iteration: 653 is complete
# 0.0 1.0
# The iteration: 654 is complete
# 0.0 1.0
# The iteration: 655 is complete
# 0.0 1.0
# The iteration: 656 is complete
# 0.0 1.0
# The iteration: 657 is complete
# 0.0 1.0
# The iteration: 658 is complete
# 0.0 1.0
# The iteration: 659 is complete
# 0.0 1.0
# The iteration: 660 is complete
# 0.0 1.0
# The iteration: 661 is complete
# 0.0 1.0
# The iteration: 662 is complete
# 0.0 1.0
# The iteration: 663 is complete
# 0.0 1.0
# The iteration: 664 is complete
# 0.0 1.0
# The iteration: 665 is complete
# 0.0 1.0
# The iteration: 666 is complete
# 0.0 1.0
# The iteration: 667 is complete
# 0.0 1.0
# The iteration: 668 is complete
# 0.0 1.0
# The iteration: 669 is complete
# 0.0 1.0
# The iteration: 670 is complete
# 0.0 1.0
# The iteration: 671 is complete
# 0.0 1.0
# The iteration: 672 is complete
# 0.0 1.0
# The iteration: 673 is complete
# 0.0 1.0
# The iteration: 674 is complete
# 0.0 1.0
# The iteration: 675 is complete
# 0.0 1.0
# The iteration: 676 is complete
# 0.0 1.0
# The iteration: 677 is complete
# 0.0 1.0
# The iteration: 678 is complete
# 0.0 1.0
# The iteration: 679 is complete
# 0.0 1.0
# The iteration: 680 is complete
# 0.0 1.0
# The iteration: 681 is complete
# 0.0 1.0
# The iteration: 682 is complete
# 0.0 1.0
# The iteration: 683 is complete
# 0.0 1.0
# The iteration: 684 is complete
# 0.0 1.0
# The iteration: 685 is complete
# 0.0 1.0
# The iteration: 686 is complete
# 0.0 1.0
# The iteration: 687 is complete
# 0.0 1.0
# The iteration: 688 is complete
# 0.0 1.0
# The iteration: 689 is complete
# 0.0 1.0
# The iteration: 690 is complete
# 0.0 1.0
# The iteration: 691 is complete
# 0.0 1.0
# The iteration: 692 is complete
# 0.0 1.0
# The iteration: 693 is complete
# 0.0 1.0
# The iteration: 694 is complete
# 0.0 1.0
# The iteration: 695 is complete
# 0.0 1.0
# The iteration: 696 is complete
# 0.0 1.0
# The iteration: 697 is complete
# 0.0 1.0
# The iteration: 698 is complete
# 0.0 1.0
# The iteration: 699 is complete
# 0.0 1.0
# The iteration: 700 is complete
# 0.0 1.0
# The iteration: 701 is complete
# 0.0 1.0
# The iteration: 702 is complete
# 0.0 1.0
# The iteration: 703 is complete
# 0.0 1.0
# The iteration: 704 is complete
# 0.0 1.0
# The iteration: 705 is complete
# 0.0 1.0
# The iteration: 706 is complete
# 0.0 1.0
# The iteration: 707 is complete
# 0.0 1.0
# The iteration: 708 is complete
# 0.0 1.0
# The iteration: 709 is complete
# 0.0 1.0
# The iteration: 710 is complete
# 0.0 1.0
# The iteration: 711 is complete
# 0.0 1.0
# The iteration: 712 is complete
# 0.0 1.0
# The iteration: 713 is complete
# 0.0 1.0
# The iteration: 714 is complete
# 0.0 1.0
# The iteration: 715 is complete
# 0.0 1.0
# The iteration: 716 is complete
# 0.0 1.0
# The iteration: 717 is complete
# 0.0 1.0
# The iteration: 718 is complete
# 0.0 1.0
# The iteration: 719 is complete
# 0.0 1.0
# The iteration: 720 is complete
# 0.0 1.0
# The iteration: 721 is complete
# 0.0 1.0
# The iteration: 722 is complete
# 0.0 1.0
# The iteration: 723 is complete
# 0.0 1.0
# The iteration: 724 is complete
# 0.0 1.0
# The iteration: 725 is complete
# 0.0 1.0
# The iteration: 726 is complete
# 0.0 1.0
# The iteration: 727 is complete
# 0.0 1.0
# The iteration: 728 is complete
# 0.0 1.0
# The iteration: 729 is complete
# 0.0 1.0
# The iteration: 730 is complete
# 0.0 1.0
# The iteration: 731 is complete
# 0.0 1.0
# The iteration: 732 is complete
# 0.0 1.0
# The iteration: 733 is complete
# 0.0 1.0
# The iteration: 734 is complete
# 0.0 1.0
# The iteration: 735 is complete
# 0.0 1.0
# The iteration: 736 is complete
# 0.0 1.0
# The iteration: 737 is complete
# 0.0 1.0
# The iteration: 738 is complete
# 0.0 1.0
# The iteration: 739 is complete
# 0.0 1.0
# The iteration: 740 is complete
# 0.0 1.0
# The iteration: 741 is complete
# 0.0 1.0
# The iteration: 742 is complete
# 0.0 1.0
# The iteration: 743 is complete
# 0.0 1.0
# The iteration: 744 is complete
# 0.0 1.0
# The iteration: 745 is complete
# 0.0 1.0
# The iteration: 746 is complete
# 0.0 1.0
# The iteration: 747 is complete
# 0.0 1.0
# The iteration: 748 is complete
# 0.0 1.0
# The iteration: 749 is complete
# 0.0 1.0
# The iteration: 750 is complete
# 0.0 1.0
# The iteration: 751 is complete
# 0.0 1.0
# The iteration: 752 is complete
# 0.0 1.0
# The iteration: 753 is complete
# 0.0 1.0
# The iteration: 754 is complete
# 0.0 1.0
# The iteration: 755 is complete
# 0.0 1.0
# The iteration: 756 is complete
# 0.0 1.0
# The iteration: 757 is complete
# 0.0 1.0
# The iteration: 758 is complete
# 0.0 1.0
# The iteration: 759 is complete
# 0.0 1.0
# The iteration: 760 is complete
# 0.0 1.0
# The iteration: 761 is complete
# 0.0 1.0
# The iteration: 762 is complete
# 0.0 1.0
# The iteration: 763 is complete
# 0.0 1.0
# The iteration: 764 is complete
# 0.0 1.0
# The iteration: 765 is complete
# 0.0 1.0
# The iteration: 766 is complete
# 0.0 1.0
# The iteration: 767 is complete
# 0.0 1.0
# The iteration: 768 is complete
# 0.0 1.0
# The iteration: 769 is complete
# 0.0 1.0
# The iteration: 770 is complete
# 0.0 1.0
# The iteration: 771 is complete
# 0.0 1.0
# The iteration: 772 is complete
# 0.0 1.0
# The iteration: 773 is complete
# 0.0 1.0
# The iteration: 774 is complete
# 0.0 1.0
# The iteration: 775 is complete
# 0.0 1.0
# The iteration: 776 is complete
# 0.0 1.0
# The iteration: 777 is complete
# 0.0 1.0
# The iteration: 778 is complete
# 0.0 1.0
# The iteration: 779 is complete
# 0.0 1.0
# The iteration: 780 is complete
# 0.0 1.0
# The iteration: 781 is complete
# 0.0 1.0
# The iteration: 782 is complete
# 0.0 1.0
# The iteration: 783 is complete
# 0.0 1.0
# The iteration: 784 is complete
# 0.0 1.0
# The iteration: 785 is complete
# 0.0 1.0
# The iteration: 786 is complete
# 0.0 1.0
# The iteration: 787 is complete
# 0.0 1.0
# The iteration: 788 is complete
# 0.0 1.0
# The iteration: 789 is complete
# 0.0 1.0
# The iteration: 790 is complete
# 0.0 1.0
# The iteration: 791 is complete
# 0.0 1.0
# The iteration: 792 is complete
# 0.0 1.0
# The iteration: 793 is complete
# 0.0 1.0
# The iteration: 794 is complete
# 0.0 1.0
# The iteration: 795 is complete
# 0.0 1.0
# The iteration: 796 is complete
# 0.0 1.0
# The iteration: 797 is complete
# 0.0 1.0
# The iteration: 798 is complete
# 0.0 1.0
# The iteration: 799 is complete
# 0.0 1.0
# The iteration: 800 is complete
# 0.0 1.0
# The iteration: 801 is complete
# 0.0 1.0
# The iteration: 802 is complete
# 0.0 1.0
# The iteration: 803 is complete
# 0.0 1.0
# The iteration: 804 is complete
# 0.0 1.0
# The iteration: 805 is complete
# 0.0 1.0
# The iteration: 806 is complete
# 0.0 1.0
# The iteration: 807 is complete
# 0.0 1.0
# The iteration: 808 is complete
# 0.0 1.0
# The iteration: 809 is complete
# 0.0 1.0
# The iteration: 810 is complete
# 0.0 1.0
# The iteration: 811 is complete
# 0.0 1.0
# The iteration: 812 is complete
# 0.0 1.0
# The iteration: 813 is complete
# 0.0 1.0
# The iteration: 814 is complete
# 0.0 1.0
# The iteration: 815 is complete
# 0.0 1.0
# The iteration: 816 is complete
# 0.0 1.0
# The iteration: 817 is complete
# 0.0 1.0
# The iteration: 818 is complete
# 0.0 1.0
# The iteration: 819 is complete
# 0.0 1.0
# The iteration: 820 is complete
# 0.0 1.0
# The iteration: 821 is complete
# 0.0 1.0
# The iteration: 822 is complete
# 0.0 1.0
# The iteration: 823 is complete
# 0.0 1.0
# The iteration: 824 is complete
# 0.0 1.0
# The iteration: 825 is complete
# 0.0 1.0
# The iteration: 826 is complete
# 0.0 1.0
# The iteration: 827 is complete
# 0.0 1.0
# The iteration: 828 is complete
# 0.0 1.0
# The iteration: 829 is complete
# 0.0 1.0
# The iteration: 830 is complete
# 0.0 1.0
# The iteration: 831 is complete
# 0.0 1.0
# The iteration: 832 is complete
# 0.0 1.0
# The iteration: 833 is complete
# 0.0 1.0
# The iteration: 834 is complete
# 0.0 1.0
# The iteration: 835 is complete
# 0.0 1.0
# The iteration: 836 is complete
# 0.0 1.0
# The iteration: 837 is complete
# 0.0 1.0
# The iteration: 838 is complete
# 0.0 1.0
# The iteration: 839 is complete
# 0.0 1.0
# The iteration: 840 is complete
# 0.0 1.0
# The iteration: 841 is complete
# 0.0 1.0
# The iteration: 842 is complete
# 0.0 1.0
# The iteration: 843 is complete
# 0.0 1.0
# The iteration: 844 is complete
# 0.0 1.0
# The iteration: 845 is complete
# 0.0 1.0
# The iteration: 846 is complete
# 0.0 1.0
# The iteration: 847 is complete
# 0.0 1.0
# The iteration: 848 is complete
# 0.0 1.0
# The iteration: 849 is complete
# 0.0 1.0
# The iteration: 850 is complete
# 0.0 1.0
# The iteration: 851 is complete
# 0.0 1.0
# The iteration: 852 is complete
# 0.0 1.0
# The iteration: 853 is complete
# 0.0 1.0
# The iteration: 854 is complete
# 0.0 1.0
# The iteration: 855 is complete
# 0.0 1.0
# The iteration: 856 is complete
# 0.0 1.0
# The iteration: 857 is complete
# 0.0 1.0
# The iteration: 858 is complete
# 0.0 1.0
# The iteration: 859 is complete
# 0.0 1.0
# The iteration: 860 is complete
# 0.0 1.0
# The iteration: 861 is complete
# 0.0 1.0
# The iteration: 862 is complete
# 0.0 1.0
# The iteration: 863 is complete
# 0.0 1.0
# The iteration: 864 is complete
# 0.0 1.0
# The iteration: 865 is complete
# 0.0 1.0
# The iteration: 866 is complete
# 0.0 1.0
# The iteration: 867 is complete
# 0.0 1.0
# The iteration: 868 is complete
# 0.0 1.0
# The iteration: 869 is complete
# 0.0 1.0
# The iteration: 870 is complete
# 0.0 1.0
# The iteration: 871 is complete
# 0.0 1.0
# The iteration: 872 is complete
# 0.0 1.0
# The iteration: 873 is complete
# 0.0 1.0
# The iteration: 874 is complete
# 0.0 1.0
# The iteration: 875 is complete
# 0.0 1.0
# The iteration: 876 is complete
# 0.0 1.0
# The iteration: 877 is complete
# 0.0 1.0
# The iteration: 878 is complete
# 0.0 1.0
# The iteration: 879 is complete
# 0.0 1.0
# The iteration: 880 is complete
# 0.0 1.0
# The iteration: 881 is complete
# 0.0 1.0
# The iteration: 882 is complete
# 0.0 1.0
# The iteration: 883 is complete
# 0.0 1.0
# The iteration: 884 is complete
# 0.0 1.0
# The iteration: 885 is complete
# 0.0 1.0
# The iteration: 886 is complete
# 0.0 1.0
# The iteration: 887 is complete
# 0.0 1.0
# The iteration: 888 is complete
# 0.0 1.0
# The iteration: 889 is complete
# 0.0 1.0
# The iteration: 890 is complete
# 0.0 1.0
# The iteration: 891 is complete
# 0.0 1.0
# The iteration: 892 is complete
# 0.0 1.0
# The iteration: 893 is complete
# 0.0 1.0
# The iteration: 894 is complete
# 0.0 1.0
# The iteration: 895 is complete
# 0.0 1.0
# The iteration: 896 is complete
# 0.0 1.0
# The iteration: 897 is complete
# 0.0 1.0
# The iteration: 898 is complete
# 0.0 1.0
# The iteration: 899 is complete
# 0.0 1.0
# The iteration: 900 is complete
# 0.0 1.0
# The iteration: 901 is complete
# 0.0 1.0
# The iteration: 902 is complete
# 0.0 1.0
# The iteration: 903 is complete
# 0.0 1.0
# The iteration: 904 is complete
# 0.0 1.0
# The iteration: 905 is complete
# 0.0 1.0
# The iteration: 906 is complete
# 0.0 1.0
# The iteration: 907 is complete
# 0.0 1.0
# The iteration: 908 is complete
# 0.0 1.0
# The iteration: 909 is complete
# 0.0 1.0
# The iteration: 910 is complete
# 0.0 1.0
# The iteration: 911 is complete
# 0.0 1.0
# The iteration: 912 is complete
# 0.0 1.0
# The iteration: 913 is complete
# 0.0 1.0
# The iteration: 914 is complete
# 0.0 1.0
# The iteration: 915 is complete
# 0.0 1.0
# The iteration: 916 is complete
# 0.0 1.0
# The iteration: 917 is complete
# 0.0 1.0
# The iteration: 918 is complete
# 0.0 1.0
# The iteration: 919 is complete
# 0.0 1.0
# The iteration: 920 is complete
# 0.0 1.0
# The iteration: 921 is complete
# 0.0 1.0
# The iteration: 922 is complete
# 0.0 1.0
# The iteration: 923 is complete
# 0.0 1.0
# The iteration: 924 is complete
# 0.0 1.0
# The iteration: 925 is complete
# 0.0 1.0
# The iteration: 926 is complete
# 0.0 1.0
# The iteration: 927 is complete
# 0.0 1.0
# The iteration: 928 is complete
# 0.0 1.0
# The iteration: 929 is complete
# 0.0 1.0
# The iteration: 930 is complete
# 0.0 1.0
# The iteration: 931 is complete
# 0.0 1.0
# The iteration: 932 is complete
# 0.0 1.0
# The iteration: 933 is complete
# 0.0 1.0
# The iteration: 934 is complete
# 0.0 1.0
# The iteration: 935 is complete
# 0.0 1.0
# The iteration: 936 is complete
# 0.0 1.0
# The iteration: 937 is complete
# 0.0 1.0
# The iteration: 938 is complete
# 0.0 1.0
# The iteration: 939 is complete
# 0.0 1.0
# The iteration: 940 is complete
# 0.0 1.0
# The iteration: 941 is complete
# 0.0 1.0
# The iteration: 942 is complete
# 0.0 1.0
# The iteration: 943 is complete
# 0.0 1.0
# The iteration: 944 is complete
# 0.0 1.0
# The iteration: 945 is complete
# 0.0 1.0
# The iteration: 946 is complete
# 0.0 1.0
# The iteration: 947 is complete
# 0.0 1.0
# The iteration: 948 is complete
# 0.0 1.0
# The iteration: 949 is complete
# 0.0 1.0
# The iteration: 950 is complete
# 0.0 1.0
# The iteration: 951 is complete
# 0.0 1.0
# The iteration: 952 is complete
# 0.0 1.0
# The iteration: 953 is complete
# 0.0 1.0
# The iteration: 954 is complete
# 0.0 1.0
# The iteration: 955 is complete
# 0.0 1.0
# The iteration: 956 is complete
# 0.0 1.0
# The iteration: 957 is complete
# 0.0 1.0
# The iteration: 958 is complete
# 0.0 1.0
# The iteration: 959 is complete
# 0.0 1.0
# The iteration: 960 is complete
# 0.0 1.0
# The iteration: 961 is complete
# 0.0 1.0
# The iteration: 962 is complete
# 0.0 1.0
# The iteration: 963 is complete
# 0.0 1.0
# The iteration: 964 is complete
# 0.0 1.0
# The iteration: 965 is complete
# 0.0 1.0
# The iteration: 966 is complete
# 0.0 1.0
# The iteration: 967 is complete
# 0.0 1.0
# The iteration: 968 is complete
# 0.0 1.0
# The iteration: 969 is complete
# 0.0 1.0
# The iteration: 970 is complete
# 0.0 1.0
# The iteration: 971 is complete
# 0.0 1.0
# The iteration: 972 is complete
# 0.0 1.0
# The iteration: 973 is complete
# 0.0 1.0
# The iteration: 974 is complete
# 0.0 1.0
# The iteration: 975 is complete
# 0.0 1.0
# The iteration: 976 is complete
# 0.0 1.0
# The iteration: 977 is complete
# 0.0 1.0
# The iteration: 978 is complete
# 0.0 1.0
# The iteration: 979 is complete
# 0.0 1.0
# The iteration: 980 is complete
# 0.0 1.0
# The iteration: 981 is complete
# 0.0 1.0
# The iteration: 982 is complete
# 0.0 1.0
# The iteration: 983 is complete
# 0.0 1.0
# The iteration: 984 is complete
# 0.0 1.0
# The iteration: 985 is complete
# 0.0 1.0
# The iteration: 986 is complete
# 0.0 1.0
# The iteration: 987 is complete
# 0.0 1.0
# The iteration: 988 is complete
# 0.0 1.0
# The iteration: 989 is complete
# 0.0 1.0
# The iteration: 990 is complete
# 0.0 1.0
# The iteration: 991 is complete
# 0.0 1.0
# The iteration: 992 is complete
# 0.0 1.0
# The iteration: 993 is complete
# 0.0 1.0
# The iteration: 994 is complete
# 0.0 1.0
# The iteration: 995 is complete
# 0.0 1.0
# The iteration: 996 is complete
# 0.0 1.0
# The iteration: 997 is complete
# 0.0 1.0
# The iteration: 998 is complete
# 0.0 1.0
# The iteration: 999 is complete
# 0.0 1.0
# The iteration: 1000 is complete
# 0.0 1.0
# The iteration: 1001 is complete
# 0.0 1.0
# The iteration: 1002 is complete
# 0.0 1.0
# The iteration: 1003 is complete
# 0.0 1.0
# The iteration: 1004 is complete
# 0.0 1.0
# The iteration: 1005 is complete
# 0.0 1.0
# The iteration: 1006 is complete
# 0.0 1.0
# The iteration: 1007 is complete
# 0.0 1.0
# The iteration: 1008 is complete
# 0.0 1.0
# The iteration: 1009 is complete
# 0.0 1.0
# The iteration: 1010 is complete
# 0.0 1.0
# The iteration: 1011 is complete
# 0.0 1.0
# The iteration: 1012 is complete
# 0.0 1.0
# The iteration: 1013 is complete
# 0.0 1.0
# The iteration: 1014 is complete
# 0.0 1.0
# The iteration: 1015 is complete
# 0.0 1.0
# The iteration: 1016 is complete
# 0.0 1.0
# The iteration: 1017 is complete
# 0.0 1.0
# The iteration: 1018 is complete
# 0.0 1.0
# The iteration: 1019 is complete
# 0.0 1.0
# The iteration: 1020 is complete
# 0.0 1.0
# The iteration: 1021 is complete
# 0.0 1.0
# The iteration: 1022 is complete
# 0.0 1.0
# The iteration: 1023 is complete
# 0.0 1.0
# The iteration: 1024 is complete
# 0.0 1.0
# The iteration: 1025 is complete
# 0.0 1.0
# The iteration: 1026 is complete
# 0.0 1.0
# The iteration: 1027 is complete
# 0.0 1.0
# The iteration: 1028 is complete
# 0.0 1.0
# The iteration: 1029 is complete
# 0.0 1.0
# The iteration: 1030 is complete
# 0.0 1.0
# The iteration: 1031 is complete
# 0.0 1.0
# The iteration: 1032 is complete
# 0.0 1.0
# The iteration: 1033 is complete
# 0.0 1.0
# The iteration: 1034 is complete
# 0.0 1.0
# The iteration: 1035 is complete
# 0.0 1.0
# The iteration: 1036 is complete
# 0.0 1.0
# The iteration: 1037 is complete
# 0.0 1.0
# The iteration: 1038 is complete
# 0.0 1.0
# The iteration: 1039 is complete
# 0.0 1.0
# The iteration: 1040 is complete
# 0.0 1.0
# The iteration: 1041 is complete
# 0.0 1.0
# The iteration: 1042 is complete
# 0.0 1.0
# The iteration: 1043 is complete
# 0.0 1.0
# The iteration: 1044 is complete
# 0.0 1.0
# The iteration: 1045 is complete
# 0.0 1.0
# The iteration: 1046 is complete
# 0.0 1.0
# The iteration: 1047 is complete
# 0.0 1.0
# The iteration: 1048 is complete
# 0.0 1.0
# The iteration: 1049 is complete
# 0.0 1.0
# The iteration: 1050 is complete
# 0.0 1.0
# The iteration: 1051 is complete
# 0.0 1.0
# The iteration: 1052 is complete
# 0.0 1.0
# The iteration: 1053 is complete
# 0.0 1.0
# The iteration: 1054 is complete
# 0.0 1.0
# The iteration: 1055 is complete
# 0.0 1.0
# The iteration: 1056 is complete
# 0.0 1.0
# The iteration: 1057 is complete
# 0.0 1.0
# The iteration: 1058 is complete
# 0.0 1.0
# The iteration: 1059 is complete
# 0.0 1.0
# The iteration: 1060 is complete
# 0.0 1.0
# The iteration: 1061 is complete
# 0.0 1.0
# The iteration: 1062 is complete
# 0.0 1.0
# The iteration: 1063 is complete
# 0.0 1.0
# The iteration: 1064 is complete
# 0.0 1.0
# The iteration: 1065 is complete
# 0.0 1.0
# The iteration: 1066 is complete
# 0.0 1.0
# The iteration: 1067 is complete
# 0.0 1.0
# The iteration: 1068 is complete
# 0.0 1.0
# The iteration: 1069 is complete
# 0.0 1.0
# The iteration: 1070 is complete
# 0.0 1.0
# The iteration: 1071 is complete
# 0.0 1.0
# The iteration: 1072 is complete
# 0.0 1.0
# The iteration: 1073 is complete
# 0.0 1.0
# The iteration: 1074 is complete
# 0.0 1.0
# The iteration: 1075 is complete
# 0.0 1.0
# The iteration: 1076 is complete
# 0.0 1.0
# The iteration: 1077 is complete
# 0.0 1.0
# The iteration: 1078 is complete
# 0.0 1.0
# The iteration: 1079 is complete
# 0.0 1.0
# The iteration: 1080 is complete
# 0.0 1.0
# The iteration: 1081 is complete
# 0.0 1.0
# The iteration: 1082 is complete
# 0.0 1.0
# The iteration: 1083 is complete
# 0.0 1.0
# The iteration: 1084 is complete
# 0.0 1.0
# The iteration: 1085 is complete
# 0.0 1.0
# The iteration: 1086 is complete
# 0.0 1.0
# The iteration: 1087 is complete
# 0.0 1.0
# The iteration: 1088 is complete
# 0.0 1.0
# The iteration: 1089 is complete
# 0.0 1.0
# The iteration: 1090 is complete
# 0.0 1.0
# The iteration: 1091 is complete
# 0.0 1.0
# The iteration: 1092 is complete
# 0.0 1.0
# The iteration: 1093 is complete
# 0.0 1.0
# The iteration: 1094 is complete
# 0.0 1.0
# The iteration: 1095 is complete
# 0.0 1.0
# The iteration: 1096 is complete
# 0.0 1.0
# The iteration: 1097 is complete
# 0.0 1.0
# The iteration: 1098 is complete
# 0.0 1.0
# The iteration: 1099 is complete
# 0.0 1.0
# The iteration: 1100 is complete
# 0.0 1.0
# The iteration: 1101 is complete
# 0.0 1.0
# The iteration: 1102 is complete
# 0.0 1.0
# The iteration: 1103 is complete
# 0.0 1.0
# The iteration: 1104 is complete
# 0.0 1.0
# The iteration: 1105 is complete
# 0.0 1.0
# The iteration: 1106 is complete
# 0.0 1.0
# The iteration: 1107 is complete
# 0.0 1.0
# The iteration: 1108 is complete
# 0.0 1.0
# The iteration: 1109 is complete
# 0.0 1.0
# The iteration: 1110 is complete
# 0.0 1.0
# The iteration: 1111 is complete
# 0.0 1.0
# The iteration: 1112 is complete
# 0.0 1.0
# The iteration: 1113 is complete
# 0.0 1.0
# The iteration: 1114 is complete
# 0.0 1.0
# The iteration: 1115 is complete
# 0.0 1.0
# The iteration: 1116 is complete
# 0.0 1.0
# The iteration: 1117 is complete
# 0.0 1.0
# The iteration: 1118 is complete
# 0.0 1.0
# The iteration: 1119 is complete
# 0.0 1.0
# The iteration: 1120 is complete
# 0.0 1.0
# The iteration: 1121 is complete
# 0.0 1.0
# The iteration: 1122 is complete
# 0.0 1.0
# The iteration: 1123 is complete
# 0.0 1.0
# The iteration: 1124 is complete
# 0.0 1.0
# The iteration: 1125 is complete
# 0.0 1.0
# The iteration: 1126 is complete
# 0.0 1.0
# The iteration: 1127 is complete
# 0.0 1.0
# The iteration: 1128 is complete
# 0.0 1.0
# The iteration: 1129 is complete
# 0.0 1.0
# The iteration: 1130 is complete
# 0.0 1.0
# The iteration: 1131 is complete
# 0.0 1.0
# The iteration: 1132 is complete
# 0.0 1.0
# The iteration: 1133 is complete
# 0.0 1.0
# The iteration: 1134 is complete
# 0.0 1.0
# The iteration: 1135 is complete
# 0.0 1.0
# The iteration: 1136 is complete
# 0.0 1.0
# The iteration: 1137 is complete
# 0.0 1.0
# The iteration: 1138 is complete
# 0.0 1.0
# The iteration: 1139 is complete
# 0.0 1.0
# The iteration: 1140 is complete
# 0.0 1.0
# The iteration: 1141 is complete
# 0.0 1.0
# The iteration: 1142 is complete
# 0.0 1.0
# The iteration: 1143 is complete
# 0.0 1.0
# The iteration: 1144 is complete
# 0.0 1.0
# The iteration: 1145 is complete
# 0.0 1.0
# The iteration: 1146 is complete
# 0.0 1.0
# The iteration: 1147 is complete
# 0.0 1.0
# The iteration: 1148 is complete
# 0.0 1.0
# The iteration: 1149 is complete
# 0.0 1.0
# The iteration: 1150 is complete
# 0.0 1.0
# The iteration: 1151 is complete
# 0.0 1.0
# The iteration: 1152 is complete
# 0.0 1.0
# The iteration: 1153 is complete
# 0.0 1.0
# The iteration: 1154 is complete
# 0.0 1.0
# The iteration: 1155 is complete
# 0.0 1.0
# The iteration: 1156 is complete
# 0.0 1.0
# The iteration: 1157 is complete
# 0.0 1.0
# The iteration: 1158 is complete
# 0.0 1.0
# The iteration: 1159 is complete
# 0.0 1.0
# The iteration: 1160 is complete
# 0.0 1.0
# The iteration: 1161 is complete
# 0.0 1.0
# The iteration: 1162 is complete
# 0.0 1.0
# The iteration: 1163 is complete
# 0.0 1.0
# The iteration: 1164 is complete
# 0.0 1.0
# The iteration: 1165 is complete
# 0.0 1.0
# The iteration: 1166 is complete
# 0.0 1.0
# The iteration: 1167 is complete
# 0.0 1.0
# The iteration: 1168 is complete
# 0.0 1.0
# The iteration: 1169 is complete
# 0.0 1.0
# The iteration: 1170 is complete
# 0.0 1.0
# The iteration: 1171 is complete
# 0.0 1.0
# The iteration: 1172 is complete
# 0.0 1.0
# The iteration: 1173 is complete
# 0.0 1.0
# The iteration: 1174 is complete
# 0.0 1.0
# The iteration: 1175 is complete
# 0.0 1.0
# The iteration: 1176 is complete
# 0.0 1.0
# The iteration: 1177 is complete
# 0.0 1.0
# The iteration: 1178 is complete
# 0.0 1.0
# The iteration: 1179 is complete
# 0.0 1.0
# The iteration: 1180 is complete
# 0.0 1.0
# The iteration: 1181 is complete
# 0.0 1.0
# The iteration: 1182 is complete
# 0.0 1.0
# The iteration: 1183 is complete
# 0.0 1.0
# The iteration: 1184 is complete
# 0.0 1.0
# The iteration: 1185 is complete
# 0.0 1.0
# The iteration: 1186 is complete
# 0.0 1.0
# The iteration: 1187 is complete
# 0.0 1.0
# The iteration: 1188 is complete
# 0.0 1.0
# The iteration: 1189 is complete
# 0.0 1.0
# The iteration: 1190 is complete
# 0.0 1.0
# The iteration: 1191 is complete
# 0.0 1.0
# The iteration: 1192 is complete
# 0.0 1.0
# The iteration: 1193 is complete
# 0.0 1.0
# The iteration: 1194 is complete
# 0.0 1.0
# The iteration: 1195 is complete
# 0.0 1.0
# The iteration: 1196 is complete
# 0.0 1.0
# The iteration: 1197 is complete
# 0.0 1.0
# The iteration: 1198 is complete
# 0.0 1.0
# The iteration: 1199 is complete
# 0.0 1.0
# The iteration: 1200 is complete
# 0.0 1.0
# The iteration: 1201 is complete
# 0.0 1.0
# The iteration: 1202 is complete
# 0.0 1.0
# The iteration: 1203 is complete
# 0.0 1.0
# The iteration: 1204 is complete
# 0.0 1.0
# The iteration: 1205 is complete
# 0.0 1.0
# The iteration: 1206 is complete
# 0.0 1.0
# The iteration: 1207 is complete
# 0.0 1.0
# The iteration: 1208 is complete
# 0.0 1.0
# The iteration: 1209 is complete
# 0.0 1.0
# The iteration: 1210 is complete
# 0.0 1.0
# The iteration: 1211 is complete
# 0.0 1.0
# The iteration: 1212 is complete
# 0.0 1.0
# The iteration: 1213 is complete
# 0.0 1.0
# The iteration: 1214 is complete
# 0.0 1.0
# The iteration: 1215 is complete
# 0.0 1.0
# The iteration: 1216 is complete
# 0.0 1.0
# The iteration: 1217 is complete
# 0.0 1.0
# The iteration: 1218 is complete
# 0.0 1.0
# The iteration: 1219 is complete
# 0.0 1.0
# The iteration: 1220 is complete
# 0.0 1.0
# The iteration: 1221 is complete
# 0.0 1.0
# The iteration: 1222 is complete
# 0.0 1.0
# The iteration: 1223 is complete
# 0.0 1.0
# The iteration: 1224 is complete
# 0.0 1.0
# The iteration: 1225 is complete
# 0.0 1.0
# The iteration: 1226 is complete
# 0.0 1.0
# ...
# The iteration: 2723 is complete
# 0.0 1.0
# The iteration: 2724 is complete
# 0.0 1.0
# The iteration: 2725 is complete
# 0.0 1.0
# The iteration: 2726 is complete
# 0.0 1.0
# The iteration: 2727 is complete
# 0.0 1.0
# The iteration: 2728 is complete
# 0.0 1.0
# The iteration: 2729 is complete
# 0.0 1.0
# The iteration: 2730 is complete
# 0.0 1.0
# The iteration: 2731 is complete
# 0.0 1.0
# The iteration: 2732 is complete
# 0.0 1.0
# The iteration: 2733 is complete
# 0.0 1.0
# The iteration: 2734 is complete
# 0.0 1.0
# The iteration: 2735 is complete
# 0.0 1.0
# The iteration: 2736 is complete
# 0.0 1.0
# The iteration: 2737 is complete
# 0.0 1.0
# The iteration: 2738 is complete
# 0.0 1.0
# The iteration: 2739 is complete
# 0.0 1.0
# The iteration: 2740 is complete
# 0.0 1.0
# The iteration: 2741 is complete
# 0.0 1.0
# The iteration: 2742 is complete
# 0.0 1.0
# The iteration: 2743 is complete
# 0.0 1.0
# The iteration: 2744 is complete
# 0.0 1.0
# The iteration: 2745 is complete
# 0.0 1.0
# The iteration: 2746 is complete
# 0.0 1.0
# The iteration: 2747 is complete
# 0.0 1.0
# The iteration: 2748 is complete
# 0.0 1.0
# The iteration: 2749 is complete
# 0.0 1.0
# The iteration: 2750 is complete
# 0.0 1.0
# The iteration: 2751 is complete
# 0.0 1.0
# The iteration: 2752 is complete
# 0.0 1.0
# The iteration: 2753 is complete
# 0.0 1.0
# The iteration: 2754 is complete
# 0.0 1.0
# The iteration: 2755 is complete
# 0.0 1.0
# The iteration: 2756 is complete
# 0.0 1.0
# The iteration: 2757 is complete
# 0.0 1.0
# The iteration: 2758 is complete
# 0.0 1.0
# The iteration: 2759 is complete
# 0.0 1.0
# The iteration: 2760 is complete
# 0.0 1.0
# The iteration: 2761 is complete
# 0.0 1.0
# The iteration: 2762 is complete
# 0.0 1.0
# The iteration: 2763 is complete
# 0.0 1.0
# The iteration: 2764 is complete
# 0.0 1.0
# The iteration: 2765 is complete
# 0.0 1.0
# The iteration: 2766 is complete
# 0.0 1.0
# The iteration: 2767 is complete
# 0.0 1.0
# The iteration: 2768 is complete
# 0.0 1.0
# The iteration: 2769 is complete
# 0.0 1.0
# The iteration: 2770 is complete
# 0.0 1.0
# The iteration: 2771 is complete
# 0.0 1.0
# The iteration: 2772 is complete
# 0.0 1.0
# The iteration: 2773 is complete
# 0.0 1.0
# The iteration: 2774 is complete
# 0.0 1.0
# The iteration: 2775 is complete
# 0.0 1.0
# The iteration: 2776 is complete
# 0.0 1.0
# The iteration: 2777 is complete
# 0.0 1.0
# The iteration: 2778 is complete
# 0.0 1.0
# The iteration: 2779 is complete
# 0.0 1.0
# The iteration: 2780 is complete
# 0.0 1.0
# The iteration: 2781 is complete
# 0.0 1.0
# The iteration: 2782 is complete
# 0.0 1.0
# The iteration: 2783 is complete
# 0.0 1.0
# The iteration: 2784 is complete
# 0.0 1.0
# The iteration: 2785 is complete
# 0.0 1.0
# The iteration: 2786 is complete
# 0.0 1.0
# The iteration: 2787 is complete
# 0.0 1.0
# The iteration: 2788 is complete
# 0.0 1.0
# The iteration: 2789 is complete
# 0.0 1.0
# The iteration: 2790 is complete
# 0.0 1.0
# The iteration: 2791 is complete
# 0.0 1.0
# The iteration: 2792 is complete
# 0.0 1.0
# The iteration: 2793 is complete
# 0.0 1.0
# The iteration: 2794 is complete
# 0.0 1.0
# The iteration: 2795 is complete
# 0.0 1.0
# The iteration: 2796 is complete
# 0.0 1.0
# The iteration: 2797 is complete
# 0.0 1.0
# The iteration: 2798 is complete
# 0.0 1.0
# The iteration: 2799 is complete
# 0.0 1.0
# The iteration: 2800 is complete
# 0.0 1.0
# The iteration: 2801 is complete
# 0.0 1.0
# The iteration: 2802 is complete
# 0.0 1.0
# The iteration: 2803 is complete
# 0.0 1.0
# The iteration: 2804 is complete
# 0.0 1.0
# The iteration: 2805 is complete
# 0.0 1.0
# The iteration: 2806 is complete
# 0.0 1.0
# The iteration: 2807 is complete
# 0.0 1.0
# The iteration: 2808 is complete
# 0.0 1.0
# The iteration: 2809 is complete
# 0.0 1.0
# The iteration: 2810 is complete
# 0.0 1.0
# The iteration: 2811 is complete
# 0.0 1.0
# The iteration: 2812 is complete
# 0.0 1.0
# The iteration: 2813 is complete
# 0.0 1.0
# The iteration: 2814 is complete
# 0.0 1.0
# The iteration: 2815 is complete
# 0.0 1.0
# The iteration: 2816 is complete
# 0.0 1.0
# The iteration: 2817 is complete
# 0.0 1.0
# The iteration: 2818 is complete
# 0.0 1.0
# The iteration: 2819 is complete
# 0.0 1.0
# The iteration: 2820 is complete
# 0.0 1.0
# The iteration: 2821 is complete
# 0.0 1.0
# The iteration: 2822 is complete
# 0.0 1.0
# The iteration: 2823 is complete
# 0.0 1.0
# The iteration: 2824 is complete
# 0.0 1.0
# The iteration: 2825 is complete
# 0.0 1.0
# The iteration: 2826 is complete
# 0.0 1.0
# The iteration: 2827 is complete
# 0.0 1.0
# The iteration: 2828 is complete
# 0.0 1.0
# The iteration: 2829 is complete
# 0.0 1.0
# The iteration: 2830 is complete
# 0.0 1.0
# The iteration: 2831 is complete
# 0.0 1.0
# The iteration: 2832 is complete
# 0.0 1.0
# The iteration: 2833 is complete
# 0.0 1.0
# The iteration: 2834 is complete
# 0.0 1.0
# The iteration: 2835 is complete
# 0.0 1.0
# The iteration: 2836 is complete
# 0.0 1.0
# The iteration: 2837 is complete
# 0.0 1.0
# The iteration: 2838 is complete
# 0.0 1.0
# The iteration: 2839 is complete
# 0.0 1.0
# The iteration: 2840 is complete
# 0.0 1.0
# The iteration: 2841 is complete
# 0.0 1.0
# The iteration: 2842 is complete
# 0.0 1.0
# The iteration: 2843 is complete
# 0.0 1.0
# The iteration: 2844 is complete
# 0.0 1.0
# The iteration: 2845 is complete
# 0.0 1.0
# The iteration: 2846 is complete
# 0.0 1.0
# The iteration: 2847 is complete
# 0.0 1.0
# The iteration: 2848 is complete
# 0.0 1.0
# The iteration: 2849 is complete
# 0.0 1.0
# The iteration: 2850 is complete
# 0.0 1.0
# The iteration: 2851 is complete
# 0.0 1.0
# The iteration: 2852 is complete
# 0.0 1.0
# The iteration: 2853 is complete
# 0.0 1.0
# The iteration: 2854 is complete
# 0.0 1.0
# The iteration: 2855 is complete
# 0.0 1.0
# The iteration: 2856 is complete
# 0.0 1.0
# The iteration: 2857 is complete
# 0.0 1.0
# The iteration: 2858 is complete
# 0.0 1.0
# The iteration: 2859 is complete
# 0.0 1.0
# The iteration: 2860 is complete
# 0.0 1.0
# The iteration: 2861 is complete
# 0.0 1.0
# The iteration: 2862 is complete
# 0.0 1.0
# The iteration: 2863 is complete
# 0.0 1.0
# The iteration: 2864 is complete
# 0.0 1.0
# The iteration: 2865 is complete
# 0.0 1.0
# The iteration: 2866 is complete
# 0.0 1.0
# The iteration: 2867 is complete
# 0.0 1.0
# The iteration: 2868 is complete
# 0.0 1.0
# The iteration: 2869 is complete
# 0.0 1.0
# The iteration: 2870 is complete
# 0.0 1.0
# The iteration: 2871 is complete
# 0.0 1.0
# The iteration: 2872 is complete
# 0.0 1.0
# The iteration: 2873 is complete
# 0.0 1.0
# The iteration: 2874 is complete
# 0.0 1.0
# The iteration: 2875 is complete
# 0.0 1.0
# The iteration: 2876 is complete
# 0.0 1.0
# The iteration: 2877 is complete
# 0.0 1.0
# The iteration: 2878 is complete
# 0.0 1.0
# The iteration: 2879 is complete
# 0.0 1.0
# The iteration: 2880 is complete
# 0.0 1.0
# The iteration: 2881 is complete
# 0.0 1.0
# The iteration: 2882 is complete
# 0.0 1.0
# The iteration: 2883 is complete
# 0.0 1.0
# The iteration: 2884 is complete
# 0.0 1.0
# The iteration: 2885 is complete
# 0.0 1.0
# The iteration: 2886 is complete
# 0.0 1.0
# The iteration: 2887 is complete
# 0.0 1.0
# The iteration: 2888 is complete
# 0.0 1.0
# The iteration: 2889 is complete
# 0.0 1.0
# The iteration: 2890 is complete
# 0.0 1.0
# The iteration: 2891 is complete
# 0.0 1.0
# The iteration: 2892 is complete
# 0.0 1.0
# The iteration: 2893 is complete
# 0.0 1.0
# The iteration: 2894 is complete
# 0.0 1.0
# The iteration: 2895 is complete
# 0.0 1.0
# The iteration: 2896 is complete
# 0.0 1.0
# The iteration: 2897 is complete
# 0.0 1.0
# The iteration: 2898 is complete
# 0.0 1.0
# The iteration: 2899 is complete
# 0.0 1.0
# The iteration: 2900 is complete
# 0.0 1.0
# The iteration: 2901 is complete
# 0.0 1.0
# The iteration: 2902 is complete
# 0.0 1.0
# The iteration: 2903 is complete
# 0.0 1.0
# The iteration: 2904 is complete
# 0.0 1.0
# The iteration: 2905 is complete
# 0.0 1.0
# The iteration: 2906 is complete
# 0.0 1.0
# The iteration: 2907 is complete
# 0.0 1.0
# The iteration: 2908 is complete
# 0.0 1.0
# The iteration: 2909 is complete
# 0.0 1.0
# The iteration: 2910 is complete
# 0.0 1.0
# The iteration: 2911 is complete
# 0.0 1.0
# The iteration: 2912 is complete
# 0.0 1.0
# The iteration: 2913 is complete
# 0.0 1.0
# The iteration: 2914 is complete
# 0.0 1.0
# The iteration: 2915 is complete
# 0.0 1.0
# The iteration: 2916 is complete
# 0.0 1.0
# The iteration: 2917 is complete
# 0.0 1.0
# The iteration: 2918 is complete
# 0.0 1.0
# The iteration: 2919 is complete
# 0.0 1.0
# The iteration: 2920 is complete
# 0.0 1.0
# The iteration: 2921 is complete
# 0.0 1.0
# The iteration: 2922 is complete
# 0.0 1.0
# The iteration: 2923 is complete
# 0.0 1.0
# The iteration: 2924 is complete
# 0.0 1.0
# The iteration: 2925 is complete
# 0.0 1.0
# The iteration: 2926 is complete
# 0.0 1.0
# The iteration: 2927 is complete
# 0.0 1.0
# The iteration: 2928 is complete
# 0.0 1.0
# The iteration: 2929 is complete
# 0.0 1.0
# The iteration: 2930 is complete
# 0.0 1.0
# The iteration: 2931 is complete
# 0.0 1.0
# The iteration: 2932 is complete
# 0.0 1.0
# The iteration: 2933 is complete
# 0.0 1.0
# The iteration: 2934 is complete
# 0.0 1.0
# The iteration: 2935 is complete
# 0.0 1.0
# The iteration: 2936 is complete
# 0.0 1.0
# The iteration: 2937 is complete
# 0.0 1.0
# The iteration: 2938 is complete
# 0.0 1.0
# The iteration: 2939 is complete
# 0.0 1.0
# The iteration: 2940 is complete
# 0.0 1.0
# The iteration: 2941 is complete
# 0.0 1.0
# The iteration: 2942 is complete
# 0.0 1.0
# The iteration: 2943 is complete
# 0.0 1.0
# The iteration: 2944 is complete
# 0.0 1.0
# The iteration: 2945 is complete
# 0.0 1.0
# The iteration: 2946 is complete
# 0.0 1.0
# The iteration: 2947 is complete
# 0.0 1.0
# The iteration: 2948 is complete
# 0.0 1.0
# The iteration: 2949 is complete
# 0.0 1.0
# The iteration: 2950 is complete
# 0.0 1.0
# The iteration: 2951 is complete
# 0.0 1.0
# The iteration: 2952 is complete
# 0.0 1.0
# The iteration: 2953 is complete
# 0.0 1.0
# The iteration: 2954 is complete
# 0.0 1.0
# The iteration: 2955 is complete
# 0.0 1.0
# The iteration: 2956 is complete
# 0.0 1.0
# The iteration: 2957 is complete
# 0.0 1.0
# The iteration: 2958 is complete
# 0.0 1.0
# The iteration: 2959 is complete
# 0.0 1.0
# The iteration: 2960 is complete
# 0.0 1.0
# The iteration: 2961 is complete
# 0.0 1.0
# The iteration: 2962 is complete
# 0.0 1.0
# The iteration: 2963 is complete
# 0.0 1.0
# The iteration: 2964 is complete
# 0.0 1.0
# The iteration: 2965 is complete
# 0.0 1.0
# The iteration: 2966 is complete
# 0.0 1.0
# The iteration: 2967 is complete
# 0.0 1.0
# The iteration: 2968 is complete
# 0.0 1.0
# The iteration: 2969 is complete
# 0.0 1.0
# The iteration: 2970 is complete
# 0.0 1.0
# The iteration: 2971 is complete
# 0.0 1.0
# The iteration: 2972 is complete
# 0.0 1.0
# The iteration: 2973 is complete
# 0.0 1.0
# The iteration: 2974 is complete
# 0.0 1.0
# The iteration: 2975 is complete
# 0.0 1.0
# The iteration: 2976 is complete
# 0.0 1.0
# The iteration: 2977 is complete
# 0.0 1.0
# The iteration: 2978 is complete
# 0.0 1.0
# The iteration: 2979 is complete
# 0.0 1.0
# The iteration: 2980 is complete
# 0.0 1.0
# The iteration: 2981 is complete
# 0.0 1.0
# The iteration: 2982 is complete
# 0.0 1.0
# The iteration: 2983 is complete
# 0.0 1.0
# The iteration: 2984 is complete
# 0.0 1.0
# The iteration: 2985 is complete
# 0.0 1.0
# The iteration: 2986 is complete
# 0.0 1.0
# The iteration: 2987 is complete
# 0.0 1.0
# The iteration: 2988 is complete
# 0.0 1.0
# The iteration: 2989 is complete
# 0.0 1.0
# The iteration: 2990 is complete
# 0.0 1.0
# The iteration: 2991 is complete
# 0.0 1.0
# The iteration: 2992 is complete
# 0.0 1.0
# The iteration: 2993 is complete
# 0.0 1.0
# The iteration: 2994 is complete
# 0.0 1.0
# The iteration: 2995 is complete
# 0.0 1.0
# The iteration: 2996 is complete
# 0.0 1.0
# The iteration: 2997 is complete
# 0.0 1.0
# The iteration: 2998 is complete
# 0.0 1.0
# The iteration: 2999 is complete
# 0.0 1.0
# The iteration: 3000 is complete
# 0.0 1.0
# The iteration: 3001 is complete
# 0.0 1.0
# The iteration: 3002 is complete
# 0.0 1.0
# The iteration: 3003 is complete
# 0.0 1.0
# The iteration: 3004 is complete
# 0.0 1.0
# The iteration: 3005 is complete
# 0.0 1.0
# The iteration: 3006 is complete
# 0.0 1.0
# The iteration: 3007 is complete
# 0.0 1.0
# The iteration: 3008 is complete
# 0.0 1.0
# The iteration: 3009 is complete
# 0.0 1.0
# The iteration: 3010 is complete
# 0.0 1.0
# The iteration: 3011 is complete
# 0.0 1.0
# The iteration: 3012 is complete
# 0.0 1.0
# The iteration: 3013 is complete
# 0.0 1.0
# The iteration: 3014 is complete
# 0.0 1.0
# The iteration: 3015 is complete
# 0.0 1.0
# The iteration: 3016 is complete
# 0.0 1.0
# The iteration: 3017 is complete
# 0.0 1.0
# The iteration: 3018 is complete
# 0.0 1.0
# The iteration: 3019 is complete
# 0.0 1.0
# The iteration: 3020 is complete
# 0.0 1.0
# The iteration: 3021 is complete
# 0.0 1.0
# The iteration: 3022 is complete
# 0.0 1.0
# The iteration: 3023 is complete
# 0.0 1.0
# The iteration: 3024 is complete
# 0.0 1.0
# The iteration: 3025 is complete
# 0.0 1.0
# The iteration: 3026 is complete
# 0.0 1.0
# The iteration: 3027 is complete
# 0.0 1.0
# The iteration: 3028 is complete
# 0.0 1.0
# The iteration: 3029 is complete
# 0.0 1.0
# The iteration: 3030 is complete
# 0.0 1.0
# The iteration: 3031 is complete
# 0.0 1.0
# The iteration: 3032 is complete
# 0.0 1.0
# The iteration: 3033 is complete
# 0.0 1.0
# The iteration: 3034 is complete
# 0.0 1.0
# The iteration: 3035 is complete
# 0.0 1.0
# The iteration: 3036 is complete
# 0.0 1.0
# The iteration: 3037 is complete
# 0.0 1.0
# The iteration: 3038 is complete
# 0.0 1.0
# The iteration: 3039 is complete
# 0.0 1.0
# The iteration: 3040 is complete
# 0.0 1.0
# The iteration: 3041 is complete
# 0.0 1.0
# The iteration: 3042 is complete
# 0.0 1.0
# The iteration: 3043 is complete
# 0.0 1.0
# The iteration: 3044 is complete
# 0.0 1.0
# The iteration: 3045 is complete
# 0.0 1.0
# The iteration: 3046 is complete
# 0.0 1.0
# The iteration: 3047 is complete
# 0.0 1.0
# The iteration: 3048 is complete
# 0.0 1.0
# The iteration: 3049 is complete
# 0.0 1.0
# The iteration: 3050 is complete
# 0.0 1.0
# The iteration: 3051 is complete
# 0.0 1.0
# The iteration: 3052 is complete
# 0.0 1.0
# The iteration: 3053 is complete
# 0.0 1.0
# The iteration: 3054 is complete
# 0.0 1.0
# The iteration: 3055 is complete
# 0.0 1.0
# The iteration: 3056 is complete
# 0.0 1.0
# The iteration: 3057 is complete
# 0.0 1.0
# The iteration: 3058 is complete
# 0.0 1.0
# The iteration: 3059 is complete
# 0.0 1.0
# The iteration: 3060 is complete
# 0.0 1.0
# The iteration: 3061 is complete
# 0.0 1.0
# The iteration: 3062 is complete
# 0.0 1.0
# The iteration: 3063 is complete
# 0.0 1.0
# The iteration: 3064 is complete
# 0.0 1.0
# The iteration: 3065 is complete
# 0.0 1.0
# The iteration: 3066 is complete
# 0.0 1.0
# The iteration: 3067 is complete
# 0.0 1.0
# The iteration: 3068 is complete
# 0.0 1.0
# The iteration: 3069 is complete
# 0.0 1.0
# The iteration: 3070 is complete
# 0.0 1.0
# The iteration: 3071 is complete
# 0.0 1.0
# The iteration: 3072 is complete
# 0.0 1.0
# The iteration: 3073 is complete
# 0.0 1.0
# The iteration: 3074 is complete
# 0.0 1.0
# The iteration: 3075 is complete
# 0.0 1.0
# The iteration: 3076 is complete
# 0.0 1.0
# The iteration: 3077 is complete
# 0.0 1.0
# The iteration: 3078 is complete
# 0.0 1.0
# The iteration: 3079 is complete
# 0.0 1.0
# The iteration: 3080 is complete
# 0.0 1.0
# The iteration: 3081 is complete
# 0.0 1.0
# The iteration: 3082 is complete
# 0.0 1.0
# The iteration: 3083 is complete
# 0.0 1.0
# The iteration: 3084 is complete
# 0.0 1.0
# The iteration: 3085 is complete
# 0.0 1.0
# The iteration: 3086 is complete
# 0.0 1.0
# The iteration: 3087 is complete
# 0.0 1.0
# The iteration: 3088 is complete
# 0.0 1.0
# The iteration: 3089 is complete
# 0.0 1.0
# The iteration: 3090 is complete
# 0.0 1.0
# The iteration: 3091 is complete
# 0.0 1.0
# The iteration: 3092 is complete
# 0.0 1.0
# The iteration: 3093 is complete
# 0.0 1.0
# The iteration: 3094 is complete
# 0.0 1.0
# The iteration: 3095 is complete
# 0.0 1.0
# The iteration: 3096 is complete
# 0.0 1.0
# The iteration: 3097 is complete
# 0.0 1.0
# The iteration: 3098 is complete
# 0.0 1.0
# The iteration: 3099 is complete
# 0.0 1.0
# The iteration: 3100 is complete
# 0.0 1.0
# The iteration: 3101 is complete
# 0.0 1.0
# The iteration: 3102 is complete
# 0.0 1.0
# The iteration: 3103 is complete
# 0.0 1.0
# The iteration: 3104 is complete
# 0.0 1.0
# The iteration: 3105 is complete
# 0.0 1.0
# The iteration: 3106 is complete
# 0.0 1.0
# The iteration: 3107 is complete
# 0.0 1.0
# The iteration: 3108 is complete
# 0.0 1.0
# The iteration: 3109 is complete
# 0.0 1.0
# The iteration: 3110 is complete
# 0.0 1.0
# The iteration: 3111 is complete
# 0.0 1.0
# The iteration: 3112 is complete
# 0.0 1.0
# The iteration: 3113 is complete
# 0.0 1.0
# The iteration: 3114 is complete
# 0.0 1.0
# The iteration: 3115 is complete
# 0.0 1.0
# The iteration: 3116 is complete
# 0.0 1.0
# The iteration: 3117 is complete
# 0.0 1.0
# The iteration: 3118 is complete
# 0.0 1.0
# The iteration: 3119 is complete
# 0.0 1.0
# The iteration: 3120 is complete
# Found the specific value. Stopping the loop.
# Time elapsed: 0.09169063740306431 hours

# %%
# Calcular os minutos a partir da parte decimal do tempo decorrido em horas
elapsed_minutes = (elapsed_time_hours - int(elapsed_time_hours)) * 60

print("Time elapsed:", int(elapsed_time_hours), "hours and", round(elapsed_minutes), "minutes")
# Out:
# Time elapsed: 0 hours and 6 minutes

# %%
porosity_vector_values.min()
# Out:
# 0.14427381601173606

# %%
porosity_vector_values[0]
# Out:
# 0.1723469666693398

# %%
len(porosity_vector_values)
# Out:
# 3121

# %%
porosity_vector_values.min(), porosity_vector_values.max()
# Out:
# (0.14427381601173606, 0.1795654220542986)

# %%
# Calculating the distance between the pixels in each direction:
# In the real world we have 1704 pixels in a diameter with 3.81 cm
value_pixel_real_world=(3.81)/(1704) # Simple rule
# Calculating the distance of the width and height in mm
image_width_cm = (2024 * value_pixel_real_world)
image_height_cm = (2024 * value_pixel_real_world)
image_width_m = image_width_cm * (10)**(-2)
image_height_m = image_height_cm * (10)**(-2)
# Calculating the total area in meters:
total_check_real_area = (image_width_m) * (image_height_m)
# Calculate the total number of pixels in the image
total_pixels_horizontal = 2024
total_pixels_vertical = 2024
total_pixels = total_pixels_horizontal * total_pixels_vertical

# %%
image_width_m, image_height_m
# Out:
# (0.045254929577464784, 0.045254929577464784)

# %%
# Define the dimensions of the image in meters
image_width_meters = image_width_m  # example width of the image in meters
image_height_meters = image_height_m  # example height of the image in meters

# Calculate the number of pixels in each direction
number_of_pixels_in_each_direction = total_pixels_horizontal  # Assuming y_pred is your prediction array

# Calculate the distance between pixels in meters
pixel_distance_horizontal = image_width_meters / (number_of_pixels_in_each_direction - 1)
pixel_distance_vertical = image_height_meters / (number_of_pixels_in_each_direction - 1)

# Calculate the total area
total_area = image_width_meters * image_height_meters

# Print the results
print("Distance between pixels horizontally:", pixel_distance_horizontal, "meters")
print("Distance between pixels vertically:", pixel_distance_vertical, "meters")
print("Total Area:", total_area, "square meters")
# Out:
# Distance between pixels horizontally: 2.2370207403591095e-05 meters
# Distance between pixels vertically: 2.2370207403591095e-05 meters
# Total Area: 0.002048008651061297 square meters

# %%
# Checking if the area formed by the distance between the pixels is less than the total area.
pixel_distance_horizontal * pixel_distance_vertical  < total_area
# Out:
# True

# %%
# There are two ways to define the dz to the riemann integral:
# The first way
# comp_z = number_of_crooped_images * mean of the distance between pixels
length_z = 7.36*10**(-2)


# Checking the dz
dz1 = length_z/3121.

dz2 = value_pixel_real_world+pixel_distance_horizontal
dz1, dz2
# A razão de aspecto do pixel é 1, então o diametro é de uma esfera.
# dz1 - intervalo do slice baseado nos intervalos entre os slices no valor real.
# dz2 - intervalo do slice baseado no diametro do pixel na transformação de escala para o real.
# Out:
# (2.3582185197052225e-05, 0.0022582857003613376)

# %%
dz1
# Out:
# 2.3582185197052225e-05

# %% [markdown]
# ## Calculating the 3d properties by using the riemann integral

# %%
porosity_vector_values.min(), porosity_vector_values.max()
# Out:
# (0.14427381601173606, 0.1795654220542986)

# %%
porosity_vector_values[2201], porosity_vector_values[3120]
# Out:
# (0.1537446850808758, 0.16776049632553724)

# %%
porosity_vector_values[2200], Grain_fraction_vector_values[2200]
# Out:
# (0.15392979644514782, 0.8460702035548522)

# %%
def riemann_integral_L_porosity(porosity_values, slice_thickness):
    total_porosity = sum(porosity_values)
    integral_approximation = total_porosity * slice_thickness 
    return integral_approximation

# %%
def riemann_integral_L_fraction_grain(fraction_grain_values, slice_thickness):
    total_fraction_grain = sum(fraction_grain_values) 
    integral_approximation = total_fraction_grain * slice_thickness 
    return integral_approximation

# %%
def riemann_integral_L_pore_area(pore_area_values, slice_thickness):
    total_pore_area = sum(pore_area_values)
    integral_approximation = total_pore_area * slice_thickness
    return integral_approximation

# %%
def riemann_integral_L_grain_area(grain_area_values, slice_thickness):
    total_grain_area = sum(grain_area_values)
    integral_approximation = total_grain_area * slice_thickness
    return integral_approximation

# %%
## side Area of  cylinder
r = value_pixel_real_world/2
side_area = 2 * 3.1415 * r * length_z

# %%
delta_side_area = side_area/3121
delta_side_area_percentage = (delta_side_area * 100.0) / side_area
delta_side_area, side_area, delta_side_area_percentage
# Out:
# (1.6564429963310786e-07, 0.0005169758591549296, 0.03204101249599488)

# %%
# In the case of porosity and grain fraction, the integral is supposed to be in percentage, wich means that
# we need to covnert the interval "H" and the range of riemman integral both in percentage

# Example porosity values (vector representing porosity values at discrete depths)
# Example porosity values at different }depths
# The "H" of the reimann integral

slice_thickness =  dz1 # meters 


##slice_thickness_percentage = (100.0 * slice_thickness)/(length_z) # based on the length
slice_thickness_percentage = delta_side_area_percentage # Based on the side area

# Compute Riemann integral approximation for porosity over the depth of the rock
integral_approximation_porosity = riemann_integral_L_porosity(porosity_vector_values, slice_thickness_percentage)

print("Riemann integral approximation for porosity in 3D to the sample IL033:", integral_approximation_porosity, "%")
# Out:
# Riemann integral approximation for porosity in 3D to the sample IL033: 16.465679993869472 %

# %%
porosity_vector_values.min(), porosity_vector_values.max()
# Out:
# (0.14427381601173606, 0.1795654220542986)

# %%
import numpy as np

# Assuming porosity_vector_values is a NumPy array
# Find the minimum value and its index
min_value = np.min(porosity_vector_values)
min_position = np.argmin(porosity_vector_values)

print("Minimum value:", min_value)
print("Position of minimum value:", min_position)
# Out:
# Minimum value: 0.14427381601173606
# Position of minimum value: 2430

# %%
slice_thickness_percentage
# Out:
# 0.03204101249599488

# %%
# The "H" of the reimann integral
##slice_thickness = (pixel_distance_horizontal + pixel_distance_vertical) / 2  # meters 

# Compute Riemann integral approximation for porosity over the depth of the rock
integral_approximation_grain_fraction = riemann_integral_L_fraction_grain(Grain_fraction_vector_values, slice_thickness_percentage)

print("Riemann integral approximation for grain fraction in 3D over length:", integral_approximation_grain_fraction, "%")
# Out:
# Riemann integral approximation for grain fraction in 3D over length: 83.53432000613032 %

# %%
integral_approximation_porosity + integral_approximation_grain_fraction
# Out:
# 99.99999999999979

# %%
# Compute Riemann integral approximation for porosity over the depth of the rock
integral_approximation_pore_volume = riemann_integral_L_pore_area(pore_Area_vector_values, slice_thickness)

print("Riemann integral approximation for pore_volume:", integral_approximation_pore_volume,"m^3")
# Out:
# Riemann integral approximation for pore_volume: 1.402398875661841e-07 m^3

# %%
pore_Area_vector_values[1], Grain_Area_vector_values[1]
# Out:
# (0.00019945640463214982, 0.000964601928033872)

# %%
# Compute Riemann integral approximation for porosity over the depth of the rock
integral_approximation_grain_volume = riemann_integral_L_grain_area(Grain_Area_vector_values, slice_thickness)

print("Riemann integral approximation for grain_volume:", integral_approximation_grain_volume, "m^3")
# Out:
# Riemann integral approximation for grain_volume: 7.114402634693295e-07 m^3

# %%
vol_sample = 3.1415 * ((3.81/2)*10**(-2))**2 * length_z

# %%
total_volu = integral_approximation_pore_volume + integral_approximation_grain_volume
print('Checando o volume total da amostra (aproximado)',total_volu, vol_sample)
# Out:
# Checando o volume total da amostra (aproximado) 8.516801510355137e-07 8.390828379600002e-05

# %%
percentual_variation = ((total_volu - vol_sample)*100.0)/vol_sample

# %%
# priting the error
print('the error in relation to the volume of the sample is:',percentual_variation,'%')
# Out:
# the error in relation to the volume of the sample is: -98.98498680642051 %

# %%
## Calculating the porosity from the volume grain and pore:
#total_volu
#integral_approximation_grain_volume
grain_frac = (integral_approximation_grain_volume * 100)/total_volu
grain_frac
# Out:
# 83.53373770708714

# %% [markdown]
# ### Graphic of the 2d variation properties

# %%
import matplotlib.pyplot as plt
import numpy as np

# Ajustar o tamanho da figura
plt.figure(figsize=(12, 6))  # Largura = 18 polegadas, Altura = 6 polegadas

# Plot
plt.plot(np.arange(len(Grain_fraction_vector_values)), abs(Grain_fraction_vector_values))
plt.xlabel('Índice', fontsize=18)
plt.ylabel('Valores de fração de grão (%)')
plt.title('Valores de fração de grão (%) vs. Índice')

# Calculate statistics
mean_value = Grain_fraction_vector_values.mean()
max_value = Grain_fraction_vector_values.max()
min_value = Grain_fraction_vector_values.min()

# Round the statistics to four decimal places
mean_value = round(mean_value, 4)
max_value = round(max_value, 4)
min_value = round(min_value, 4)

# Draw lines for mean, max, and min
plt.axhline(y=mean_value, color='r', linestyle='--', label=f'Mean: {mean_value}')
plt.axhline(y=max_value, color='g', linestyle='--', label=f'Max: {max_value}')
plt.axhline(y=min_value, color='b', linestyle='--', label=f'Min: {min_value}')
plt.legend(fontsize=18)  # Define o tamanho da fonte para a legenda

plt.xticks(fontsize=18)  # Define o tamanho da fonte para os números no eixo x
plt.yticks(fontsize=18)  # Define o tamanho da fonte para os números no eixo y

plt.grid(True)

# Save the plot as PNG
###plt.savefig('TheCNNresults\Grain_fraction_cnn_plot.png')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Ajustar o tamanho da figura
plt.figure(figsize=(16, 8))  # Largura = 18 polegadas, Altura = 6 polegadas

# Plot
plt.plot(np.arange(len(porosity_vector_values)), abs(porosity_vector_values))
plt.xlabel('Índice')
plt.ylabel('Valores de Porosidade (%)')
plt.title('Valores de Porosidade (%) vs. Índice')

# Calculate statistics
mean_value = porosity_vector_values.mean()
max_value = porosity_vector_values.max()
min_value = porosity_vector_values.min()

# Draw lines for mean, max, and min
plt.axhline(y=mean_value, color='r', linestyle='--', label=f'Mean: {mean_value}')
plt.axhline(y=max_value, color='g', linestyle='--', label=f'Max: {max_value}')
plt.axhline(y=min_value, color='b', linestyle='--', label=f'Min: {min_value}')
plt.legend()

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Ajustar o tamanho da figura
plt.figure(figsize=(12, 6))  # Largura = 18 polegadas, Altura = 6 polegadas

# Plot
plt.plot(np.arange(len(Grain_fraction_vector_values)), abs(Grain_fraction_vector_values))
plt.xlabel('Índice', fontsize=22)
plt.ylabel('Valores de fração de grão (%)',fontsize=22)
plt.title('Valores de fração de grão (%) vs. Índice',fontsize=22)

# Calculate statistics
mean_value = Grain_fraction_vector_values.mean()
max_value = Grain_fraction_vector_values.max()
min_value = Grain_fraction_vector_values.min()

# Round the statistics to four decimal places
mean_value = round(mean_value, 4)
max_value = round(max_value, 4)
min_value = round(min_value, 4)

# Draw lines for mean, max, and min
plt.axhline(y=mean_value, color='r', linestyle='--', label=f'Mean: {mean_value}')
plt.axhline(y=max_value, color='g', linestyle='--', label=f'Max: {max_value}')
plt.axhline(y=min_value, color='b', linestyle='--', label=f'Min: {min_value}')
plt.legend(fontsize=22)  # Define o tamanho da fonte para a legenda

plt.xticks(fontsize=22)  # Define o tamanho da fonte para os números no eixo x
plt.yticks(fontsize=22)  # Define o tamanho da fonte para os números no eixo y

plt.grid(True)

# Save the plot as PNG
plt.savefig('TheCNN_unet_results\grain_fraction_thresold_plot.png')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Ajustar o tamanho da figura
plt.figure(figsize=(12, 6))  # Largura = 12 polegadas, Altura = 6 polegadas

# Plot
plt.plot(np.arange(len(porosity_vector_values)), abs(porosity_vector_values))
plt.xlabel('Índice', fontsize=22)  # Define o tamanho da fonte para o eixo x
plt.ylabel('Valores de Porosidade (%)', fontsize=22)  # Define o tamanho da fonte para o eixo y
plt.title('Valores de Porosidade (%) vs. Índice', fontsize=22)  # Define o tamanho da fonte para o título

# Calculate statistics
mean_value = porosity_vector_values.mean()
max_value = porosity_vector_values.max()
min_value = porosity_vector_values.min()

# Round the statistics to four decimal places
mean_value = round(mean_value, 4)
max_value = round(max_value, 4)
min_value = round(min_value, 4)

# Draw lines for mean, max, and min
plt.axhline(y=mean_value, color='r', linestyle='--', label=f'Mean: {mean_value}')
plt.axhline(y=max_value, color='g', linestyle='--', label=f'Max: {max_value}')
plt.axhline(y=min_value, color='b', linestyle='--', label=f'Min: {min_value}')
plt.legend(fontsize=22)  # Define o tamanho da fonte para a legenda

plt.xticks(fontsize=22)  # Define o tamanho da fonte para os números no eixo x
plt.yticks(fontsize=22)  # Define o tamanho da fonte para os números no eixo y

plt.grid(True)


# Save the plot as PNG
plt.savefig('TheCNN_unet_results\porosity_thresold_plot.png')
plt.show()

# %%
porosity_vector_values.min(), porosity_vector_values.max()
# Out:
# (0.14427381601173606, 0.1795654220542986)

# %%
Grain_fraction_vector_values.min(), Grain_fraction_vector_values.max()
# Out:
# (0.8204345779457014, 0.8557261839882639)

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

# Dados de exemplo (valores de porosidade)
# porosity_vector_values = np.random.normal(loc=mean_value, scale=std_value, size=1000)

# Ajustar o tamanho da figura
plt.figure(figsize=(12, 6))

# Plot da distribuição normal
plt.hist(porosity_vector_values, bins=30, density=True, alpha=0.6, color='g')

# Obter os parâmetros da distribuição normal
mu, std = norm.fit(porosity_vector_values)

# Calcular a PDF da distribuição normal
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)

# Plot da PDF da distribuição normal
plt.plot(x, p, 'k', linewidth=2)

# Adicionar legendas e rótulos
plt.title('Distribuição Normal dos Valores de Porosidade', fontsize=22)
plt.xlabel('Valores de Porosidade (%)', fontsize=22)
plt.ylabel('Densidade de Probabilidade', fontsize=22)
plt.legend(['Distribuição Normal', 'Dados de Porosidade'], fontsize=22)

plt.xticks(fontsize=22)  # Define o tamanho da fonte para os números no eixo x
plt.yticks(fontsize=22)  # Define o tamanho da fonte para os números no eixo y

plt.grid(True)

# Salvar o gráfico como PNG
plt.savefig('TheCNN_unet_results\porosity_distribution_plot_thresold.png')

plt.show()

# %%
pore_Area_vector_values_cm_2 = pore_Area_vector_values*(10)**(4)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Ajustar o tamanho da figura
plt.figure(figsize=(12, 6))  # Largura = 18 polegadas, Altura = 6 polegadas

# Plot
plt.plot(np.arange(len(pore_Area_vector_values_cm_2)), abs(pore_Area_vector_values_cm_2))
plt.xlabel('Índice', fontsize=22)
plt.ylabel('Valores de área do poro (cm²)', fontsize=22)
plt.title('Valores de área do poro (cm²) vs. Índice', fontsize=22)

# Calculate statistics
mean_value = pore_Area_vector_values_cm_2.mean()
max_value = pore_Area_vector_values_cm_2.max()
min_value = pore_Area_vector_values_cm_2.min()

# Round the statistics to four decimal places
mean_value = round(mean_value, 4)
max_value = round(max_value, 4)
min_value = round(min_value, 4)


# Draw lines for mean, max, and min
plt.axhline(y=mean_value, color='r', linestyle='--', label=f'Mean: {mean_value}')
plt.axhline(y=max_value, color='g', linestyle='--', label=f'Max: {max_value}')
plt.axhline(y=min_value, color='b', linestyle='--', label=f'Min: {min_value}')

plt.legend(fontsize=22)  # Define o tamanho da fonte para a legenda

plt.xticks(fontsize=22)  # Define o tamanho da fonte para os números no eixo x
plt.yticks(fontsize=22)  # Define o tamanho da fonte para os números no eixo y

plt.grid(True)

# Save the plot as PNG
plt.savefig('TheCNN_unet_results\pore_area_thresold_plot.png')

plt.show()

# %%
Grain_Area_vector_values_cm_2 = Grain_Area_vector_values * 10**(4)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Ajustar o tamanho da figura
plt.figure(figsize=(12, 6))  # Largura = 18 polegadas, Altura = 6 polegadas

# Plot
plt.plot(np.arange(len(Grain_Area_vector_values_cm_2)), abs(Grain_Area_vector_values_cm_2))
plt.xlabel('Índice', fontsize=22)
plt.ylabel('Valores de área do grão (cm²)', fontsize=22)
plt.title('Valores de área do grão (cm²) vs. Índice', fontsize=22)

# Calculate statistics
mean_value = Grain_Area_vector_values_cm_2.mean()
max_value = Grain_Area_vector_values_cm_2.max()
min_value = Grain_Area_vector_values_cm_2.min()

# Round the statistics to four decimal places
mean_value = round(mean_value, 4)
max_value = round(max_value, 4)
min_value = round(min_value, 4)

# Draw lines for mean, max, and min
plt.axhline(y=mean_value, color='r', linestyle='--', label=f'Mean: {mean_value}')
plt.axhline(y=max_value, color='g', linestyle='--', label=f'Max: {max_value}')
plt.axhline(y=min_value, color='b', linestyle='--', label=f'Min: {min_value}')

plt.legend(fontsize=22)  # Define o tamanho da fonte para a legenda

plt.xticks(fontsize=22)  # Define o tamanho da fonte para os números no eixo x
plt.yticks(fontsize=22)  # Define o tamanho da fonte para os números no eixo y

plt.grid(True)

# Save the plot as PNG
plt.savefig('TheCNN_unet_results\grain_area_thresold_plot.png')

plt.show()

# %%
## Testing
import statistics
# Calculate median
median_value = statistics.median(pore_Area_vector_values)
total_area = sum(pore_Area_vector_values)

# convert to the percentage
median_percentage = (100.0 * median_value)/(total_area)
print("Median:", median_value, 'total area', total_area, 'median percentage', median_percentage)
# Out:
# Median: 7.93011359941885e-05 total area 0.25603352437951415 median percentage 0.030972950197194402

# %%
#delta_a = 3.81/3121
delta_a = median_value # The median of area per slice
delta_a_percentage = median_percentage
delta_a, delta_a_percentage
# Out:
# (7.93011359941885e-05, 0.030972950197194402)

# %%
def riemann_integral_volume_new_version(porosity_values, delta_h, delta_a):
    total_volume = 0
    for porosity in porosity_values:
        area = porosity * delta_h  # Area of each slice
        volume = area * delta_a  # Volume of each slice
        total_volume += volume  # Accumulate the volume
    return total_volume

# %%
# Compute Riemann integral approximation for porosity over the depth of the rock
integral_approximation_porosity_new = riemann_integral_volume_new_version(porosity_vector_values, slice_thickness_percentage, delta_a_percentage)

print("Riemann integral approximation for porosity in 3D to the sample IL033:", integral_approximation_porosity_new, "%")
# Out:
# Riemann integral approximation for porosity in 3D to the sample IL033: 0.21956087311109937 %

# %%
## Testing
import statistics
# Calculate median
median_value_grain = statistics.median(Grain_Area_vector_values)
total_area_grain = sum(Grain_Area_vector_values)

# convert to the percentage
median_percentage_grain = (100.0 * median_value_grain)/(total_area_grain)
print("Median:", median_value_grain, 'total area', total_area_grain, 'median percentage', median_percentage_grain)
# Out:
# Median: 0.0010779967109545473 total area 3.355506898693627 median percentage 0.032126195639002715

# %%
# The "H" of the reimann integral
##slice_thickness = (pixel_distance_horizontal + pixel_distance_vertical) / 2  # meters 

# Compute Riemann integral approximation for porosity over the depth of the rock
integral_approximation_grain_fraction = riemann_integral_volume_new_version(Grain_fraction_vector_values, slice_thickness_percentage, median_percentage_grain)

print("Riemann integral approximation for grain fraction in 3D over length:", integral_approximation_grain_fraction, "%")
# Out:
# Riemann integral approximation for grain fraction in 3D over length: 2.976969102542287 %
